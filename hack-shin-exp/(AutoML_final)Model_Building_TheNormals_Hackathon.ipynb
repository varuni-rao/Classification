# %% [markdown]
# # **Hackathon: Shinkansen Travel Experience**

# %% [markdown]
# ## **Organization**
#
# This project has 3 notebook files.
#
# 1. Data_preparation_TheNormals_Hackathon
# 2. Model_Building_TheNormals_Hackathon
# 3. Prediction_TheNormals_Hackathon
#
# This notebook is the second notebook where data stored in .csv file in 1st notebook, is read and various models are built. The best performing models are stored to be used in the next notebook for prediction.

# %% [markdown]
# ## **Problem Statement**
#
# This problem is to determine passengers' experience, whether they are deligighted or not after their travel on the Shinkansen Bullet Train in Japan. This machine learning exercise aims to determine the relative importance of each parameter about their contribution to the passengers' overall travel experience. The dataset contains a random sample of individuals who traveled on this train. The on-time performance of the trains along with passenger information is published in a file named 'Traveldata_train.csv'.  These passengers were later asked to provide their feedback on various parameters related to the travel along with their overall experience. These collected details are made available in the survey report labeled 'Surveydata_train.csv'.
#
# In the survey, each passenger was explicitly asked whether they were satisfied with their overall travel experience or not, and that is captured in the data of the survey report under the variable labeled 'Overall_Experience', which is the target variable.
#
# The objective of this problem is to understand which parameters play an important role in swaying passenger feedback towards a positive scale. We are provided with test data containing the travel data and the survey data of passengers. Both the test data and the train data are collected at the same time and belong to the same population.

# %% [markdown]
# ## **Solution**
#
# The given problem statement suggests that the problem is a Supervised learning classification problem. We will use various Machine Learning models available in the library for classification and observe which model gives us the best accuracy on the test set and select it as our final model.

# %% [markdown]
# ### **Loading Libraries**

# %%
# %pip install flaml[automl] matplotlib openml
# Out:
# Requirement already satisfied: flaml[automl] in /usr/local/lib/python3.10/dist-packages (2.1.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: openml in /usr/local/lib/python3.10/dist-packages (0.14.1)
# Requirement already satisfied: NumPy>=1.17.0rc1 in /usr/local/lib/python3.10/dist-packages (from flaml[automl]) (1.23.5)
# Requirement already satisfied: lightgbm>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from flaml[automl]) (4.1.0)
# Requirement already satisfied: xgboost>=0.90 in /usr/local/lib/python3.10/dist-packages (from flaml[automl]) (2.0.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from flaml[automl]) (1.11.4)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from flaml[automl]) (1.5.3)
# Requirement already satisfied: scikit-learn>=0.24 in /usr/local/lib/python3.10/dist-packages (from flaml[automl]) (1.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: liac-arff>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from openml) (2.5.0)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.10/dist-packages (from openml) (0.13.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from openml) (2.31.0)
# Requirement already satisfied: minio in /usr/local/lib/python3.10/dist-packages (from openml) (7.2.3)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from openml) (10.0.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->flaml[automl]) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24->flaml[automl]) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24->flaml[automl]) (3.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from minio->openml) (2023.11.17)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from minio->openml) (2.0.7)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from minio->openml) (23.1.0)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.10/dist-packages (from minio->openml) (3.20.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from minio->openml) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->openml) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->openml) (3.6)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->minio->openml) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->minio->openml) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->minio->openml) (2.21)

# %%
# !pip3 install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.4)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)

# %%
! pip install -U accelerate
! pip install -U transformers
# Out:
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (0.26.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.1.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.2)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.1.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.36.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.20.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.19.3->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)

# %%
# !pip install datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.16.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.23.5)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (10.0.1)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: huggingface-hub>=0.19.4 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.20.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.19.4->datasets) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2023.11.17)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets) (1.16.0)

# %%
# libraries for data manipulation
import pandas as pd
import numpy as np

from minio.error import ServerError
from flaml.automl.data import load_openml_dataset

# library to prettu print python datastructures
from pprint import pprint

# library for train test split
from sklearn.model_selection import train_test_split

# library for scaling data
from sklearn.preprocessing import MinMaxScaler

# library for metrics
from sklearn.metrics import accuracy_score

# libraries for GridSearchCV and RandomizedSearchCV
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# library for imputation
from sklearn.impute import KNNImputer

# libraries for cross validation
from sklearn.model_selection import cross_val_score, KFold

# library for ensemble models
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier, StackingClassifier

# library for XGBoostClassifier model
from xgboost import XGBClassifier

# library for lightgbm
from lightgbm import LGBMClassifier

# library for AutoML
from flaml import AutoML

# library for random number generator
import random

# library to save and load files
import joblib

# ignore Warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### **Reading train dataframe from .csv file**

# %%
# mount google colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# read df_train from .csv files
df_train = pd.read_csv('/content/drive/MyDrive/DScourse/Hackathon/KNN3/train_data.csv')

# %%
# read df_test from .csv files
# while we do not use df_test, we need to use the same MinMaxScaler to scale it.
# hence we will scale the df_test and
# store it as df_test_scaled to be used in the next notebook for prediction
df_pred = pd.read_csv('/content/drive/MyDrive/DScourse/Hackathon/KNN3/pred_data.csv')

# %% [markdown]
# ### **Data Preprocessing**

# %%
df_train.head()
# Out:
#          ID  Gender  Customer_Type   Age  Type_Travel  Travel_Class  \
# 0  98800001     1.0            1.0  52.0          NaN             1
# 1  98800002     0.0            1.0  48.0          0.0             0
# 2  98800003     1.0            1.0  43.0          1.0             1
# 3  98800004     1.0            1.0  44.0          1.0             1
# 4  98800005     1.0            1.0  50.0          1.0             1
#
#    Travel_Distance  Departure_Delay_in_Mins  Arrival_Delay_in_Mins  \
# 0              272                      0.0                    5.0
# 1             2200                      9.0                    0.0
# 2             1061                     77.0                  119.0
# 3              780                     13.0                   18.0
# 4             1981                      0.0                    0.0
#
#    Overall_Experience  ...  Onboard_Wifi_Service  Onboard_Entertainment  \
# 0                   0  ...                   4.0                    2.0
# 1                   0  ...                   4.0                    1.0
# 2                   1  ...                   2.0                    4.0
# 3                   0  ...                   3.0                    2.0
# 4                   1  ...                   2.0                    4.0
#
#    Online_Support  Ease_of_Online_Booking  Onboard_Service  Legroom  \
# 0             3.0                     2.0              2.0      3.0
# 1             4.0                     4.0              5.0      2.0
# 2             5.0                     5.0              5.0      5.0
# 3             3.0                     3.0              3.0      3.0
# 4             5.0                     4.0              4.0      4.0
#
#    Baggage_Handling  CheckIn_Service  Cleanliness  Online_Boarding
# 0               2.0              4.0          2.0              1.0
# 1               1.0              2.0          4.0              4.0
# 2               5.0              4.0          5.0              5.0
# 3               3.0              4.0          3.0              3.0
# 4               4.0              4.0          4.0              4.0
#
# [5 rows x 25 columns]

# %%
df_pred.head()
# Out:
#          ID  Gender  Customer_Type   Age  Type_Travel  Travel_Class  \
# 0  99900001     1.0            NaN  36.0          1.0             1
# 1  99900002     1.0            0.0  21.0          1.0             1
# 2  99900003     0.0            1.0  60.0          1.0             1
# 3  99900004     1.0            1.0  29.0          0.0             0
# 4  99900005     0.0            0.0  18.0          1.0             1
#
#    Travel_Distance  Departure_Delay_in_Mins  Arrival_Delay_in_Mins  \
# 0              532                      0.0                    0.0
# 1             1425                      9.0                   28.0
# 2             2832                      0.0                    0.0
# 3             1352                      0.0                    0.0
# 4             1610                     17.0                    0.0
#
#    Seat_Comfort  ...  Onboard_Wifi_Service  Onboard_Entertainment  \
# 0           3.0  ...                   2.0                    5.0
# 1           0.0  ...                   3.0                    1.0
# 2           5.0  ...                   5.0                    5.0
# 3           3.0  ...                   1.0                    3.0
# 4           5.0  ...                   5.0                    5.0
#
#    Online_Support  Ease_of_Online_Booking  Onboard_Service  Legroom  \
# 0             4.0                     5.0              5.0      5.0
# 1             3.0                     3.0              5.0      3.0
# 2             5.0                     2.0              2.0      2.0
# 3             5.0                     1.0              3.0      2.0
# 4             5.0                     5.0              NaN      3.0
#
#    Baggage_Handling  CheckIn_Service  Cleanliness  Online_Boarding
# 0               5.0              4.0          5.0              1.0
# 1               4.0              3.0          5.0              3.0
# 2               2.0              4.0          2.0              5.0
# 3               5.0              5.0          5.0              1.0
# 4               5.0              5.0          5.0              5.0
#
# [5 rows x 24 columns]

# %% [markdown]
# #### **Seperate Train and Test data**

# %%
# saving a copy of df_train for future reference
df_train_copy = df_train.copy()

# splitting X, y
X = df_train.drop(['ID','Overall_Experience'], axis = 1)
y = df_train['Overall_Experience']

# %%
X.shape, y.shape
# Out:
# ((94379, 23), (94379,))

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=13)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((66065, 23), (28314, 23), (66065,), (28314,))

# %% [markdown]
# #### **Impute Missing values**

# %%
# creating a copy of test data
df_pred_orig = df_pred.copy()

# %%
# checking for missing values
X_train.isnull().sum()[X_train.isnull().sum() != 0], X_test.isnull().sum()[X_test.isnull().sum() != 0], df_pred.isnull().sum()[df_pred.isnull().sum() != 0]
# Out:
# (Gender                       61
#  Customer_Type              6284
#  Age                          26
#  Type_Travel                6403
#  Departure_Delay_in_Mins      41
#  Arrival_Delay_in_Mins       256
#  Seat_Comfort                 49
#  Arrival_Time_Convenient    6275
#  Catering                   6153
#  Platform_Location            18
#  Onboard_Wifi_Service         18
#  Onboard_Entertainment        10
#  Online_Support               60
#  Ease_of_Online_Booking       50
#  Onboard_Service            5225
#  Legroom                      61
#  Baggage_Handling            101
#  CheckIn_Service              56
#  Cleanliness                   5
#  Online_Boarding               5
#  dtype: int64,
#  Gender                       16
#  Customer_Type              2667
#  Age                           7
#  Type_Travel                2823
#  Departure_Delay_in_Mins      16
#  Arrival_Delay_in_Mins       101
#  Seat_Comfort                 12
#  Arrival_Time_Convenient    2655
#  Catering                   2588
#  Platform_Location            12
#  Onboard_Wifi_Service         12
#  Onboard_Entertainment         8
#  Online_Support               31
#  Ease_of_Online_Booking       23
#  Onboard_Service            2376
#  Legroom                      29
#  Baggage_Handling             41
#  CheckIn_Service              21
#  Cleanliness                   1
#  Online_Boarding               1
#  dtype: int64,
#  Gender                       30
#  Customer_Type              3383
#  Age                          11
#  Type_Travel                3448
#  Departure_Delay_in_Mins      29
#  Arrival_Delay_in_Mins       123
#  Seat_Comfort                 22
#  Arrival_Time_Convenient    3325
#  Catering                   3357
#  Platform_Location            12
#  Onboard_Wifi_Service         12
#  Onboard_Entertainment         8
#  Online_Support               26
#  Ease_of_Online_Booking       18
#  Onboard_Service            2872
#  Legroom                      25
#  Baggage_Handling             40
#  CheckIn_Service              22
#  Cleanliness                   2
#  Online_Boarding               2
#  dtype: int64)

# %%
# making ID column index to be retained in original prediction dataframe
df_pred.set_index('ID', inplace = True)

# %%
df_pred.head()
# Out:
#           Gender  Customer_Type   Age  Type_Travel  Travel_Class  \
# ID
# 99900001     1.0            NaN  36.0          1.0             1
# 99900002     1.0            0.0  21.0          1.0             1
# 99900003     0.0            1.0  60.0          1.0             1
# 99900004     1.0            1.0  29.0          0.0             0
# 99900005     0.0            0.0  18.0          1.0             1
#
#           Travel_Distance  Departure_Delay_in_Mins  Arrival_Delay_in_Mins  \
# ID
# 99900001              532                      0.0                    0.0
# 99900002             1425                      9.0                   28.0
# 99900003             2832                      0.0                    0.0
# 99900004             1352                      0.0                    0.0
# 99900005             1610                     17.0                    0.0
#
#           Seat_Comfort  Seat_Class  ...  Onboard_Wifi_Service  \
# ID                                  ...
# 99900001           3.0           1  ...                   2.0
# 99900002           0.0           0  ...                   3.0
# 99900003           5.0           0  ...                   5.0
# 99900004           3.0           1  ...                   1.0
# 99900005           5.0           0  ...                   5.0
#
#           Onboard_Entertainment  Online_Support  Ease_of_Online_Booking  \
# ID
# 99900001                    5.0             4.0                     5.0
# 99900002                    1.0             3.0                     3.0
# 99900003                    5.0             5.0                     2.0
# 99900004                    3.0             5.0                     1.0
# 99900005                    5.0             5.0                     5.0
#
#           Onboard_Service  Legroom  Baggage_Handling  CheckIn_Service  \
# ID
# 99900001              5.0      5.0               5.0              4.0
# 99900002              5.0      3.0               4.0              3.0
# 99900003              2.0      2.0               2.0              4.0
# 99900004              3.0      2.0               5.0              5.0
# 99900005              NaN      3.0               5.0              5.0
#
#           Cleanliness  Online_Boarding
# ID
# 99900001          5.0              1.0
# 99900002          5.0              3.0
# 99900003          2.0              5.0
# 99900004          5.0              1.0
# 99900005          5.0              5.0
#
# [5 rows x 23 columns]

# %%
# declaring KNNImputer
imputer = KNNImputer(n_neighbors=14)

# imputing missing values
X_train_imputed = pd.DataFrame(imputer.fit_transform(X_train), columns = X_train.columns)
X_test_imputed = pd.DataFrame(imputer.transform(X_test), columns = X_test.columns)
df_pred_imputed = pd.DataFrame(imputer.transform(df_pred), columns = df_pred.columns)

# %%
X_train_imputed = X_train_imputed.round(decimals=0).astype(int)

X_test_imputed = X_test_imputed.round(decimals = 0).astype(int)

df_pred_imputed = df_pred_imputed.round(decimals = 0).astype(int)

# %%
# checking for null values
X_train_imputed.isnull().sum()[X_train_imputed.isnull().sum() != 0], X_test_imputed.isnull().sum()[X_test_imputed.isnull().sum() != 0],  df_pred_imputed.isnull().sum()[df_pred_imputed.isnull().sum() != 0]
# Out:
# (Series([], dtype: int64), Series([], dtype: int64), Series([], dtype: int64))

# %%
df_pred_imputed.head()
# Out:
#    Gender  Customer_Type  Age  Type_Travel  Travel_Class  Travel_Distance  \
# 0       1              1   36            1             1              532
# 1       1              0   21            1             1             1425
# 2       0              1   60            1             1             2832
# 3       1              1   29            0             0             1352
# 4       0              0   18            1             1             1610
#
#    Departure_Delay_in_Mins  Arrival_Delay_in_Mins  Seat_Comfort  Seat_Class  \
# 0                        0                      0             3           1
# 1                        9                     28             0           0
# 2                        0                      0             5           0
# 3                        0                      0             3           1
# 4                       17                      0             5           0
#
#    ...  Onboard_Wifi_Service  Onboard_Entertainment  Online_Support  \
# 0  ...                     2                      5               4
# 1  ...                     3                      1               3
# 2  ...                     5                      5               5
# 3  ...                     1                      3               5
# 4  ...                     5                      5               5
#
#    Ease_of_Online_Booking  Onboard_Service  Legroom  Baggage_Handling  \
# 0                       5                5        5                 5
# 1                       3                5        3                 4
# 2                       2                2        2                 2
# 3                       1                3        2                 5
# 4                       5                4        3                 5
#
#    CheckIn_Service  Cleanliness  Online_Boarding
# 0                4            5                1
# 1                3            5                3
# 2                4            2                5
# 3                5            5                1
# 4                5            5                5
#
# [5 rows x 23 columns]

# %% [markdown]
# ### **Building Models**

# %% [markdown]
# #### **Functions to build models and obtain scores**

# %%
# predict on the test data
def predict(model, model_name, predictiondata):
    # create a copy of df_test
    #predictiondata = df_pred_unscaled.copy()

    # set 'ID' column as the index
    predictiondata.set_index('ID', inplace=True)

    # separate ID column from df_test for predictions
    X = predictiondata.copy()

    # predict on test set
    y_pred = np.round(model.predict(X), 0).astype(int) if model == 'nn_model9a' else model.predict(X).astype(int)

    # create a DataFrame for the current model's predictions
    prediction_df = pd.DataFrame({'ID': X.index, 'Overall_Experience': y_pred.flatten()})

    # save predictions to a CSV file for the current model
    filename = "/content/drive/MyDrive/DScourse/Hackathon/AutoML/Predictions/" + model_name + "_pred.csv"
    prediction_df.to_csv(filename, index=False, header=True, line_terminator='\r\n')

# %% [markdown]
# #### **Model 1: Unscaled imputed data, KNNImputer, all original columns**

# %%
train_x = X_train_imputed.copy()

test_x = X_test_imputed.copy()

pred_x = pd.concat([df_pred_orig['ID'], df_pred_imputed.copy()], axis = 1)

# %%
pred_x.head()
# Out:
#          ID  Gender  Customer_Type  Age  Type_Travel  Travel_Class  \
# 0  99900001       1              1   36            1             1
# 1  99900002       1              0   21            1             1
# 2  99900003       0              1   60            1             1
# 3  99900004       1              1   29            0             0
# 4  99900005       0              0   18            1             1
#
#    Travel_Distance  Departure_Delay_in_Mins  Arrival_Delay_in_Mins  \
# 0              532                        0                      0
# 1             1425                        9                     28
# 2             2832                        0                      0
# 3             1352                        0                      0
# 4             1610                       17                      0
#
#    Seat_Comfort  ...  Onboard_Wifi_Service  Onboard_Entertainment  \
# 0             3  ...                     2                      5
# 1             0  ...                     3                      1
# 2             5  ...                     5                      5
# 3             3  ...                     1                      3
# 4             5  ...                     5                      5
#
#    Online_Support  Ease_of_Online_Booking  Onboard_Service  Legroom  \
# 0               4                       5                5        5
# 1               3                       3                5        3
# 2               5                       2                2        2
# 3               5                       1                3        2
# 4               5                       5                4        3
#
#    Baggage_Handling  CheckIn_Service  Cleanliness  Online_Boarding
# 0                 5                4            5                1
# 1                 4                3            5                3
# 2                 2                4            2                5
# 3                 5                5            5                1
# 4                 5                5            5                5
#
# [5 rows x 24 columns]

# %%
# declare model for logistic regression
automl1 = AutoML()

# setting for AutoML
settings = {
    "time_budget": 600,  # total running time in seconds
    "metric": 'accuracy',
    # check the documentation for options of metrics (https://microsoft.github.io/FLAML/docs/Use-Cases/Task-Oriented-AutoML#optimization-metric)
    "task": 'classification',  # task type
    "estimator_list": ['xgboost', 'xgb_limitdepth', 'rf', 'lgbm', 'histgb', 'lrl1', 'lrl2', 'catboost', 'extra_tree', 'kneighbor'],
    "log_file_name": '/content/drive/MyDrive/DScourse/Hackathon/AutoML/hackathon1.log',  # flaml log file
    "seed": 13,    # random seed
}

# %%
# The main flaml automl API
automl1.fit(X_train=train_x, y_train=y_train, **settings)
# Out:
# [flaml.automl.logger: 01-12 02:25:03] {1679} INFO - task = classification
# [flaml.automl.logger: 01-12 02:25:03] {1690} INFO - Evaluation method: holdout
# [flaml.automl.logger: 01-12 02:25:03] {1788} INFO - Minimizing error metric: 1-accuracy
# [flaml.automl.logger: 01-12 02:25:03] {1900} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'catboost', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'lrl1']
# [flaml.automl.logger: 01-12 02:25:03] {2218} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:03] {2344} INFO - Estimated sufficient time budget=12282s. Estimated necessary time budget=302s.
# [flaml.automl.logger: 01-12 02:25:03] {2391} INFO -  at 0.8s,	estimator lgbm's best error=0.1563,	best estimator lgbm's best error=0.1563
# [flaml.automl.logger: 01-12 02:25:03] {2218} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:04] {2391} INFO -  at 0.9s,	estimator lgbm's best error=0.1563,	best estimator lgbm's best error=0.1563
# [flaml.automl.logger: 01-12 02:25:04] {2218} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:04] {2391} INFO -  at 0.9s,	estimator lgbm's best error=0.1563,	best estimator lgbm's best error=0.1563
# [flaml.automl.logger: 01-12 02:25:04] {2218} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:04] {2391} INFO -  at 1.0s,	estimator lgbm's best error=0.1164,	best estimator lgbm's best error=0.1164
# [flaml.automl.logger: 01-12 02:25:04] {2218} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:04] {2391} INFO -  at 1.0s,	estimator lgbm's best error=0.1164,	best estimator lgbm's best error=0.1164
# [flaml.automl.logger: 01-12 02:25:04] {2218} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:04] {2391} INFO -  at 1.1s,	estimator lgbm's best error=0.1164,	best estimator lgbm's best error=0.1164
# [flaml.automl.logger: 01-12 02:25:04] {2218} INFO - iteration 6, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:04] {2391} INFO -  at 1.2s,	estimator lgbm's best error=0.1164,	best estimator lgbm's best error=0.1164
# [flaml.automl.logger: 01-12 02:25:04] {2218} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:04] {2391} INFO -  at 1.2s,	estimator lgbm's best error=0.1164,	best estimator lgbm's best error=0.1164
# [flaml.automl.logger: 01-12 02:25:04] {2218} INFO - iteration 8, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:04] {2391} INFO -  at 1.5s,	estimator lgbm's best error=0.1144,	best estimator lgbm's best error=0.1144
# [flaml.automl.logger: 01-12 02:25:04] {2218} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:04] {2391} INFO -  at 1.6s,	estimator xgboost's best error=0.1563,	best estimator lgbm's best error=0.1144
# [flaml.automl.logger: 01-12 02:25:04] {2218} INFO - iteration 10, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:04] {2391} INFO -  at 1.7s,	estimator xgboost's best error=0.1563,	best estimator lgbm's best error=0.1144
# [flaml.automl.logger: 01-12 02:25:04] {2218} INFO - iteration 11, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:04] {2391} INFO -  at 1.7s,	estimator xgboost's best error=0.1563,	best estimator lgbm's best error=0.1144
# [flaml.automl.logger: 01-12 02:25:04] {2218} INFO - iteration 12, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:04] {2391} INFO -  at 1.8s,	estimator xgboost's best error=0.1563,	best estimator lgbm's best error=0.1144
# [flaml.automl.logger: 01-12 02:25:04] {2218} INFO - iteration 13, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:04] {2391} INFO -  at 1.9s,	estimator xgboost's best error=0.1448,	best estimator lgbm's best error=0.1144
# [flaml.automl.logger: 01-12 02:25:04] {2218} INFO - iteration 14, current learner extra_tree
# [flaml.automl.logger: 01-12 02:25:05] {2391} INFO -  at 1.9s,	estimator extra_tree's best error=0.2082,	best estimator lgbm's best error=0.1144
# [flaml.automl.logger: 01-12 02:25:05] {2218} INFO - iteration 15, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:05] {2391} INFO -  at 2.0s,	estimator xgboost's best error=0.1371,	best estimator lgbm's best error=0.1144
# [flaml.automl.logger: 01-12 02:25:05] {2218} INFO - iteration 16, current learner extra_tree
# [flaml.automl.logger: 01-12 02:25:05] {2391} INFO -  at 2.2s,	estimator extra_tree's best error=0.1537,	best estimator lgbm's best error=0.1144
# [flaml.automl.logger: 01-12 02:25:05] {2218} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:05] {2391} INFO -  at 2.5s,	estimator lgbm's best error=0.1144,	best estimator lgbm's best error=0.1144
# [flaml.automl.logger: 01-12 02:25:05] {2218} INFO - iteration 18, current learner extra_tree
# [flaml.automl.logger: 01-12 02:25:05] {2391} INFO -  at 2.5s,	estimator extra_tree's best error=0.1537,	best estimator lgbm's best error=0.1144
# [flaml.automl.logger: 01-12 02:25:05] {2218} INFO - iteration 19, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:05] {2391} INFO -  at 2.6s,	estimator xgboost's best error=0.1053,	best estimator xgboost's best error=0.1053
# [flaml.automl.logger: 01-12 02:25:05] {2218} INFO - iteration 20, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:05] {2391} INFO -  at 2.7s,	estimator xgboost's best error=0.1027,	best estimator xgboost's best error=0.1027
# [flaml.automl.logger: 01-12 02:25:05] {2218} INFO - iteration 21, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:05] {2391} INFO -  at 2.8s,	estimator xgboost's best error=0.1023,	best estimator xgboost's best error=0.1023
# [flaml.automl.logger: 01-12 02:25:05] {2218} INFO - iteration 22, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:06] {2391} INFO -  at 2.9s,	estimator xgboost's best error=0.1023,	best estimator xgboost's best error=0.1023
# [flaml.automl.logger: 01-12 02:25:06] {2218} INFO - iteration 23, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:06] {2391} INFO -  at 3.0s,	estimator xgboost's best error=0.0747,	best estimator xgboost's best error=0.0747
# [flaml.automl.logger: 01-12 02:25:06] {2218} INFO - iteration 24, current learner extra_tree
# [flaml.automl.logger: 01-12 02:25:06] {2391} INFO -  at 3.1s,	estimator extra_tree's best error=0.1537,	best estimator xgboost's best error=0.0747
# [flaml.automl.logger: 01-12 02:25:06] {2218} INFO - iteration 25, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:06] {2391} INFO -  at 3.2s,	estimator xgboost's best error=0.0744,	best estimator xgboost's best error=0.0744
# [flaml.automl.logger: 01-12 02:25:06] {2218} INFO - iteration 26, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:06] {2391} INFO -  at 3.3s,	estimator xgboost's best error=0.0723,	best estimator xgboost's best error=0.0723
# [flaml.automl.logger: 01-12 02:25:06] {2218} INFO - iteration 27, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:06] {2391} INFO -  at 3.4s,	estimator xgboost's best error=0.0723,	best estimator xgboost's best error=0.0723
# [flaml.automl.logger: 01-12 02:25:06] {2218} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 01-12 02:25:06] {2391} INFO -  at 3.7s,	estimator extra_tree's best error=0.1257,	best estimator xgboost's best error=0.0723
# [flaml.automl.logger: 01-12 02:25:06] {2218} INFO - iteration 29, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:07] {2391} INFO -  at 3.9s,	estimator xgboost's best error=0.0617,	best estimator xgboost's best error=0.0617
# [flaml.automl.logger: 01-12 02:25:07] {2218} INFO - iteration 30, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:07] {2391} INFO -  at 4.0s,	estimator xgboost's best error=0.0617,	best estimator xgboost's best error=0.0617
# [flaml.automl.logger: 01-12 02:25:07] {2218} INFO - iteration 31, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:07] {2391} INFO -  at 4.3s,	estimator xgboost's best error=0.0617,	best estimator xgboost's best error=0.0617
# [flaml.automl.logger: 01-12 02:25:07] {2218} INFO - iteration 32, current learner extra_tree
# [flaml.automl.logger: 01-12 02:25:07] {2391} INFO -  at 4.5s,	estimator extra_tree's best error=0.1257,	best estimator xgboost's best error=0.0617
# [flaml.automl.logger: 01-12 02:25:07] {2218} INFO - iteration 33, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:08] {2391} INFO -  at 5.0s,	estimator xgboost's best error=0.0590,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:25:08] {2218} INFO - iteration 34, current learner rf
# [flaml.automl.logger: 01-12 02:25:08] {2391} INFO -  at 5.0s,	estimator rf's best error=0.1966,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:25:08] {2218} INFO - iteration 35, current learner rf
# [flaml.automl.logger: 01-12 02:25:08] {2391} INFO -  at 5.2s,	estimator rf's best error=0.1572,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:25:08] {2218} INFO - iteration 36, current learner extra_tree
# [flaml.automl.logger: 01-12 02:25:08] {2391} INFO -  at 5.6s,	estimator extra_tree's best error=0.1168,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:25:08] {2218} INFO - iteration 37, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:08] {2391} INFO -  at 5.8s,	estimator xgboost's best error=0.0590,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:25:08] {2218} INFO - iteration 38, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:09] {2391} INFO -  at 6.1s,	estimator xgboost's best error=0.0590,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:25:09] {2218} INFO - iteration 39, current learner rf
# [flaml.automl.logger: 01-12 02:25:09] {2391} INFO -  at 6.2s,	estimator rf's best error=0.1572,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:25:09] {2218} INFO - iteration 40, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:09] {2391} INFO -  at 6.7s,	estimator xgboost's best error=0.0590,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:25:09] {2218} INFO - iteration 41, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:10] {2391} INFO -  at 7.0s,	estimator xgboost's best error=0.0590,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:25:10] {2218} INFO - iteration 42, current learner rf
# [flaml.automl.logger: 01-12 02:25:10] {2391} INFO -  at 7.2s,	estimator rf's best error=0.1572,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:25:10] {2218} INFO - iteration 43, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:10] {2391} INFO -  at 7.5s,	estimator xgboost's best error=0.0590,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:25:10] {2218} INFO - iteration 44, current learner extra_tree
# [flaml.automl.logger: 01-12 02:25:10] {2391} INFO -  at 7.7s,	estimator extra_tree's best error=0.1168,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:25:10] {2218} INFO - iteration 45, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:10] {2391} INFO -  at 7.8s,	estimator xgboost's best error=0.0590,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:25:10] {2218} INFO - iteration 46, current learner rf
# [flaml.automl.logger: 01-12 02:25:11] {2391} INFO -  at 8.1s,	estimator rf's best error=0.1221,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:25:11] {2218} INFO - iteration 47, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:16] {2391} INFO -  at 13.7s,	estimator xgboost's best error=0.0590,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:25:16] {2218} INFO - iteration 48, current learner rf
# [flaml.automl.logger: 01-12 02:25:17] {2391} INFO -  at 14.0s,	estimator rf's best error=0.1221,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:25:17] {2218} INFO - iteration 49, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:18] {2391} INFO -  at 14.9s,	estimator xgboost's best error=0.0534,	best estimator xgboost's best error=0.0534
# [flaml.automl.logger: 01-12 02:25:18] {2218} INFO - iteration 50, current learner extra_tree
# [flaml.automl.logger: 01-12 02:25:18] {2391} INFO -  at 15.6s,	estimator extra_tree's best error=0.1168,	best estimator xgboost's best error=0.0534
# [flaml.automl.logger: 01-12 02:25:18] {2218} INFO - iteration 51, current learner rf
# [flaml.automl.logger: 01-12 02:25:19] {2391} INFO -  at 16.1s,	estimator rf's best error=0.1218,	best estimator xgboost's best error=0.0534
# [flaml.automl.logger: 01-12 02:25:19] {2218} INFO - iteration 52, current learner catboost
# [flaml.automl.logger: 01-12 02:25:20] {2391} INFO -  at 17.1s,	estimator catboost's best error=0.0586,	best estimator xgboost's best error=0.0534
# [flaml.automl.logger: 01-12 02:25:20] {2218} INFO - iteration 53, current learner catboost
# [flaml.automl.logger: 01-12 02:25:21] {2391} INFO -  at 17.9s,	estimator catboost's best error=0.0586,	best estimator xgboost's best error=0.0534
# [flaml.automl.logger: 01-12 02:25:21] {2218} INFO - iteration 54, current learner catboost
# [flaml.automl.logger: 01-12 02:25:22] {2391} INFO -  at 19.0s,	estimator catboost's best error=0.0586,	best estimator xgboost's best error=0.0534
# [flaml.automl.logger: 01-12 02:25:22] {2218} INFO - iteration 55, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:22] {2391} INFO -  at 19.2s,	estimator lgbm's best error=0.0985,	best estimator xgboost's best error=0.0534
# [flaml.automl.logger: 01-12 02:25:22] {2218} INFO - iteration 56, current learner catboost
# [flaml.automl.logger: 01-12 02:25:23] {2391} INFO -  at 20.8s,	estimator catboost's best error=0.0560,	best estimator xgboost's best error=0.0534
# [flaml.automl.logger: 01-12 02:25:23] {2218} INFO - iteration 57, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:24] {2391} INFO -  at 21.0s,	estimator lgbm's best error=0.0985,	best estimator xgboost's best error=0.0534
# [flaml.automl.logger: 01-12 02:25:24] {2218} INFO - iteration 58, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:24] {2391} INFO -  at 21.7s,	estimator lgbm's best error=0.0788,	best estimator xgboost's best error=0.0534
# [flaml.automl.logger: 01-12 02:25:24] {2218} INFO - iteration 59, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:25] {2391} INFO -  at 22.1s,	estimator lgbm's best error=0.0788,	best estimator xgboost's best error=0.0534
# [flaml.automl.logger: 01-12 02:25:25] {2218} INFO - iteration 60, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:25] {2391} INFO -  at 22.4s,	estimator lgbm's best error=0.0646,	best estimator xgboost's best error=0.0534
# [flaml.automl.logger: 01-12 02:25:25] {2218} INFO - iteration 61, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:30] {2391} INFO -  at 27.6s,	estimator lgbm's best error=0.0516,	best estimator lgbm's best error=0.0516
# [flaml.automl.logger: 01-12 02:25:30] {2218} INFO - iteration 62, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:30] {2391} INFO -  at 27.8s,	estimator lgbm's best error=0.0516,	best estimator lgbm's best error=0.0516
# [flaml.automl.logger: 01-12 02:25:30] {2218} INFO - iteration 63, current learner catboost
# [flaml.automl.logger: 01-12 02:25:32] {2391} INFO -  at 29.2s,	estimator catboost's best error=0.0560,	best estimator lgbm's best error=0.0516
# [flaml.automl.logger: 01-12 02:25:32] {2218} INFO - iteration 64, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:33] {2391} INFO -  at 30.5s,	estimator xgboost's best error=0.0468,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 02:25:33] {2218} INFO - iteration 65, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:34] {2391} INFO -  at 31.1s,	estimator lgbm's best error=0.0480,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 02:25:34] {2218} INFO - iteration 66, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:34] {2391} INFO -  at 31.6s,	estimator lgbm's best error=0.0480,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 02:25:34] {2218} INFO - iteration 67, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:35] {2391} INFO -  at 32.5s,	estimator xgboost's best error=0.0468,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 02:25:35] {2218} INFO - iteration 68, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:38] {2391} INFO -  at 35.0s,	estimator lgbm's best error=0.0472,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 02:25:38] {2218} INFO - iteration 69, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:38] {2391} INFO -  at 35.7s,	estimator lgbm's best error=0.0472,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 02:25:38] {2218} INFO - iteration 70, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:39] {2391} INFO -  at 36.3s,	estimator xgboost's best error=0.0468,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 02:25:39] {2218} INFO - iteration 71, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:46] {2391} INFO -  at 43.6s,	estimator xgboost's best error=0.0468,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 02:25:46] {2218} INFO - iteration 72, current learner lgbm
# [flaml.automl.logger: 01-12 02:25:47] {2391} INFO -  at 44.6s,	estimator lgbm's best error=0.0472,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 02:25:47] {2218} INFO - iteration 73, current learner extra_tree
# [flaml.automl.logger: 01-12 02:25:48] {2391} INFO -  at 45.1s,	estimator extra_tree's best error=0.1168,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 02:25:48] {2218} INFO - iteration 74, current learner catboost
# [flaml.automl.logger: 01-12 02:25:50] {2391} INFO -  at 47.0s,	estimator catboost's best error=0.0560,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 02:25:50] {2218} INFO - iteration 75, current learner xgboost
# [flaml.automl.logger: 01-12 02:25:52] {2391} INFO -  at 49.2s,	estimator xgboost's best error=0.0468,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 02:25:52] {2218} INFO - iteration 76, current learner lgbm
# [flaml.automl.logger: 01-12 02:26:00] {2391} INFO -  at 57.8s,	estimator lgbm's best error=0.0469,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 02:26:00] {2218} INFO - iteration 77, current learner lgbm
# [flaml.automl.logger: 01-12 02:26:02] {2391} INFO -  at 59.3s,	estimator lgbm's best error=0.0469,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 02:26:02] {2218} INFO - iteration 78, current learner xgboost
# [flaml.automl.logger: 01-12 02:26:03] {2391} INFO -  at 60.1s,	estimator xgboost's best error=0.0468,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 02:26:03] {2218} INFO - iteration 79, current learner catboost
# [flaml.automl.logger: 01-12 02:26:04] {2391} INFO -  at 61.4s,	estimator catboost's best error=0.0560,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 02:26:04] {2218} INFO - iteration 80, current learner lgbm
# [flaml.automl.logger: 01-12 02:26:19] {2391} INFO -  at 76.4s,	estimator lgbm's best error=0.0437,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:26:19] {2218} INFO - iteration 81, current learner extra_tree
# [flaml.automl.logger: 01-12 02:26:19] {2391} INFO -  at 76.6s,	estimator extra_tree's best error=0.1168,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:26:19] {2218} INFO - iteration 82, current learner catboost
# [flaml.automl.logger: 01-12 02:26:22] {2391} INFO -  at 79.1s,	estimator catboost's best error=0.0560,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:26:22] {2218} INFO - iteration 83, current learner xgboost
# [flaml.automl.logger: 01-12 02:26:29] {2391} INFO -  at 86.3s,	estimator xgboost's best error=0.0448,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:26:29] {2218} INFO - iteration 84, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:26:29] {2391} INFO -  at 86.4s,	estimator xgb_limitdepth's best error=0.0791,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:26:29] {2218} INFO - iteration 85, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:26:29] {2391} INFO -  at 86.5s,	estimator xgb_limitdepth's best error=0.0648,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:26:29] {2218} INFO - iteration 86, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:26:29] {2391} INFO -  at 86.6s,	estimator xgb_limitdepth's best error=0.0648,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:26:29] {2218} INFO - iteration 87, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:26:30] {2391} INFO -  at 87.1s,	estimator xgb_limitdepth's best error=0.0567,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:26:30] {2218} INFO - iteration 88, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:26:30] {2391} INFO -  at 87.2s,	estimator xgb_limitdepth's best error=0.0567,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:26:30] {2218} INFO - iteration 89, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:26:30] {2391} INFO -  at 87.5s,	estimator xgb_limitdepth's best error=0.0567,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:26:30] {2218} INFO - iteration 90, current learner extra_tree
# [flaml.automl.logger: 01-12 02:26:31] {2391} INFO -  at 88.8s,	estimator extra_tree's best error=0.1168,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:26:31] {2218} INFO - iteration 91, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:26:32] {2391} INFO -  at 89.4s,	estimator xgb_limitdepth's best error=0.0567,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:26:32] {2218} INFO - iteration 92, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:26:33] {2391} INFO -  at 90.5s,	estimator xgb_limitdepth's best error=0.0567,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:26:33] {2218} INFO - iteration 93, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:26:34] {2391} INFO -  at 91.8s,	estimator xgb_limitdepth's best error=0.0501,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:26:34] {2218} INFO - iteration 94, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:26:35] {2391} INFO -  at 92.7s,	estimator xgb_limitdepth's best error=0.0501,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:26:35] {2218} INFO - iteration 95, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:26:38] {2391} INFO -  at 94.9s,	estimator xgb_limitdepth's best error=0.0463,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:26:38] {2218} INFO - iteration 96, current learner lgbm
# [flaml.automl.logger: 01-12 02:27:36] {2391} INFO -  at 152.9s,	estimator lgbm's best error=0.0437,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:27:36] {2218} INFO - iteration 97, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:27:42] {2391} INFO -  at 158.9s,	estimator xgb_limitdepth's best error=0.0463,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:27:42] {2218} INFO - iteration 98, current learner extra_tree
# [flaml.automl.logger: 01-12 02:27:42] {2391} INFO -  at 159.8s,	estimator extra_tree's best error=0.1095,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:27:42] {2218} INFO - iteration 99, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:27:44] {2391} INFO -  at 161.9s,	estimator xgb_limitdepth's best error=0.0463,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:27:44] {2218} INFO - iteration 100, current learner xgboost
# [flaml.automl.logger: 01-12 02:27:46] {2391} INFO -  at 163.1s,	estimator xgboost's best error=0.0448,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:27:46] {2218} INFO - iteration 101, current learner xgboost
# [flaml.automl.logger: 01-12 02:27:46] {2391} INFO -  at 163.7s,	estimator xgboost's best error=0.0448,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:27:46] {2218} INFO - iteration 102, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:27:48] {2391} INFO -  at 165.0s,	estimator xgb_limitdepth's best error=0.0463,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:27:48] {2218} INFO - iteration 103, current learner extra_tree
# [flaml.automl.logger: 01-12 02:27:49] {2391} INFO -  at 166.2s,	estimator extra_tree's best error=0.1095,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:27:49] {2218} INFO - iteration 104, current learner lgbm
# [flaml.automl.logger: 01-12 02:27:57] {2391} INFO -  at 174.2s,	estimator lgbm's best error=0.0437,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:27:57] {2218} INFO - iteration 105, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:28:01] {2391} INFO -  at 178.2s,	estimator xgb_limitdepth's best error=0.0463,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:28:01] {2218} INFO - iteration 106, current learner xgboost
# [flaml.automl.logger: 01-12 02:28:15] {2391} INFO -  at 192.3s,	estimator xgboost's best error=0.0448,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:28:15] {2218} INFO - iteration 107, current learner extra_tree
# [flaml.automl.logger: 01-12 02:28:15] {2391} INFO -  at 192.8s,	estimator extra_tree's best error=0.1018,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:28:15] {2218} INFO - iteration 108, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:28:17] {2391} INFO -  at 194.0s,	estimator xgb_limitdepth's best error=0.0463,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:28:17] {2218} INFO - iteration 109, current learner xgboost
# [flaml.automl.logger: 01-12 02:28:18] {2391} INFO -  at 195.6s,	estimator xgboost's best error=0.0448,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:28:18] {2218} INFO - iteration 110, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:28:26] {2391} INFO -  at 203.8s,	estimator xgb_limitdepth's best error=0.0463,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:28:26] {2218} INFO - iteration 111, current learner extra_tree
# [flaml.automl.logger: 01-12 02:28:27] {2391} INFO -  at 204.7s,	estimator extra_tree's best error=0.1018,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:28:27] {2218} INFO - iteration 112, current learner lrl1
# INFO:flaml.tune.searcher.blendsearch:No low-cost partial config given to the search algorithm. For cost-frugal search, consider providing low-cost values for cost-related hps via 'low_cost_partial_config'. More info can be found at https://microsoft.github.io/FLAML/docs/FAQ#about-low_cost_partial_config-in-tune
# [flaml.automl.logger: 01-12 02:28:28] {2391} INFO -  at 205.3s,	estimator lrl1's best error=0.4138,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:28:28] {2218} INFO - iteration 113, current learner rf
# [flaml.automl.logger: 01-12 02:28:28] {2391} INFO -  at 205.6s,	estimator rf's best error=0.1218,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:28:28] {2218} INFO - iteration 114, current learner lrl1
# [flaml.automl.logger: 01-12 02:28:29] {2391} INFO -  at 206.2s,	estimator lrl1's best error=0.4138,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:28:29] {2218} INFO - iteration 115, current learner lrl1
# [flaml.automl.logger: 01-12 02:28:30] {2391} INFO -  at 206.9s,	estimator lrl1's best error=0.4138,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:28:30] {2218} INFO - iteration 116, current learner lrl1
# [flaml.automl.logger: 01-12 02:28:34] {2391} INFO -  at 211.7s,	estimator lrl1's best error=0.3436,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:28:34] {2218} INFO - iteration 117, current learner catboost
# [flaml.automl.logger: 01-12 02:28:45] {2391} INFO -  at 222.1s,	estimator catboost's best error=0.0496,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:28:45] {2218} INFO - iteration 118, current learner catboost
# [flaml.automl.logger: 01-12 02:28:48] {2391} INFO -  at 225.5s,	estimator catboost's best error=0.0481,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:28:48] {2218} INFO - iteration 119, current learner lrl1
# [flaml.automl.logger: 01-12 02:28:55] {2391} INFO -  at 232.6s,	estimator lrl1's best error=0.3436,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:28:55] {2218} INFO - iteration 120, current learner extra_tree
# [flaml.automl.logger: 01-12 02:28:56] {2391} INFO -  at 233.0s,	estimator extra_tree's best error=0.1018,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:28:56] {2218} INFO - iteration 121, current learner lgbm
# [flaml.automl.logger: 01-12 02:29:01] {2391} INFO -  at 238.8s,	estimator lgbm's best error=0.0437,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:29:01] {2218} INFO - iteration 122, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:29:15] {2391} INFO -  at 252.6s,	estimator xgb_limitdepth's best error=0.0463,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:29:15] {2218} INFO - iteration 123, current learner extra_tree
# [flaml.automl.logger: 01-12 02:29:16] {2391} INFO -  at 253.3s,	estimator extra_tree's best error=0.0872,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:29:16] {2218} INFO - iteration 124, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:29:17] {2391} INFO -  at 254.0s,	estimator xgb_limitdepth's best error=0.0463,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:29:17] {2218} INFO - iteration 125, current learner extra_tree
# [flaml.automl.logger: 01-12 02:29:18] {2391} INFO -  at 255.5s,	estimator extra_tree's best error=0.0872,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:29:18] {2218} INFO - iteration 126, current learner catboost
# [flaml.automl.logger: 01-12 02:29:29] {2391} INFO -  at 266.3s,	estimator catboost's best error=0.0481,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:29:29] {2218} INFO - iteration 127, current learner lgbm
# [flaml.automl.logger: 01-12 02:29:56] {2391} INFO -  at 293.2s,	estimator lgbm's best error=0.0437,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:29:56] {2218} INFO - iteration 128, current learner lgbm
# [flaml.automl.logger: 01-12 02:30:00] {2391} INFO -  at 297.9s,	estimator lgbm's best error=0.0437,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:30:00] {2218} INFO - iteration 129, current learner lgbm
# [flaml.automl.logger: 01-12 02:30:19] {2391} INFO -  at 316.4s,	estimator lgbm's best error=0.0437,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:30:19] {2218} INFO - iteration 130, current learner xgboost
# [flaml.automl.logger: 01-12 02:30:28] {2391} INFO -  at 325.4s,	estimator xgboost's best error=0.0448,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:30:28] {2218} INFO - iteration 131, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:30:29] {2391} INFO -  at 326.9s,	estimator xgb_limitdepth's best error=0.0463,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:30:29] {2218} INFO - iteration 132, current learner extra_tree
# [flaml.automl.logger: 01-12 02:30:30] {2391} INFO -  at 327.4s,	estimator extra_tree's best error=0.0784,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:30:30] {2218} INFO - iteration 133, current learner extra_tree
# [flaml.automl.logger: 01-12 02:30:30] {2391} INFO -  at 327.8s,	estimator extra_tree's best error=0.0784,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:30:30] {2218} INFO - iteration 134, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:30:35] {2391} INFO -  at 332.7s,	estimator xgb_limitdepth's best error=0.0460,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:30:35] {2218} INFO - iteration 135, current learner catboost
# [flaml.automl.logger: 01-12 02:30:39] {2391} INFO -  at 336.8s,	estimator catboost's best error=0.0481,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:30:39] {2218} INFO - iteration 136, current learner xgboost
# [flaml.automl.logger: 01-12 02:30:40] {2391} INFO -  at 337.8s,	estimator xgboost's best error=0.0448,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:30:40] {2218} INFO - iteration 137, current learner extra_tree
# [flaml.automl.logger: 01-12 02:30:41] {2391} INFO -  at 338.7s,	estimator extra_tree's best error=0.0620,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:30:41] {2218} INFO - iteration 138, current learner extra_tree
# [flaml.automl.logger: 01-12 02:30:42] {2391} INFO -  at 339.3s,	estimator extra_tree's best error=0.0620,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:30:42] {2218} INFO - iteration 139, current learner extra_tree
# [flaml.automl.logger: 01-12 02:30:43] {2391} INFO -  at 340.5s,	estimator extra_tree's best error=0.0587,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:30:43] {2218} INFO - iteration 140, current learner lgbm
# [flaml.automl.logger: 01-12 02:30:48] {2391} INFO -  at 345.4s,	estimator lgbm's best error=0.0437,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:30:48] {2218} INFO - iteration 141, current learner extra_tree
# [flaml.automl.logger: 01-12 02:30:52] {2391} INFO -  at 349.7s,	estimator extra_tree's best error=0.0521,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:30:52] {2218} INFO - iteration 142, current learner xgboost
# [flaml.automl.logger: 01-12 02:30:58] {2391} INFO -  at 355.0s,	estimator xgboost's best error=0.0448,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:30:58] {2218} INFO - iteration 143, current learner extra_tree
# [flaml.automl.logger: 01-12 02:30:59] {2391} INFO -  at 356.2s,	estimator extra_tree's best error=0.0521,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:30:59] {2218} INFO - iteration 144, current learner extra_tree
# [flaml.automl.logger: 01-12 02:31:01] {2391} INFO -  at 358.1s,	estimator extra_tree's best error=0.0521,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:31:01] {2218} INFO - iteration 145, current learner extra_tree
# [flaml.automl.logger: 01-12 02:31:04] {2391} INFO -  at 361.1s,	estimator extra_tree's best error=0.0490,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:31:04] {2218} INFO - iteration 146, current learner extra_tree
# [flaml.automl.logger: 01-12 02:31:07] {2391} INFO -  at 364.7s,	estimator extra_tree's best error=0.0490,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:31:07] {2218} INFO - iteration 147, current learner extra_tree
# [flaml.automl.logger: 01-12 02:31:12] {2391} INFO -  at 369.9s,	estimator extra_tree's best error=0.0486,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:31:13] {2218} INFO - iteration 148, current learner lgbm
# [flaml.automl.logger: 01-12 02:31:45] {2391} INFO -  at 402.4s,	estimator lgbm's best error=0.0437,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:31:45] {2218} INFO - iteration 149, current learner lgbm
# [flaml.automl.logger: 01-12 02:32:15] {2391} INFO -  at 432.0s,	estimator lgbm's best error=0.0437,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:32:15] {2218} INFO - iteration 150, current learner rf
# [flaml.automl.logger: 01-12 02:32:16] {2391} INFO -  at 433.0s,	estimator rf's best error=0.1182,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:32:16] {2218} INFO - iteration 151, current learner lgbm
# [flaml.automl.logger: 01-12 02:32:28] {2391} INFO -  at 445.5s,	estimator lgbm's best error=0.0437,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:32:28] {2218} INFO - iteration 152, current learner rf
# [flaml.automl.logger: 01-12 02:32:30] {2391} INFO -  at 447.3s,	estimator rf's best error=0.1182,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:32:30] {2218} INFO - iteration 153, current learner rf
# [flaml.automl.logger: 01-12 02:32:31] {2391} INFO -  at 448.0s,	estimator rf's best error=0.1147,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:32:31] {2218} INFO - iteration 154, current learner xgboost
# [flaml.automl.logger: 01-12 02:32:39] {2391} INFO -  at 455.9s,	estimator xgboost's best error=0.0448,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:32:39] {2218} INFO - iteration 155, current learner xgboost
# [flaml.automl.logger: 01-12 02:32:40] {2391} INFO -  at 457.5s,	estimator xgboost's best error=0.0448,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:32:40] {2218} INFO - iteration 156, current learner lgbm
# [flaml.automl.logger: 01-12 02:33:11] {2391} INFO -  at 488.8s,	estimator lgbm's best error=0.0437,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:33:11] {2218} INFO - iteration 157, current learner lgbm
# [flaml.automl.logger: 01-12 02:33:15] {2391} INFO -  at 492.1s,	estimator lgbm's best error=0.0437,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:33:15] {2218} INFO - iteration 158, current learner lrl1
# [flaml.automl.logger: 01-12 02:33:21] {2391} INFO -  at 498.7s,	estimator lrl1's best error=0.3436,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:33:21] {2218} INFO - iteration 159, current learner xgboost
# [flaml.automl.logger: 01-12 02:33:24] {2391} INFO -  at 501.7s,	estimator xgboost's best error=0.0448,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:33:24] {2218} INFO - iteration 160, current learner rf
# [flaml.automl.logger: 01-12 02:33:25] {2391} INFO -  at 502.1s,	estimator rf's best error=0.1043,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:33:25] {2218} INFO - iteration 161, current learner rf
# [flaml.automl.logger: 01-12 02:33:26] {2391} INFO -  at 502.9s,	estimator rf's best error=0.1043,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:33:26] {2218} INFO - iteration 162, current learner catboost
# [flaml.automl.logger: 01-12 02:33:30] {2391} INFO -  at 507.3s,	estimator catboost's best error=0.0471,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:33:30] {2218} INFO - iteration 163, current learner rf
# [flaml.automl.logger: 01-12 02:33:30] {2391} INFO -  at 507.6s,	estimator rf's best error=0.0982,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:33:30] {2218} INFO - iteration 164, current learner rf
# [flaml.automl.logger: 01-12 02:33:31] {2391} INFO -  at 508.1s,	estimator rf's best error=0.0970,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:33:31] {2218} INFO - iteration 165, current learner lrl1
# [flaml.automl.logger: 01-12 02:33:37] {2391} INFO -  at 514.9s,	estimator lrl1's best error=0.3436,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:33:38] {2218} INFO - iteration 166, current learner extra_tree
# [flaml.automl.logger: 01-12 02:33:52] {2391} INFO -  at 529.7s,	estimator extra_tree's best error=0.0484,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:33:52] {2218} INFO - iteration 167, current learner rf
# [flaml.automl.logger: 01-12 02:33:53] {2391} INFO -  at 530.1s,	estimator rf's best error=0.0970,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:33:53] {2218} INFO - iteration 168, current learner catboost
# [flaml.automl.logger: 01-12 02:33:56] {2391} INFO -  at 533.2s,	estimator catboost's best error=0.0471,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:33:56] {2218} INFO - iteration 169, current learner xgboost
# [flaml.automl.logger: 01-12 02:33:58] {2391} INFO -  at 535.6s,	estimator xgboost's best error=0.0448,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:33:58] {2218} INFO - iteration 170, current learner xgboost
# [flaml.automl.logger: 01-12 02:34:01] {2391} INFO -  at 538.5s,	estimator xgboost's best error=0.0448,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:34:01] {2218} INFO - iteration 171, current learner rf
# [flaml.automl.logger: 01-12 02:34:02] {2391} INFO -  at 539.1s,	estimator rf's best error=0.0837,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:34:02] {2218} INFO - iteration 172, current learner lgbm
# [flaml.automl.logger: 01-12 02:34:09] {2391} INFO -  at 546.3s,	estimator lgbm's best error=0.0437,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:34:09] {2218} INFO - iteration 173, current learner rf
# [flaml.automl.logger: 01-12 02:34:10] {2391} INFO -  at 547.3s,	estimator rf's best error=0.0837,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:34:10] {2218} INFO - iteration 174, current learner rf
# [flaml.automl.logger: 01-12 02:34:10] {2391} INFO -  at 547.6s,	estimator rf's best error=0.0837,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:34:10] {2218} INFO - iteration 175, current learner rf
# [flaml.automl.logger: 01-12 02:34:11] {2391} INFO -  at 547.9s,	estimator rf's best error=0.0837,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:34:11] {2218} INFO - iteration 176, current learner rf
# [flaml.automl.logger: 01-12 02:34:11] {2391} INFO -  at 548.8s,	estimator rf's best error=0.0758,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:34:11] {2218} INFO - iteration 177, current learner rf
# [flaml.automl.logger: 01-12 02:34:12] {2391} INFO -  at 549.3s,	estimator rf's best error=0.0758,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:34:12] {2218} INFO - iteration 178, current learner lrl1
# [flaml.automl.logger: 01-12 02:34:17] {2391} INFO -  at 553.9s,	estimator lrl1's best error=0.3436,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:34:17] {2218} INFO - iteration 179, current learner rf
# [flaml.automl.logger: 01-12 02:34:19] {2391} INFO -  at 555.9s,	estimator rf's best error=0.0746,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:34:19] {2218} INFO - iteration 180, current learner catboost
# [flaml.automl.logger: 01-12 02:34:27] {2391} INFO -  at 564.5s,	estimator catboost's best error=0.0471,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:34:27] {2218} INFO - iteration 181, current learner xgboost
# [flaml.automl.logger: 01-12 02:34:29] {2391} INFO -  at 566.3s,	estimator xgboost's best error=0.0448,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:34:29] {2218} INFO - iteration 182, current learner xgboost
# [flaml.automl.logger: 01-12 02:34:31] {2391} INFO -  at 568.8s,	estimator xgboost's best error=0.0448,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:34:31] {2218} INFO - iteration 183, current learner xgboost
# [flaml.automl.logger: 01-12 02:34:38] {2391} INFO -  at 575.8s,	estimator xgboost's best error=0.0448,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:34:38] {2218} INFO - iteration 184, current learner rf
# [flaml.automl.logger: 01-12 02:34:41] {2391} INFO -  at 578.6s,	estimator rf's best error=0.0726,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:34:41] {2218} INFO - iteration 185, current learner lgbm
# [flaml.automl.logger: 01-12 02:35:06] {2391} INFO -  at 603.7s,	estimator lgbm's best error=0.0437,	best estimator lgbm's best error=0.0437
# [flaml.automl.logger: 01-12 02:35:23] {2627} INFO - retrain lgbm for 16.2s
# [flaml.automl.logger: 01-12 02:35:23] {2630} INFO - retrained model: LGBMClassifier(colsample_bytree=0.7474731186737704,
#                learning_rate=0.6810175093276573, max_bin=127,
#                min_child_samples=26, n_estimators=1, n_jobs=-1, num_leaves=3341,
#                reg_alpha=0.0026114080577972036, reg_lambda=0.4440306981875064,
#                verbose=-1)
# [flaml.automl.logger: 01-12 02:35:23] {1930} INFO - fit succeeded
# [flaml.automl.logger: 01-12 02:35:23] {1931} INFO - Time taken to find the best model: 76.38804411888123

# %%
# retrieve best config and best learner
print('Best ML leaner:', automl1.best_estimator)
print('Best hyperparmeter config:', automl1.best_config)
print('Best accuracy on validation data: {0:.4g}'.format(1-automl1.best_loss))
print('Training duration of best run: {0:.4g} s'.format(automl1.best_config_train_time))
# Out:
# Best ML leaner: lgbm
# Best hyperparmeter config: {'n_estimators': 489, 'num_leaves': 3341, 'min_child_samples': 26, 'learning_rate': 0.6810175093276573, 'log_max_bin': 7, 'colsample_bytree': 0.7474731186737704, 'reg_alpha': 0.0026114080577972036, 'reg_lambda': 0.4440306981875064}
# Best accuracy on validation data: 0.9563
# Training duration of best run: 16.24 s

# %%
# obtain best model
automl1.model.estimator
# Out:
# LGBMClassifier(colsample_bytree=0.7474731186737704,
#                learning_rate=0.6810175093276573, max_bin=127,
#                min_child_samples=26, n_estimators=1, n_jobs=-1, num_leaves=3341,
#                reg_alpha=0.0026114080577972036, reg_lambda=0.4440306981875064,
#                verbose=-1)

# %% [markdown]
# ##### Predict for train data using CV

# %%
# compute predictions of testing dataset'''
y_pred1 = automl1.predict(X_test)
y_pred_proba1 = automl1.predict_proba(X_test)[:,1]

# %%
# compute different metric values on testing dataset'''
from flaml.ml import sklearn_metric_loss_score
print('accuracy', '=', 1 - sklearn_metric_loss_score('accuracy', y_pred1, y_test))
print('roc_auc', '=', 1 - sklearn_metric_loss_score('roc_auc', y_pred_proba1, y_test))
print('log_loss', '=', sklearn_metric_loss_score('log_loss', y_pred_proba1, y_test))
# Out:
# accuracy = 0.9539450448541358
# roc_auc = 0.9924621781639097
# log_loss = 0.1903503946566573

# %%
predict(automl1, 'automl1', pred_x)

# %% [markdown]
# #### **Model 2: Unscaled imputed data, KNNImputer, all original columns for stacked model - ensemble**

# %%
train_x = X_train_imputed.copy()

test_x = X_test_imputed.copy()

pred_x = pd.concat([df_pred_orig['ID'], df_pred_imputed.copy()], axis = 1)

# %%
# declare model for logistic regression
automl2 = AutoML()

# setting for AutoML
settings = {
    "time_budget": 600,  # total running time in seconds
    "metric": 'accuracy',
    # check the documentation for options of metrics (https://microsoft.github.io/FLAML/docs/Use-Cases/Task-Oriented-AutoML#optimization-metric)
    "task": 'classification',  # task type
    "estimator_list": ['xgboost', 'xgb_limitdepth', 'rf', 'lgbm', 'lrl1', 'lrl2', 'catboost', 'extra_tree', 'kneighbor'],
    "log_file_name": '/content/drive/MyDrive/DScourse/Hackathon/AutoML/hackathon1.log',  # flaml log file
    "ensemble": True,
    "seed": 13,    # random seed
}

# %%
# The main flaml automl API
automl2.fit(X_train=train_x, y_train=y_train, **settings)
# Out:
# [flaml.automl.logger: 01-12 02:50:23] {1679} INFO - task = classification
# [flaml.automl.logger: 01-12 02:50:23] {1690} INFO - Evaluation method: holdout
# [flaml.automl.logger: 01-12 02:50:23] {1788} INFO - Minimizing error metric: 1-accuracy
# [flaml.automl.logger: 01-12 02:50:23] {1900} INFO - List of ML learners in AutoML Run: ['xgboost', 'xgb_limitdepth', 'rf', 'lgbm', 'lrl1', 'lrl2', 'catboost', 'extra_tree', 'kneighbor']
# [flaml.automl.logger: 01-12 02:50:23] {2218} INFO - iteration 0, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:23] {2344} INFO - Estimated sufficient time budget=10036s. Estimated necessary time budget=188s.
# [flaml.automl.logger: 01-12 02:50:23] {2391} INFO -  at 1.2s,	estimator xgboost's best error=0.1563,	best estimator xgboost's best error=0.1563
# [flaml.automl.logger: 01-12 02:50:23] {2218} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:23] {2391} INFO -  at 1.4s,	estimator lgbm's best error=0.1563,	best estimator xgboost's best error=0.1563
# [flaml.automl.logger: 01-12 02:50:23] {2218} INFO - iteration 2, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:23] {2391} INFO -  at 1.5s,	estimator xgboost's best error=0.1563,	best estimator xgboost's best error=0.1563
# [flaml.automl.logger: 01-12 02:50:23] {2218} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:23] {2391} INFO -  at 1.5s,	estimator lgbm's best error=0.1563,	best estimator xgboost's best error=0.1563
# [flaml.automl.logger: 01-12 02:50:23] {2218} INFO - iteration 4, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:23] {2391} INFO -  at 1.6s,	estimator xgboost's best error=0.1563,	best estimator xgboost's best error=0.1563
# [flaml.automl.logger: 01-12 02:50:23] {2218} INFO - iteration 5, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:24] {2391} INFO -  at 1.7s,	estimator xgboost's best error=0.1563,	best estimator xgboost's best error=0.1563
# [flaml.automl.logger: 01-12 02:50:24] {2218} INFO - iteration 6, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:24] {2391} INFO -  at 1.7s,	estimator xgboost's best error=0.1448,	best estimator xgboost's best error=0.1448
# [flaml.automl.logger: 01-12 02:50:24] {2218} INFO - iteration 7, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:24] {2391} INFO -  at 1.8s,	estimator xgboost's best error=0.1371,	best estimator xgboost's best error=0.1371
# [flaml.automl.logger: 01-12 02:50:24] {2218} INFO - iteration 8, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:24] {2391} INFO -  at 1.9s,	estimator xgboost's best error=0.1053,	best estimator xgboost's best error=0.1053
# [flaml.automl.logger: 01-12 02:50:24] {2218} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:24] {2391} INFO -  at 1.9s,	estimator xgboost's best error=0.1027,	best estimator xgboost's best error=0.1027
# [flaml.automl.logger: 01-12 02:50:24] {2218} INFO - iteration 10, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:24] {2391} INFO -  at 2.0s,	estimator xgboost's best error=0.1023,	best estimator xgboost's best error=0.1023
# [flaml.automl.logger: 01-12 02:50:24] {2218} INFO - iteration 11, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:24] {2391} INFO -  at 2.1s,	estimator xgboost's best error=0.1023,	best estimator xgboost's best error=0.1023
# [flaml.automl.logger: 01-12 02:50:24] {2218} INFO - iteration 12, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:24] {2391} INFO -  at 2.2s,	estimator xgboost's best error=0.0747,	best estimator xgboost's best error=0.0747
# [flaml.automl.logger: 01-12 02:50:24] {2218} INFO - iteration 13, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:24] {2391} INFO -  at 2.2s,	estimator lgbm's best error=0.1563,	best estimator xgboost's best error=0.0747
# [flaml.automl.logger: 01-12 02:50:24] {2218} INFO - iteration 14, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:24] {2391} INFO -  at 2.3s,	estimator xgboost's best error=0.0744,	best estimator xgboost's best error=0.0744
# [flaml.automl.logger: 01-12 02:50:24] {2218} INFO - iteration 15, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:24] {2391} INFO -  at 2.4s,	estimator lgbm's best error=0.1164,	best estimator xgboost's best error=0.0744
# [flaml.automl.logger: 01-12 02:50:24] {2218} INFO - iteration 16, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:24] {2391} INFO -  at 2.5s,	estimator xgboost's best error=0.0723,	best estimator xgboost's best error=0.0723
# [flaml.automl.logger: 01-12 02:50:24] {2218} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:24] {2391} INFO -  at 2.6s,	estimator lgbm's best error=0.1164,	best estimator xgboost's best error=0.0723
# [flaml.automl.logger: 01-12 02:50:24] {2218} INFO - iteration 18, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:25] {2391} INFO -  at 2.6s,	estimator xgboost's best error=0.0723,	best estimator xgboost's best error=0.0723
# [flaml.automl.logger: 01-12 02:50:25] {2218} INFO - iteration 19, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:25] {2391} INFO -  at 2.9s,	estimator xgboost's best error=0.0617,	best estimator xgboost's best error=0.0617
# [flaml.automl.logger: 01-12 02:50:25] {2218} INFO - iteration 20, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:25] {2391} INFO -  at 3.0s,	estimator xgboost's best error=0.0617,	best estimator xgboost's best error=0.0617
# [flaml.automl.logger: 01-12 02:50:25] {2218} INFO - iteration 21, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:25] {2391} INFO -  at 3.3s,	estimator xgboost's best error=0.0617,	best estimator xgboost's best error=0.0617
# [flaml.automl.logger: 01-12 02:50:25] {2218} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:25] {2391} INFO -  at 3.3s,	estimator lgbm's best error=0.1164,	best estimator xgboost's best error=0.0617
# [flaml.automl.logger: 01-12 02:50:25] {2218} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:25] {2391} INFO -  at 3.4s,	estimator lgbm's best error=0.1164,	best estimator xgboost's best error=0.0617
# [flaml.automl.logger: 01-12 02:50:25] {2218} INFO - iteration 24, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:26] {2391} INFO -  at 3.9s,	estimator xgboost's best error=0.0590,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:50:26] {2218} INFO - iteration 25, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:26] {2391} INFO -  at 3.9s,	estimator lgbm's best error=0.1164,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:50:26] {2218} INFO - iteration 26, current learner extra_tree
# [flaml.automl.logger: 01-12 02:50:26] {2391} INFO -  at 4.0s,	estimator extra_tree's best error=0.2082,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:50:26] {2218} INFO - iteration 27, current learner extra_tree
# [flaml.automl.logger: 01-12 02:50:26] {2391} INFO -  at 4.2s,	estimator extra_tree's best error=0.1537,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:50:26] {2218} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 01-12 02:50:26] {2391} INFO -  at 4.2s,	estimator extra_tree's best error=0.1537,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:50:26] {2218} INFO - iteration 29, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:26] {2391} INFO -  at 4.5s,	estimator xgboost's best error=0.0590,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:50:26] {2218} INFO - iteration 30, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:30] {2391} INFO -  at 8.6s,	estimator xgboost's best error=0.0590,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:50:30] {2218} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:31] {2391} INFO -  at 9.2s,	estimator lgbm's best error=0.1144,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:50:31] {2218} INFO - iteration 32, current learner extra_tree
# [flaml.automl.logger: 01-12 02:50:31] {2391} INFO -  at 9.3s,	estimator extra_tree's best error=0.1537,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:50:31] {2218} INFO - iteration 33, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:31] {2391} INFO -  at 9.6s,	estimator lgbm's best error=0.1144,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:50:31] {2218} INFO - iteration 34, current learner extra_tree
# [flaml.automl.logger: 01-12 02:50:32] {2391} INFO -  at 9.8s,	estimator extra_tree's best error=0.1257,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:50:32] {2218} INFO - iteration 35, current learner rf
# [flaml.automl.logger: 01-12 02:50:32] {2391} INFO -  at 9.9s,	estimator rf's best error=0.1966,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:50:32] {2218} INFO - iteration 36, current learner extra_tree
# [flaml.automl.logger: 01-12 02:50:32] {2391} INFO -  at 10.1s,	estimator extra_tree's best error=0.1257,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:50:32] {2218} INFO - iteration 37, current learner rf
# [flaml.automl.logger: 01-12 02:50:32] {2391} INFO -  at 10.3s,	estimator rf's best error=0.1572,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:50:32] {2218} INFO - iteration 38, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:32] {2391} INFO -  at 10.5s,	estimator lgbm's best error=0.0985,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:50:32] {2218} INFO - iteration 39, current learner rf
# [flaml.automl.logger: 01-12 02:50:32] {2391} INFO -  at 10.6s,	estimator rf's best error=0.1572,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:50:32] {2218} INFO - iteration 40, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:33] {2391} INFO -  at 10.8s,	estimator lgbm's best error=0.0985,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:50:33] {2218} INFO - iteration 41, current learner extra_tree
# [flaml.automl.logger: 01-12 02:50:33] {2391} INFO -  at 11.2s,	estimator extra_tree's best error=0.1168,	best estimator xgboost's best error=0.0590
# [flaml.automl.logger: 01-12 02:50:33] {2218} INFO - iteration 42, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:34] {2391} INFO -  at 12.1s,	estimator xgboost's best error=0.0534,	best estimator xgboost's best error=0.0534
# [flaml.automl.logger: 01-12 02:50:34] {2218} INFO - iteration 43, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:34] {2391} INFO -  at 12.4s,	estimator lgbm's best error=0.0788,	best estimator xgboost's best error=0.0534
# [flaml.automl.logger: 01-12 02:50:34] {2218} INFO - iteration 44, current learner extra_tree
# [flaml.automl.logger: 01-12 02:50:34] {2391} INFO -  at 12.6s,	estimator extra_tree's best error=0.1168,	best estimator xgboost's best error=0.0534
# [flaml.automl.logger: 01-12 02:50:34] {2218} INFO - iteration 45, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:35] {2391} INFO -  at 12.8s,	estimator lgbm's best error=0.0788,	best estimator xgboost's best error=0.0534
# [flaml.automl.logger: 01-12 02:50:35] {2218} INFO - iteration 46, current learner rf
# [flaml.automl.logger: 01-12 02:50:35] {2391} INFO -  at 12.9s,	estimator rf's best error=0.1572,	best estimator xgboost's best error=0.0534
# [flaml.automl.logger: 01-12 02:50:35] {2218} INFO - iteration 47, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:35] {2391} INFO -  at 13.2s,	estimator lgbm's best error=0.0646,	best estimator xgboost's best error=0.0534
# [flaml.automl.logger: 01-12 02:50:35] {2218} INFO - iteration 48, current learner rf
# [flaml.automl.logger: 01-12 02:50:35] {2391} INFO -  at 13.5s,	estimator rf's best error=0.1221,	best estimator xgboost's best error=0.0534
# [flaml.automl.logger: 01-12 02:50:35] {2218} INFO - iteration 49, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:36] {2391} INFO -  at 14.0s,	estimator lgbm's best error=0.0516,	best estimator lgbm's best error=0.0516
# [flaml.automl.logger: 01-12 02:50:36] {2218} INFO - iteration 50, current learner extra_tree
# [flaml.automl.logger: 01-12 02:50:37] {2391} INFO -  at 14.8s,	estimator extra_tree's best error=0.1168,	best estimator lgbm's best error=0.0516
# [flaml.automl.logger: 01-12 02:50:37] {2218} INFO - iteration 51, current learner rf
# [flaml.automl.logger: 01-12 02:50:37] {2391} INFO -  at 15.0s,	estimator rf's best error=0.1221,	best estimator lgbm's best error=0.0516
# [flaml.automl.logger: 01-12 02:50:37] {2218} INFO - iteration 52, current learner rf
# [flaml.automl.logger: 01-12 02:50:37] {2391} INFO -  at 15.5s,	estimator rf's best error=0.1218,	best estimator lgbm's best error=0.0516
# [flaml.automl.logger: 01-12 02:50:37] {2218} INFO - iteration 53, current learner rf
# [flaml.automl.logger: 01-12 02:50:38] {2391} INFO -  at 15.7s,	estimator rf's best error=0.1218,	best estimator lgbm's best error=0.0516
# [flaml.automl.logger: 01-12 02:50:38] {2218} INFO - iteration 54, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:39] {2391} INFO -  at 17.5s,	estimator xgboost's best error=0.0534,	best estimator lgbm's best error=0.0516
# [flaml.automl.logger: 01-12 02:50:39] {2218} INFO - iteration 55, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:40] {2391} INFO -  at 17.7s,	estimator lgbm's best error=0.0516,	best estimator lgbm's best error=0.0516
# [flaml.automl.logger: 01-12 02:50:40] {2218} INFO - iteration 56, current learner rf
# [flaml.automl.logger: 01-12 02:50:41] {2391} INFO -  at 18.7s,	estimator rf's best error=0.1182,	best estimator lgbm's best error=0.0516
# [flaml.automl.logger: 01-12 02:50:41] {2218} INFO - iteration 57, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:42] {2391} INFO -  at 20.0s,	estimator lgbm's best error=0.0480,	best estimator lgbm's best error=0.0480
# [flaml.automl.logger: 01-12 02:50:42] {2218} INFO - iteration 58, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:46] {2391} INFO -  at 23.9s,	estimator lgbm's best error=0.0480,	best estimator lgbm's best error=0.0480
# [flaml.automl.logger: 01-12 02:50:46] {2218} INFO - iteration 59, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:46] {2391} INFO -  at 24.6s,	estimator xgboost's best error=0.0498,	best estimator lgbm's best error=0.0480
# [flaml.automl.logger: 01-12 02:50:46] {2218} INFO - iteration 60, current learner lgbm
# [flaml.automl.logger: 01-12 02:50:49] {2391} INFO -  at 27.1s,	estimator lgbm's best error=0.0472,	best estimator lgbm's best error=0.0472
# [flaml.automl.logger: 01-12 02:50:49] {2218} INFO - iteration 61, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:49] {2391} INFO -  at 27.3s,	estimator xgboost's best error=0.0498,	best estimator lgbm's best error=0.0472
# [flaml.automl.logger: 01-12 02:50:49] {2218} INFO - iteration 62, current learner extra_tree
# [flaml.automl.logger: 01-12 02:50:50] {2391} INFO -  at 27.8s,	estimator extra_tree's best error=0.1168,	best estimator lgbm's best error=0.0472
# [flaml.automl.logger: 01-12 02:50:50] {2218} INFO - iteration 63, current learner extra_tree
# [flaml.automl.logger: 01-12 02:50:50] {2391} INFO -  at 28.1s,	estimator extra_tree's best error=0.1168,	best estimator lgbm's best error=0.0472
# [flaml.automl.logger: 01-12 02:50:50] {2218} INFO - iteration 64, current learner xgboost
# [flaml.automl.logger: 01-12 02:50:54] {2391} INFO -  at 32.1s,	estimator xgboost's best error=0.0442,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:50:54] {2218} INFO - iteration 65, current learner rf
# [flaml.automl.logger: 01-12 02:50:56] {2391} INFO -  at 33.8s,	estimator rf's best error=0.1182,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:50:56] {2218} INFO - iteration 66, current learner extra_tree
# [flaml.automl.logger: 01-12 02:50:58] {2391} INFO -  at 36.1s,	estimator extra_tree's best error=0.1168,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:50:58] {2218} INFO - iteration 67, current learner catboost
# [flaml.automl.logger: 01-12 02:51:00] {2391} INFO -  at 37.9s,	estimator catboost's best error=0.0586,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:00] {2218} INFO - iteration 68, current learner rf
# [flaml.automl.logger: 01-12 02:51:01] {2391} INFO -  at 39.0s,	estimator rf's best error=0.1147,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:01] {2218} INFO - iteration 69, current learner xgboost
# [flaml.automl.logger: 01-12 02:51:07] {2391} INFO -  at 44.8s,	estimator xgboost's best error=0.0442,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:07] {2218} INFO - iteration 70, current learner catboost
# [flaml.automl.logger: 01-12 02:51:07] {2391} INFO -  at 45.6s,	estimator catboost's best error=0.0586,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:07] {2218} INFO - iteration 71, current learner catboost
# [flaml.automl.logger: 01-12 02:51:09] {2391} INFO -  at 46.8s,	estimator catboost's best error=0.0586,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:09] {2218} INFO - iteration 72, current learner catboost
# [flaml.automl.logger: 01-12 02:51:10] {2391} INFO -  at 48.4s,	estimator catboost's best error=0.0560,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:10] {2218} INFO - iteration 73, current learner lrl2
# INFO:flaml.tune.searcher.blendsearch:No low-cost partial config given to the search algorithm. For cost-frugal search, consider providing low-cost values for cost-related hps via 'low_cost_partial_config'. More info can be found at https://microsoft.github.io/FLAML/docs/FAQ#about-low_cost_partial_config-in-tune
# [flaml.automl.logger: 01-12 02:51:12] {2391} INFO -  at 50.1s,	estimator lrl2's best error=0.2345,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:12] {2218} INFO - iteration 74, current learner extra_tree
# [flaml.automl.logger: 01-12 02:51:14] {2391} INFO -  at 51.6s,	estimator extra_tree's best error=0.1095,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:14] {2218} INFO - iteration 75, current learner lrl2
# [flaml.automl.logger: 01-12 02:51:14] {2391} INFO -  at 52.6s,	estimator lrl2's best error=0.2345,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:14] {2218} INFO - iteration 76, current learner extra_tree
# [flaml.automl.logger: 01-12 02:51:17] {2391} INFO -  at 54.8s,	estimator extra_tree's best error=0.1095,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:17] {2218} INFO - iteration 77, current learner rf
# [flaml.automl.logger: 01-12 02:51:17] {2391} INFO -  at 55.4s,	estimator rf's best error=0.1043,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:17] {2218} INFO - iteration 78, current learner rf
# [flaml.automl.logger: 01-12 02:51:18] {2391} INFO -  at 56.1s,	estimator rf's best error=0.1043,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:18] {2218} INFO - iteration 79, current learner lrl2
# [flaml.automl.logger: 01-12 02:51:19] {2391} INFO -  at 57.3s,	estimator lrl2's best error=0.2345,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:19] {2218} INFO - iteration 80, current learner rf
# [flaml.automl.logger: 01-12 02:51:20] {2391} INFO -  at 57.6s,	estimator rf's best error=0.0982,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:20] {2218} INFO - iteration 81, current learner rf
# [flaml.automl.logger: 01-12 02:51:20] {2391} INFO -  at 58.1s,	estimator rf's best error=0.0970,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:20] {2218} INFO - iteration 82, current learner catboost
# [flaml.automl.logger: 01-12 02:51:21] {2391} INFO -  at 59.6s,	estimator catboost's best error=0.0560,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:21] {2218} INFO - iteration 83, current learner rf
# [flaml.automl.logger: 01-12 02:51:22] {2391} INFO -  at 60.0s,	estimator rf's best error=0.0970,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:22] {2218} INFO - iteration 84, current learner lrl2
# [flaml.automl.logger: 01-12 02:51:24] {2391} INFO -  at 62.0s,	estimator lrl2's best error=0.2345,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:24] {2218} INFO - iteration 85, current learner rf
# [flaml.automl.logger: 01-12 02:51:25] {2391} INFO -  at 62.6s,	estimator rf's best error=0.0837,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:25] {2218} INFO - iteration 86, current learner catboost
# [flaml.automl.logger: 01-12 02:51:26] {2391} INFO -  at 64.6s,	estimator catboost's best error=0.0560,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:26] {2218} INFO - iteration 87, current learner lgbm
# [flaml.automl.logger: 01-12 02:51:27] {2391} INFO -  at 65.3s,	estimator lgbm's best error=0.0472,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:27] {2218} INFO - iteration 88, current learner lrl2
# [flaml.automl.logger: 01-12 02:51:29] {2391} INFO -  at 67.5s,	estimator lrl2's best error=0.2345,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:29] {2218} INFO - iteration 89, current learner rf
# [flaml.automl.logger: 01-12 02:51:31] {2391} INFO -  at 69.3s,	estimator rf's best error=0.0837,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:31] {2218} INFO - iteration 90, current learner rf
# [flaml.automl.logger: 01-12 02:51:32] {2391} INFO -  at 69.8s,	estimator rf's best error=0.0837,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:32] {2218} INFO - iteration 91, current learner extra_tree
# [flaml.automl.logger: 01-12 02:51:33] {2391} INFO -  at 70.7s,	estimator extra_tree's best error=0.1018,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:33] {2218} INFO - iteration 92, current learner lgbm
# [flaml.automl.logger: 01-12 02:51:34] {2391} INFO -  at 71.8s,	estimator lgbm's best error=0.0472,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:34] {2218} INFO - iteration 93, current learner extra_tree
# [flaml.automl.logger: 01-12 02:51:34] {2391} INFO -  at 72.6s,	estimator extra_tree's best error=0.1018,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:34] {2218} INFO - iteration 94, current learner catboost
# [flaml.automl.logger: 01-12 02:51:36] {2391} INFO -  at 73.9s,	estimator catboost's best error=0.0560,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:36] {2218} INFO - iteration 95, current learner lrl2
# [flaml.automl.logger: 01-12 02:51:38] {2391} INFO -  at 75.8s,	estimator lrl2's best error=0.2345,	best estimator xgboost's best error=0.0442
# [flaml.automl.logger: 01-12 02:51:38] {2218} INFO - iteration 96, current learner xgboost
# [flaml.automl.logger: 01-12 02:51:41] {2391} INFO -  at 79.2s,	estimator xgboost's best error=0.0422,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:51:41] {2218} INFO - iteration 97, current learner extra_tree
# [flaml.automl.logger: 01-12 02:51:41] {2391} INFO -  at 79.6s,	estimator extra_tree's best error=0.1018,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:51:41] {2218} INFO - iteration 98, current learner lgbm
# [flaml.automl.logger: 01-12 02:51:50] {2391} INFO -  at 88.6s,	estimator lgbm's best error=0.0469,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:51:50] {2218} INFO - iteration 99, current learner lrl2
# [flaml.automl.logger: 01-12 02:51:51] {2419} INFO - stop trying learner lrl2
# [flaml.automl.logger: 01-12 02:51:51] {2218} INFO - iteration 100, current learner kneighbor
# [flaml.automl.logger: 01-12 02:51:51] {2391} INFO -  at 89.1s,	estimator kneighbor's best error=0.3778,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:51:51] {2218} INFO - iteration 101, current learner kneighbor
# [flaml.automl.logger: 01-12 02:51:51] {2391} INFO -  at 89.4s,	estimator kneighbor's best error=0.3731,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:51:51] {2218} INFO - iteration 102, current learner extra_tree
# [flaml.automl.logger: 01-12 02:51:52] {2391} INFO -  at 90.1s,	estimator extra_tree's best error=0.0872,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:51:52] {2218} INFO - iteration 103, current learner kneighbor
# [flaml.automl.logger: 01-12 02:51:52] {2391} INFO -  at 90.4s,	estimator kneighbor's best error=0.3731,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:51:52] {2218} INFO - iteration 104, current learner kneighbor
# [flaml.automl.logger: 01-12 02:51:55] {2391} INFO -  at 93.0s,	estimator kneighbor's best error=0.3125,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:51:55] {2218} INFO - iteration 105, current learner xgboost
# [flaml.automl.logger: 01-12 02:52:10] {2391} INFO -  at 108.3s,	estimator xgboost's best error=0.0422,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:52:10] {2218} INFO - iteration 106, current learner extra_tree
# [flaml.automl.logger: 01-12 02:52:13] {2391} INFO -  at 111.6s,	estimator extra_tree's best error=0.0872,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:52:13] {2218} INFO - iteration 107, current learner rf
# [flaml.automl.logger: 01-12 02:52:15] {2391} INFO -  at 112.7s,	estimator rf's best error=0.0837,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:52:15] {2218} INFO - iteration 108, current learner catboost
# [flaml.automl.logger: 01-12 02:52:40] {2391} INFO -  at 138.3s,	estimator catboost's best error=0.0496,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:52:40] {2218} INFO - iteration 109, current learner kneighbor
# [flaml.automl.logger: 01-12 02:52:43] {2391} INFO -  at 140.8s,	estimator kneighbor's best error=0.3125,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:52:43] {2218} INFO - iteration 110, current learner rf
# [flaml.automl.logger: 01-12 02:52:45] {2391} INFO -  at 143.3s,	estimator rf's best error=0.0723,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:52:45] {2218} INFO - iteration 111, current learner kneighbor
# [flaml.automl.logger: 01-12 02:52:47] {2391} INFO -  at 145.2s,	estimator kneighbor's best error=0.3125,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:52:47] {2218} INFO - iteration 112, current learner extra_tree
# [flaml.automl.logger: 01-12 02:52:48] {2391} INFO -  at 145.7s,	estimator extra_tree's best error=0.0784,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:52:48] {2218} INFO - iteration 113, current learner xgboost
# [flaml.automl.logger: 01-12 02:52:58] {2391} INFO -  at 156.0s,	estimator xgboost's best error=0.0422,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:52:58] {2218} INFO - iteration 114, current learner kneighbor
# [flaml.automl.logger: 01-12 02:53:00] {2391} INFO -  at 157.8s,	estimator kneighbor's best error=0.3125,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:53:00] {2218} INFO - iteration 115, current learner extra_tree
# [flaml.automl.logger: 01-12 02:53:00] {2391} INFO -  at 158.1s,	estimator extra_tree's best error=0.0784,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:53:00] {2218} INFO - iteration 116, current learner kneighbor
# [flaml.automl.logger: 01-12 02:53:02] {2391} INFO -  at 160.0s,	estimator kneighbor's best error=0.3108,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:53:02] {2218} INFO - iteration 117, current learner rf
# [flaml.automl.logger: 01-12 02:53:03] {2391} INFO -  at 161.3s,	estimator rf's best error=0.0723,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:53:03] {2218} INFO - iteration 118, current learner rf
# [flaml.automl.logger: 01-12 02:53:12] {2391} INFO -  at 169.8s,	estimator rf's best error=0.0723,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:53:12] {2218} INFO - iteration 119, current learner kneighbor
# [flaml.automl.logger: 01-12 02:53:15] {2391} INFO -  at 172.8s,	estimator kneighbor's best error=0.3082,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:53:15] {2218} INFO - iteration 120, current learner kneighbor
# [flaml.automl.logger: 01-12 02:53:18] {2391} INFO -  at 175.7s,	estimator kneighbor's best error=0.3082,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:53:18] {2218} INFO - iteration 121, current learner rf
# [flaml.automl.logger: 01-12 02:53:28] {2391} INFO -  at 186.3s,	estimator rf's best error=0.0722,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:53:28] {2218} INFO - iteration 122, current learner kneighbor
# [flaml.automl.logger: 01-12 02:53:32] {2391} INFO -  at 190.4s,	estimator kneighbor's best error=0.3082,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:53:32] {2218} INFO - iteration 123, current learner extra_tree
# [flaml.automl.logger: 01-12 02:53:34] {2391} INFO -  at 192.2s,	estimator extra_tree's best error=0.0620,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:53:34] {2218} INFO - iteration 124, current learner kneighbor
# [flaml.automl.logger: 01-12 02:53:38] {2391} INFO -  at 196.1s,	estimator kneighbor's best error=0.3082,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:53:38] {2218} INFO - iteration 125, current learner extra_tree
# [flaml.automl.logger: 01-12 02:53:40] {2391} INFO -  at 198.3s,	estimator extra_tree's best error=0.0620,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:53:40] {2218} INFO - iteration 126, current learner lgbm
# [flaml.automl.logger: 01-12 02:53:47] {2391} INFO -  at 204.6s,	estimator lgbm's best error=0.0469,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:53:47] {2218} INFO - iteration 127, current learner xgboost
# [flaml.automl.logger: 01-12 02:53:51] {2391} INFO -  at 209.3s,	estimator xgboost's best error=0.0422,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:53:51] {2218} INFO - iteration 128, current learner xgboost
# [flaml.automl.logger: 01-12 02:53:53] {2391} INFO -  at 211.1s,	estimator xgboost's best error=0.0422,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:53:53] {2218} INFO - iteration 129, current learner xgboost
# [flaml.automl.logger: 01-12 02:54:02] {2391} INFO -  at 220.3s,	estimator xgboost's best error=0.0422,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:54:02] {2218} INFO - iteration 130, current learner catboost
# [flaml.automl.logger: 01-12 02:54:06] {2391} INFO -  at 223.7s,	estimator catboost's best error=0.0481,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:54:06] {2218} INFO - iteration 131, current learner extra_tree
# [flaml.automl.logger: 01-12 02:54:07] {2391} INFO -  at 225.0s,	estimator extra_tree's best error=0.0587,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:54:07] {2218} INFO - iteration 132, current learner catboost
# [flaml.automl.logger: 01-12 02:54:18] {2391} INFO -  at 236.0s,	estimator catboost's best error=0.0481,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:54:18] {2218} INFO - iteration 133, current learner extra_tree
# [flaml.automl.logger: 01-12 02:54:21] {2391} INFO -  at 238.7s,	estimator extra_tree's best error=0.0521,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:54:21] {2218} INFO - iteration 134, current learner extra_tree
# [flaml.automl.logger: 01-12 02:54:22] {2391} INFO -  at 239.9s,	estimator extra_tree's best error=0.0521,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:54:22] {2218} INFO - iteration 135, current learner lgbm
# [flaml.automl.logger: 01-12 02:54:37] {2391} INFO -  at 255.3s,	estimator lgbm's best error=0.0437,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:54:37] {2218} INFO - iteration 136, current learner catboost
# [flaml.automl.logger: 01-12 02:54:40] {2391} INFO -  at 257.7s,	estimator catboost's best error=0.0481,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:54:40] {2218} INFO - iteration 137, current learner extra_tree
# [flaml.automl.logger: 01-12 02:54:42] {2391} INFO -  at 259.8s,	estimator extra_tree's best error=0.0521,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:54:42] {2218} INFO - iteration 138, current learner kneighbor
# [flaml.automl.logger: 01-12 02:54:45] {2391} INFO -  at 262.9s,	estimator kneighbor's best error=0.3082,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:54:45] {2218} INFO - iteration 139, current learner extra_tree
# [flaml.automl.logger: 01-12 02:54:49] {2391} INFO -  at 267.5s,	estimator extra_tree's best error=0.0490,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:54:49] {2218} INFO - iteration 140, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:54:49] {2391} INFO -  at 267.6s,	estimator xgb_limitdepth's best error=0.0791,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:54:49] {2218} INFO - iteration 141, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:54:50] {2391} INFO -  at 267.8s,	estimator xgb_limitdepth's best error=0.0648,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:54:50] {2218} INFO - iteration 142, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:54:50] {2391} INFO -  at 267.9s,	estimator xgb_limitdepth's best error=0.0648,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:54:50] {2218} INFO - iteration 143, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:54:50] {2391} INFO -  at 268.3s,	estimator xgb_limitdepth's best error=0.0567,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:54:50] {2218} INFO - iteration 144, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:54:50] {2391} INFO -  at 268.5s,	estimator xgb_limitdepth's best error=0.0567,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:54:50] {2218} INFO - iteration 145, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:54:51] {2391} INFO -  at 268.8s,	estimator xgb_limitdepth's best error=0.0567,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:54:51] {2218} INFO - iteration 146, current learner lgbm
# [flaml.automl.logger: 01-12 02:55:47] {2391} INFO -  at 324.7s,	estimator lgbm's best error=0.0437,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:55:47] {2218} INFO - iteration 147, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:55:49] {2391} INFO -  at 327.4s,	estimator xgb_limitdepth's best error=0.0567,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:55:49] {2218} INFO - iteration 148, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:55:51] {2391} INFO -  at 328.7s,	estimator xgb_limitdepth's best error=0.0501,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:55:51] {2218} INFO - iteration 149, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:55:54] {2391} INFO -  at 332.1s,	estimator xgb_limitdepth's best error=0.0501,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:55:54] {2218} INFO - iteration 150, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:55:55] {2391} INFO -  at 332.7s,	estimator xgb_limitdepth's best error=0.0501,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:55:55] {2218} INFO - iteration 151, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:55:55] {2391} INFO -  at 333.5s,	estimator xgb_limitdepth's best error=0.0501,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:55:55] {2218} INFO - iteration 152, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:55:58] {2391} INFO -  at 335.7s,	estimator xgb_limitdepth's best error=0.0463,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:55:58] {2218} INFO - iteration 153, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:56:04] {2391} INFO -  at 342.1s,	estimator xgb_limitdepth's best error=0.0463,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:56:04] {2218} INFO - iteration 154, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:56:06] {2391} INFO -  at 344.3s,	estimator xgb_limitdepth's best error=0.0463,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:56:06] {2218} INFO - iteration 155, current learner extra_tree
# [flaml.automl.logger: 01-12 02:56:08] {2391} INFO -  at 346.2s,	estimator extra_tree's best error=0.0490,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:56:08] {2218} INFO - iteration 156, current learner catboost
# [flaml.automl.logger: 01-12 02:56:13] {2391} INFO -  at 351.2s,	estimator catboost's best error=0.0471,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:56:13] {2218} INFO - iteration 157, current learner xgboost
# [flaml.automl.logger: 01-12 02:56:19] {2391} INFO -  at 357.4s,	estimator xgboost's best error=0.0422,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:56:19] {2218} INFO - iteration 158, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:56:21] {2391} INFO -  at 358.7s,	estimator xgb_limitdepth's best error=0.0463,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:56:21] {2218} INFO - iteration 159, current learner kneighbor
# [flaml.automl.logger: 01-12 02:56:22] {2391} INFO -  at 360.5s,	estimator kneighbor's best error=0.3082,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:56:22] {2218} INFO - iteration 160, current learner extra_tree
# [flaml.automl.logger: 01-12 02:56:27] {2391} INFO -  at 364.8s,	estimator extra_tree's best error=0.0486,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:56:27] {2218} INFO - iteration 161, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:56:35] {2391} INFO -  at 373.4s,	estimator xgb_limitdepth's best error=0.0463,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:56:35] {2218} INFO - iteration 162, current learner rf
# [flaml.automl.logger: 01-12 02:56:38] {2391} INFO -  at 375.8s,	estimator rf's best error=0.0722,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:56:38] {2218} INFO - iteration 163, current learner extra_tree
# [flaml.automl.logger: 01-12 02:56:53] {2391} INFO -  at 390.7s,	estimator extra_tree's best error=0.0484,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:56:53] {2218} INFO - iteration 164, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:56:54] {2391} INFO -  at 392.0s,	estimator xgb_limitdepth's best error=0.0463,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:56:54] {2218} INFO - iteration 165, current learner catboost
# [flaml.automl.logger: 01-12 02:56:57] {2391} INFO -  at 395.1s,	estimator catboost's best error=0.0471,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:56:57] {2218} INFO - iteration 166, current learner kneighbor
# [flaml.automl.logger: 01-12 02:56:59] {2391} INFO -  at 396.9s,	estimator kneighbor's best error=0.3076,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:56:59] {2218} INFO - iteration 167, current learner kneighbor
# [flaml.automl.logger: 01-12 02:56:59] {2419} INFO - stop trying learner kneighbor
# [flaml.automl.logger: 01-12 02:56:59] {2218} INFO - iteration 168, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:57:07] {2391} INFO -  at 405.3s,	estimator xgb_limitdepth's best error=0.0463,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:57:07] {2218} INFO - iteration 169, current learner lgbm
# [flaml.automl.logger: 01-12 02:57:11] {2391} INFO -  at 409.3s,	estimator lgbm's best error=0.0437,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:57:11] {2218} INFO - iteration 170, current learner catboost
# [flaml.automl.logger: 01-12 02:57:20] {2391} INFO -  at 418.1s,	estimator catboost's best error=0.0471,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:57:20] {2218} INFO - iteration 171, current learner extra_tree
# [flaml.automl.logger: 01-12 02:57:25] {2391} INFO -  at 422.9s,	estimator extra_tree's best error=0.0484,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:57:25] {2218} INFO - iteration 172, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 02:57:39] {2391} INFO -  at 436.7s,	estimator xgb_limitdepth's best error=0.0463,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:57:39] {2218} INFO - iteration 173, current learner xgboost
# [flaml.automl.logger: 01-12 02:57:39] {2391} INFO -  at 437.3s,	estimator xgboost's best error=0.0422,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:57:39] {2218} INFO - iteration 174, current learner xgboost
# [flaml.automl.logger: 01-12 02:58:06] {2391} INFO -  at 464.2s,	estimator xgboost's best error=0.0422,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:58:06] {2218} INFO - iteration 175, current learner catboost
# [flaml.automl.logger: 01-12 02:58:09] {2391} INFO -  at 467.3s,	estimator catboost's best error=0.0471,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:58:09] {2218} INFO - iteration 176, current learner catboost
# [flaml.automl.logger: 01-12 02:58:24] {2391} INFO -  at 481.7s,	estimator catboost's best error=0.0471,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:58:24] {2218} INFO - iteration 177, current learner catboost
# [flaml.automl.logger: 01-12 02:58:27] {2391} INFO -  at 484.7s,	estimator catboost's best error=0.0471,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:58:27] {2218} INFO - iteration 178, current learner rf
# [flaml.automl.logger: 01-12 02:58:30] {2391} INFO -  at 488.4s,	estimator rf's best error=0.0722,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:58:30] {2218} INFO - iteration 179, current learner extra_tree
# [flaml.automl.logger: 01-12 02:58:39] {2391} INFO -  at 497.4s,	estimator extra_tree's best error=0.0484,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:58:39] {2218} INFO - iteration 180, current learner catboost
# [flaml.automl.logger: 01-12 02:58:45] {2391} INFO -  at 503.3s,	estimator catboost's best error=0.0471,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:58:45] {2218} INFO - iteration 181, current learner rf
# [flaml.automl.logger: 01-12 02:58:55] {2391} INFO -  at 512.8s,	estimator rf's best error=0.0554,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:58:55] {2218} INFO - iteration 182, current learner lgbm
# [flaml.automl.logger: 01-12 02:59:01] {2391} INFO -  at 519.0s,	estimator lgbm's best error=0.0437,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:59:01] {2218} INFO - iteration 183, current learner extra_tree
# [flaml.automl.logger: 01-12 02:59:30] {2391} INFO -  at 548.1s,	estimator extra_tree's best error=0.0457,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 02:59:30] {2218} INFO - iteration 184, current learner lgbm
# [flaml.automl.logger: 01-12 03:00:16] {2391} INFO -  at 593.7s,	estimator lgbm's best error=0.0437,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 03:00:16] {2218} INFO - iteration 185, current learner lrl1
# INFO:flaml.tune.searcher.blendsearch:No low-cost partial config given to the search algorithm. For cost-frugal search, consider providing low-cost values for cost-related hps via 'low_cost_partial_config'. More info can be found at https://microsoft.github.io/FLAML/docs/FAQ#about-low_cost_partial_config-in-tune
# [flaml.automl.logger: 01-12 03:00:16] {2391} INFO -  at 594.3s,	estimator lrl1's best error=0.4138,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 03:00:16] {2218} INFO - iteration 186, current learner lrl1
# [flaml.automl.logger: 01-12 03:00:17] {2391} INFO -  at 594.9s,	estimator lrl1's best error=0.4138,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 03:00:17] {2218} INFO - iteration 187, current learner lrl1
# [flaml.automl.logger: 01-12 03:00:17] {2391} INFO -  at 595.6s,	estimator lrl1's best error=0.4138,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 03:00:17] {2218} INFO - iteration 188, current learner lrl1
# [flaml.automl.logger: 01-12 03:00:22] {2391} INFO -  at 600.4s,	estimator lrl1's best error=0.3435,	best estimator xgboost's best error=0.0422
# [flaml.automl.logger: 01-12 03:00:22] {2525} INFO - [('xgboost', {'n_jobs': -1, 'n_estimators': 284, 'max_leaves': 92, 'min_child_weight': 0.15784619863870844, 'learning_rate': 0.42764856004198537, 'subsample': 1.0, 'colsample_bylevel': 1.0, 'colsample_bytree': 0.8942072410001078, 'reg_alpha': 0.007949362705976761, 'reg_lambda': 0.15683325226091974, 'max_depth': 0, 'grow_policy': 'lossguide', 'tree_method': 'hist', 'verbosity': 0}), ('lgbm', {'n_jobs': -1, 'n_estimators': 489, 'num_leaves': 3341, 'min_child_samples': 26, 'learning_rate': 0.6810175093276573, 'colsample_bytree': 0.7474731186737704, 'reg_alpha': 0.0026114080577972036, 'reg_lambda': 0.4440306981875064, 'max_bin': 127, 'verbose': -1}), ('extra_tree', {'n_jobs': -1, 'n_estimators': 228, 'max_features': 0.4849557823464132, 'criterion': 'entropy', 'max_leaf_nodes': 13334, 'random_state': 12032022, 'verbose': 0}), ('xgb_limitdepth', {'n_jobs': -1, 'n_estimators': 218, 'max_depth': 8, 'min_child_weight': 2.3404041220954164, 'learning_rate': 0.14974893301783557, 'subsample': 0.9326027735030358, 'colsample_bylevel': 1.0, 'colsample_bytree': 0.9387813501544093, 'reg_alpha': 0.027834922491891564, 'reg_lambda': 0.17955329055448926, 'verbosity': 0}), ('catboost', {'early_stopping_rounds': 14, 'learning_rate': 0.16237736235263822, 'n_estimators': 226, 'thread_count': -1, 'verbose': False, 'random_seed': 10242048}), ('rf', {'n_jobs': -1, 'n_estimators': 112, 'max_features': 0.1493987346099057, 'criterion': 'entropy', 'max_leaf_nodes': 3726, 'random_state': 12032022, 'verbose': 0})]
# [flaml.automl.logger: 01-12 03:00:22] {2568} INFO - Building ensemble with tuned estimators
# [flaml.automl.logger: 01-12 03:06:24] {2574} INFO - ensemble: StackingClassifier(estimators=[('xgboost',
#                                 <flaml.automl.model.XGBoostSklearnEstimator object at 0x78fcfc64f700>),
#                                ('lgbm',
#                                 <flaml.automl.model.LGBMEstimator object at 0x78fce852fb80>),
#                                ('extra_tree',
#                                 <flaml.automl.model.ExtraTreesEstimator object at 0x78fce852de10>),
#                                ('xgb_limitdepth',
#                                 <flaml.automl.model.XGBoostLimitDepthEstimator object at 0x78fce852d030>),
#                                ('catboost',
#                                 <flaml.automl.model.CatBoostEstimator object at 0x78fce852f640>),
#                                ('rf',
#                                 <flaml.automl.model.RandomForestEstimator object at 0x78fce852f760>)],
#                    n_jobs=1, passthrough=True)
# [flaml.automl.logger: 01-12 03:06:24] {1930} INFO - fit succeeded
# [flaml.automl.logger: 01-12 03:06:24] {1931} INFO - Time taken to find the best model: 79.16133403778076

# %%
# retrieve best config and best learner
print('Best ML leaner:', automl2.best_estimator)
print('Best hyperparmeter config:', automl2.best_config)
print('Best accuracy on validation data: {0:.4g}'.format(1-automl2.best_loss))
print('Training duration of best run: {0:.4g} s'.format(automl2.best_config_train_time))
# Out:
# Best ML leaner: xgboost
# Best hyperparmeter config: {'n_estimators': 284, 'max_leaves': 92, 'min_child_weight': 0.15784619863870844, 'learning_rate': 0.42764856004198537, 'subsample': 1.0, 'colsample_bylevel': 1.0, 'colsample_bytree': 0.8942072410001078, 'reg_alpha': 0.007949362705976761, 'reg_lambda': 0.15683325226091974}
# Best accuracy on validation data: 0.9578
# Training duration of best run: 3.314 s

# %%
# obtain best model
automl2.model.estimator
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-3fd379113bdc> in <cell line: 2>()
#       1 # obtain best model
# ----> 2 automl2.model.estimator
#
# AttributeError: 'StackingClassifier' object has no attribute 'estimator'

# %% [markdown]
# ##### Predict for train data using CV

# %%
# compute predictions of testing dataset'''
y_pred2 = automl2.predict(test_x)
y_pred_proba2 = automl2.predict_proba(test_x)[:,1]

# %%
# compute different metric values on testing dataset'''
from flaml.ml import sklearn_metric_loss_score
print('accuracy', '=', 1 - sklearn_metric_loss_score('accuracy', y_pred2, y_test))
print('roc_auc', '=', 1 - sklearn_metric_loss_score('roc_auc', y_pred_proba2, y_test))
print('log_loss', '=', sklearn_metric_loss_score('log_loss', y_pred_proba2, y_test))
# Out:
# accuracy = 0.9225824680370135
# roc_auc = 0.9740513155440499
# log_loss = 0.20551637566581302

# %%
predict(automl2, 'automl2', pred_x)

# %% [markdown]
# #### **Model 3: Unscaled imputed data, KNNImputer, Seat_Class deleted**

# %%
train_x = X_train_imputed.copy()
train_x.drop('Seat_Class', axis = 1, inplace = True)

test_x = X_test_imputed.copy()
test_x.drop('Seat_Class', axis = 1, inplace = True)

pred_x = pd.concat([df_pred_orig['ID'], df_pred_imputed.copy()], axis = 1)
pred_x.drop('Seat_Class', axis = 1, inplace = True)

# %%
train_x.shape
# Out:
# (66065, 22)

# %%
# declare model for logistic regression
automl3 = AutoML()

# setting for AutoML
settings = {
    "time_budget": 600,  # total running time in seconds
    "metric": 'accuracy',
    # check the documentation for options of metrics (https://microsoft.github.io/FLAML/docs/Use-Cases/Task-Oriented-AutoML#optimization-metric)
    "task": 'classification',  # task type
    "estimator_list": ['xgboost', 'xgb_limitdepth', 'rf', 'lgbm', 'lrl1', 'lrl2', 'catboost', 'extra_tree', 'kneighbor'],
    "log_file_name": '/content/drive/MyDrive/DScourse/Hackathon/AutoML/hackathon1.log',  # flaml log file
    #"ensemble": True,
    "seed": 13,    # random seed
}

# %%
# The main flaml automl API
automl3.fit(X_train=train_x, y_train=y_train, **settings)
# Out:
# [flaml.automl.logger: 01-12 03:13:51] {1679} INFO - task = classification
# [flaml.automl.logger: 01-12 03:13:51] {1690} INFO - Evaluation method: cv
# [flaml.automl.logger: 01-12 03:13:51] {1788} INFO - Minimizing error metric: 1-accuracy
# [flaml.automl.logger: 01-12 03:13:51] {1900} INFO - List of ML learners in AutoML Run: ['xgboost', 'xgb_limitdepth', 'rf', 'lgbm', 'lrl1', 'lrl2', 'catboost', 'extra_tree', 'kneighbor']
# [flaml.automl.logger: 01-12 03:13:51] {2218} INFO - iteration 0, current learner xgboost
# [flaml.automl.logger: 01-12 03:13:54] {2344} INFO - Estimated sufficient time budget=30595s. Estimated necessary time budget=575s.
# [flaml.automl.logger: 01-12 03:13:54] {2391} INFO -  at 3.5s,	estimator xgboost's best error=0.1547,	best estimator xgboost's best error=0.1547
# [flaml.automl.logger: 01-12 03:13:54] {2218} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 01-12 03:13:56] {2391} INFO -  at 4.9s,	estimator lgbm's best error=0.1547,	best estimator xgboost's best error=0.1547
# [flaml.automl.logger: 01-12 03:13:56] {2218} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 01-12 03:13:57] {2391} INFO -  at 6.2s,	estimator lgbm's best error=0.1540,	best estimator lgbm's best error=0.1540
# [flaml.automl.logger: 01-12 03:13:57] {2218} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 01-12 03:13:58] {2391} INFO -  at 7.1s,	estimator lgbm's best error=0.1540,	best estimator lgbm's best error=0.1540
# [flaml.automl.logger: 01-12 03:13:58] {2218} INFO - iteration 4, current learner xgboost
# [flaml.automl.logger: 01-12 03:13:59] {2391} INFO -  at 8.2s,	estimator xgboost's best error=0.1516,	best estimator xgboost's best error=0.1516
# [flaml.automl.logger: 01-12 03:13:59] {2218} INFO - iteration 5, current learner xgboost
# [flaml.automl.logger: 01-12 03:14:00] {2391} INFO -  at 9.1s,	estimator xgboost's best error=0.1516,	best estimator xgboost's best error=0.1516
# [flaml.automl.logger: 01-12 03:14:00] {2218} INFO - iteration 6, current learner xgboost
# [flaml.automl.logger: 01-12 03:14:02] {2391} INFO -  at 11.3s,	estimator xgboost's best error=0.1309,	best estimator xgboost's best error=0.1309
# [flaml.automl.logger: 01-12 03:14:02] {2218} INFO - iteration 7, current learner xgboost
# [flaml.automl.logger: 01-12 03:14:03] {2391} INFO -  at 12.5s,	estimator xgboost's best error=0.1309,	best estimator xgboost's best error=0.1309
# [flaml.automl.logger: 01-12 03:14:03] {2218} INFO - iteration 8, current learner xgboost
# [flaml.automl.logger: 01-12 03:14:05] {2391} INFO -  at 14.5s,	estimator xgboost's best error=0.1237,	best estimator xgboost's best error=0.1237
# [flaml.automl.logger: 01-12 03:14:05] {2218} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 01-12 03:14:13] {2391} INFO -  at 22.0s,	estimator xgboost's best error=0.0870,	best estimator xgboost's best error=0.0870
# [flaml.automl.logger: 01-12 03:14:13] {2218} INFO - iteration 10, current learner extra_tree
# [flaml.automl.logger: 01-12 03:14:13] {2391} INFO -  at 22.5s,	estimator extra_tree's best error=0.1619,	best estimator xgboost's best error=0.0870
# [flaml.automl.logger: 01-12 03:14:13] {2218} INFO - iteration 11, current learner extra_tree
# [flaml.automl.logger: 01-12 03:14:15] {2391} INFO -  at 24.6s,	estimator extra_tree's best error=0.1475,	best estimator xgboost's best error=0.0870
# [flaml.automl.logger: 01-12 03:14:15] {2218} INFO - iteration 12, current learner rf
# [flaml.automl.logger: 01-12 03:14:16] {2391} INFO -  at 25.6s,	estimator rf's best error=0.1818,	best estimator xgboost's best error=0.0870
# [flaml.automl.logger: 01-12 03:14:16] {2218} INFO - iteration 13, current learner rf
# [flaml.automl.logger: 01-12 03:14:19] {2391} INFO -  at 28.0s,	estimator rf's best error=0.1477,	best estimator xgboost's best error=0.0870
# [flaml.automl.logger: 01-12 03:14:19] {2218} INFO - iteration 14, current learner xgboost
# [flaml.automl.logger: 01-12 03:14:30] {2391} INFO -  at 39.1s,	estimator xgboost's best error=0.0870,	best estimator xgboost's best error=0.0870
# [flaml.automl.logger: 01-12 03:14:30] {2218} INFO - iteration 15, current learner rf
# [flaml.automl.logger: 01-12 03:14:31] {2391} INFO -  at 39.7s,	estimator rf's best error=0.1477,	best estimator xgboost's best error=0.0870
# [flaml.automl.logger: 01-12 03:14:31] {2218} INFO - iteration 16, current learner xgboost
# [flaml.automl.logger: 01-12 03:14:32] {2391} INFO -  at 41.3s,	estimator xgboost's best error=0.0856,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:14:32] {2218} INFO - iteration 17, current learner extra_tree
# [flaml.automl.logger: 01-12 03:14:33] {2391} INFO -  at 41.8s,	estimator extra_tree's best error=0.1475,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:14:33] {2218} INFO - iteration 18, current learner xgboost
# [flaml.automl.logger: 01-12 03:14:34] {2391} INFO -  at 43.0s,	estimator xgboost's best error=0.0856,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:14:34] {2218} INFO - iteration 19, current learner rf
# [flaml.automl.logger: 01-12 03:14:35] {2391} INFO -  at 43.8s,	estimator rf's best error=0.1477,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:14:35] {2218} INFO - iteration 20, current learner rf
# [flaml.automl.logger: 01-12 03:14:42] {2391} INFO -  at 51.3s,	estimator rf's best error=0.1205,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:14:42] {2218} INFO - iteration 21, current learner rf
# [flaml.automl.logger: 01-12 03:14:46] {2391} INFO -  at 55.2s,	estimator rf's best error=0.1176,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:14:46] {2218} INFO - iteration 22, current learner xgboost
# [flaml.automl.logger: 01-12 03:14:49] {2391} INFO -  at 57.9s,	estimator xgboost's best error=0.0501,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:14:49] {2218} INFO - iteration 23, current learner xgboost
# [flaml.automl.logger: 01-12 03:14:56] {2391} INFO -  at 65.0s,	estimator xgboost's best error=0.0501,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:14:56] {2218} INFO - iteration 24, current learner rf
# [flaml.automl.logger: 01-12 03:15:01] {2391} INFO -  at 70.0s,	estimator rf's best error=0.1176,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:15:01] {2218} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 01-12 03:15:01] {2391} INFO -  at 70.7s,	estimator extra_tree's best error=0.1475,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:15:01] {2218} INFO - iteration 26, current learner xgboost
# [flaml.automl.logger: 01-12 03:15:04] {2391} INFO -  at 73.0s,	estimator xgboost's best error=0.0501,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:15:04] {2218} INFO - iteration 27, current learner xgboost
# [flaml.automl.logger: 01-12 03:15:09] {2391} INFO -  at 78.7s,	estimator xgboost's best error=0.0501,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:15:09] {2218} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 01-12 03:15:13] {2391} INFO -  at 82.3s,	estimator extra_tree's best error=0.1118,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:15:13] {2218} INFO - iteration 29, current learner extra_tree
# [flaml.automl.logger: 01-12 03:15:16] {2391} INFO -  at 85.5s,	estimator extra_tree's best error=0.1118,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:15:16] {2218} INFO - iteration 30, current learner xgboost
# [flaml.automl.logger: 01-12 03:15:25] {2391} INFO -  at 94.3s,	estimator xgboost's best error=0.0478,	best estimator xgboost's best error=0.0478
# [flaml.automl.logger: 01-12 03:15:25] {2218} INFO - iteration 31, current learner xgboost
# [flaml.automl.logger: 01-12 03:15:28] {2391} INFO -  at 97.3s,	estimator xgboost's best error=0.0478,	best estimator xgboost's best error=0.0478
# [flaml.automl.logger: 01-12 03:15:28] {2218} INFO - iteration 32, current learner xgboost
# [flaml.automl.logger: 01-12 03:15:39] {2391} INFO -  at 108.6s,	estimator xgboost's best error=0.0463,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:15:39] {2218} INFO - iteration 33, current learner extra_tree
# [flaml.automl.logger: 01-12 03:15:45] {2391} INFO -  at 113.8s,	estimator extra_tree's best error=0.1118,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:15:45] {2218} INFO - iteration 34, current learner xgboost
# [flaml.automl.logger: 01-12 03:16:17] {2391} INFO -  at 146.2s,	estimator xgboost's best error=0.0463,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:16:17] {2218} INFO - iteration 35, current learner catboost
# [flaml.automl.logger: 01-12 03:16:46] {2391} INFO -  at 175.1s,	estimator catboost's best error=0.0487,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:16:46] {2218} INFO - iteration 36, current learner catboost
# [flaml.automl.logger: 01-12 03:17:23] {2391} INFO -  at 212.1s,	estimator catboost's best error=0.0476,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:17:23] {2218} INFO - iteration 37, current learner extra_tree
# [flaml.automl.logger: 01-12 03:17:26] {2391} INFO -  at 215.2s,	estimator extra_tree's best error=0.1118,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:17:26] {2218} INFO - iteration 38, current learner lgbm
# [flaml.automl.logger: 01-12 03:17:29] {2391} INFO -  at 217.9s,	estimator lgbm's best error=0.1110,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:17:29] {2218} INFO - iteration 39, current learner lgbm
# [flaml.automl.logger: 01-12 03:17:30] {2391} INFO -  at 219.1s,	estimator lgbm's best error=0.1110,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:17:30] {2218} INFO - iteration 40, current learner lgbm
# [flaml.automl.logger: 01-12 03:17:31] {2391} INFO -  at 220.5s,	estimator lgbm's best error=0.1039,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:17:31] {2218} INFO - iteration 41, current learner catboost
# [flaml.automl.logger: 01-12 03:18:34] {2391} INFO -  at 283.4s,	estimator catboost's best error=0.0476,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:18:34] {2218} INFO - iteration 42, current learner extra_tree
# [flaml.automl.logger: 01-12 03:18:42] {2391} INFO -  at 290.9s,	estimator extra_tree's best error=0.1105,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:18:42] {2218} INFO - iteration 43, current learner xgboost
# [flaml.automl.logger: 01-12 03:18:48] {2391} INFO -  at 297.0s,	estimator xgboost's best error=0.0463,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:18:48] {2218} INFO - iteration 44, current learner lgbm
# [flaml.automl.logger: 01-12 03:18:49] {2391} INFO -  at 298.2s,	estimator lgbm's best error=0.1039,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:18:49] {2218} INFO - iteration 45, current learner catboost
# [flaml.automl.logger: 01-12 03:19:07] {2391} INFO -  at 316.2s,	estimator catboost's best error=0.0476,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:19:07] {2218} INFO - iteration 46, current learner lgbm
# [flaml.automl.logger: 01-12 03:19:08] {2391} INFO -  at 317.2s,	estimator lgbm's best error=0.1039,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:19:08] {2218} INFO - iteration 47, current learner xgboost
# [flaml.automl.logger: 01-12 03:19:12] {2391} INFO -  at 321.3s,	estimator xgboost's best error=0.0463,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:19:12] {2218} INFO - iteration 48, current learner lgbm
# [flaml.automl.logger: 01-12 03:19:18] {2391} INFO -  at 327.4s,	estimator lgbm's best error=0.0977,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:19:18] {2218} INFO - iteration 49, current learner xgboost
# [flaml.automl.logger: 01-12 03:19:33] {2391} INFO -  at 342.5s,	estimator xgboost's best error=0.0463,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:19:33] {2218} INFO - iteration 50, current learner lrl2
# INFO:flaml.tune.searcher.blendsearch:No low-cost partial config given to the search algorithm. For cost-frugal search, consider providing low-cost values for cost-related hps via 'low_cost_partial_config'. More info can be found at https://microsoft.github.io/FLAML/docs/FAQ#about-low_cost_partial_config-in-tune
# [flaml.automl.logger: 01-12 03:19:42] {2391} INFO -  at 351.5s,	estimator lrl2's best error=0.2429,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:19:42] {2218} INFO - iteration 51, current learner lrl2
# [flaml.automl.logger: 01-12 03:19:52] {2391} INFO -  at 361.4s,	estimator lrl2's best error=0.2429,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:19:52] {2218} INFO - iteration 52, current learner lrl2
# [flaml.automl.logger: 01-12 03:20:02] {2391} INFO -  at 371.3s,	estimator lrl2's best error=0.2367,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:20:02] {2218} INFO - iteration 53, current learner kneighbor
# [flaml.automl.logger: 01-12 03:20:21] {2391} INFO -  at 390.4s,	estimator kneighbor's best error=0.3205,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:20:21] {2218} INFO - iteration 54, current learner rf
# [flaml.automl.logger: 01-12 03:20:23] {2391} INFO -  at 392.2s,	estimator rf's best error=0.1176,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:20:23] {2218} INFO - iteration 55, current learner rf
# [flaml.automl.logger: 01-12 03:20:33] {2391} INFO -  at 401.9s,	estimator rf's best error=0.1176,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:20:33] {2218} INFO - iteration 56, current learner xgboost
# [flaml.automl.logger: 01-12 03:20:51] {2391} INFO -  at 419.9s,	estimator xgboost's best error=0.0463,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:20:51] {2218} INFO - iteration 57, current learner xgboost
# [flaml.automl.logger: 01-12 03:20:55] {2391} INFO -  at 424.3s,	estimator xgboost's best error=0.0463,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:20:55] {2218} INFO - iteration 58, current learner kneighbor
# [flaml.automl.logger: 01-12 03:21:14] {2391} INFO -  at 443.2s,	estimator kneighbor's best error=0.3173,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:21:14] {2218} INFO - iteration 59, current learner xgboost
# [flaml.automl.logger: 01-12 03:21:15] {2391} INFO -  at 444.6s,	estimator xgboost's best error=0.0463,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:21:15] {2218} INFO - iteration 60, current learner xgboost
# [flaml.automl.logger: 01-12 03:22:25] {2391} INFO -  at 514.3s,	estimator xgboost's best error=0.0463,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:22:25] {2218} INFO - iteration 61, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 03:22:26] {2391} INFO -  at 515.4s,	estimator xgb_limitdepth's best error=0.0735,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:22:26] {2218} INFO - iteration 62, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 03:22:28] {2391} INFO -  at 517.5s,	estimator xgb_limitdepth's best error=0.0540,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:22:28] {2218} INFO - iteration 63, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 03:22:29] {2391} INFO -  at 518.7s,	estimator xgb_limitdepth's best error=0.0540,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:22:29] {2218} INFO - iteration 64, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 03:22:40] {2391} INFO -  at 529.2s,	estimator xgb_limitdepth's best error=0.0502,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:22:40] {2218} INFO - iteration 65, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 03:22:42] {2391} INFO -  at 531.3s,	estimator xgb_limitdepth's best error=0.0502,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:22:42] {2218} INFO - iteration 66, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 03:22:46] {2391} INFO -  at 535.2s,	estimator xgb_limitdepth's best error=0.0502,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:22:46] {2218} INFO - iteration 67, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 03:22:59] {2391} INFO -  at 548.6s,	estimator xgb_limitdepth's best error=0.0492,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:22:59] {2218} INFO - iteration 68, current learner xgboost
# [flaml.automl.logger: 01-12 03:23:13] {2391} INFO -  at 562.5s,	estimator xgboost's best error=0.0463,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:23:13] {2218} INFO - iteration 69, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 03:23:44] {2391} INFO -  at 592.9s,	estimator xgb_limitdepth's best error=0.0492,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:23:44] {2218} INFO - iteration 70, current learner lgbm
# [flaml.automl.logger: 01-12 03:23:49] {2391} INFO -  at 598.5s,	estimator lgbm's best error=0.0977,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:23:49] {2218} INFO - iteration 71, current learner lrl1
# INFO:flaml.tune.searcher.blendsearch:No low-cost partial config given to the search algorithm. For cost-frugal search, consider providing low-cost values for cost-related hps via 'low_cost_partial_config'. More info can be found at https://microsoft.github.io/FLAML/docs/FAQ#about-low_cost_partial_config-in-tune
# [flaml.automl.logger: 01-12 03:23:54] {2391} INFO -  at 603.6s,	estimator lrl1's best error=0.3515,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:23:56] {2627} INFO - retrain xgboost for 1.6s
# [flaml.automl.logger: 01-12 03:23:56] {2630} INFO - retrained model: XGBClassifier(base_score=None, booster=None, callbacks=[],
#               colsample_bylevel=0.5909530535241774, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy='lossguide', importance_type=None,
#               interaction_constraints=None, learning_rate=0.14016333421486576,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=0, max_leaves=147,
#               min_child_weight=0.04742539395483736, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=91,
#               n_jobs=-1, num_parallel_tree=None, random_state=None, ...)
# [flaml.automl.logger: 01-12 03:23:56] {1930} INFO - fit succeeded
# [flaml.automl.logger: 01-12 03:23:56] {1931} INFO - Time taken to find the best model: 108.63955473899841

# %%
# retrieve best config and best learner
print('Best ML leaner:', automl3.best_estimator)
print('Best hyperparmeter config:', automl3.best_config)
print('Best accuracy on validation data: {0:.4g}'.format(1-automl3.best_loss))
print('Training duration of best run: {0:.4g} s'.format(automl3.best_config_train_time))
# Out:
# Best ML leaner: xgboost
# Best hyperparmeter config: {'n_estimators': 91, 'max_leaves': 147, 'min_child_weight': 0.04742539395483736, 'learning_rate': 0.14016333421486576, 'subsample': 1.0, 'colsample_bylevel': 0.5909530535241774, 'colsample_bytree': 1.0, 'reg_alpha': 2.766143654293635, 'reg_lambda': 0.04798910206552531}
# Best accuracy on validation data: 0.9537
# Training duration of best run: 1.607 s

# %%
# obtain best model
automl3.model.estimator
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=[],
#               colsample_bylevel=0.5909530535241774, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy='lossguide', importance_type=None,
#               interaction_constraints=None, learning_rate=0.14016333421486576,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=0, max_leaves=147,
#               min_child_weight=0.04742539395483736, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=91,
#               n_jobs=-1, num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ##### Predict for train data using CV

# %%
# compute predictions of testing dataset'''
y_pred3 = automl3.predict(test_x)
y_pred_proba3 = automl3.predict_proba(test_x)[:,1]

# %%
# compute different metric values on testing dataset'''
from flaml.ml import sklearn_metric_loss_score
print('accuracy', '=', 1 - sklearn_metric_loss_score('accuracy', y_pred3, y_test))
print('roc_auc', '=', 1 - sklearn_metric_loss_score('roc_auc', y_pred_proba3, y_test))
print('log_loss', '=', sklearn_metric_loss_score('log_loss', y_pred_proba3, y_test))
# Out:
# accuracy = 0.9572296390478209
# roc_auc = 0.9937487713452847
# log_loss = 0.10062098556037102

# %%
predict(automl3, 'automl3', pred_x)

# %% [markdown]
# #### **Model 4: Unscaled imputed data, KNNImputer, Seat_Class deleted for stacked model**

# %%
train_x = X_train_imputed
train_x.drop('Seat_Class', axis = 1, inplace = True)

test_x = X_test_imputed
test_x.drop('Seat_Class', axis = 1, inplace = True)

pred_x = pd.concat([df_pred_orig['ID'], df_pred_imputed], axis = 1)
pred_x.drop('Seat_Class', axis = 1, inplace = True)

# %%
train_x.shape
# Out:
# (66065, 22)

# %%
# declare model for logistic regression
automl4 = AutoML()

# setting for AutoML
settings = {
    "time_budget": 600,  # total running time in seconds
    "metric": 'accuracy',
    # check the documentation for options of metrics (https://microsoft.github.io/FLAML/docs/Use-Cases/Task-Oriented-AutoML#optimization-metric)
    "task": 'classification',  # task type
    "estimator_list": ['xgboost', 'xgb_limitdepth', 'rf', 'lgbm', 'lrl1', 'lrl2', 'catboost', 'extra_tree', 'kneighbor'],
    "log_file_name": '/content/drive/MyDrive/DScourse/Hackathon/AutoML/hackathon1.log',  # flaml log file
    "ensemble": True,
    "seed": 13,    # random seed
}

# %%
# The main flaml automl API
automl4.fit(X_train=train_x, y_train=y_train, **settings)
# Out:
# [flaml.automl.logger: 01-12 03:40:07] {1679} INFO - task = classification
# [flaml.automl.logger: 01-12 03:40:07] {1690} INFO - Evaluation method: cv
# [flaml.automl.logger: 01-12 03:40:07] {1788} INFO - Minimizing error metric: 1-accuracy
# [flaml.automl.logger: 01-12 03:40:07] {1900} INFO - List of ML learners in AutoML Run: ['xgboost', 'xgb_limitdepth', 'rf', 'lgbm', 'lrl1', 'lrl2', 'catboost', 'extra_tree', 'kneighbor']
# [flaml.automl.logger: 01-12 03:40:07] {2218} INFO - iteration 0, current learner xgboost
# [flaml.automl.logger: 01-12 03:40:10] {2344} INFO - Estimated sufficient time budget=34296s. Estimated necessary time budget=644s.
# [flaml.automl.logger: 01-12 03:40:10] {2391} INFO -  at 3.9s,	estimator xgboost's best error=0.1547,	best estimator xgboost's best error=0.1547
# [flaml.automl.logger: 01-12 03:40:10] {2218} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 01-12 03:40:11] {2391} INFO -  at 5.0s,	estimator lgbm's best error=0.1547,	best estimator xgboost's best error=0.1547
# [flaml.automl.logger: 01-12 03:40:11] {2218} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 01-12 03:40:13] {2391} INFO -  at 6.2s,	estimator lgbm's best error=0.1540,	best estimator lgbm's best error=0.1540
# [flaml.automl.logger: 01-12 03:40:13] {2218} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 01-12 03:40:14] {2391} INFO -  at 7.2s,	estimator lgbm's best error=0.1540,	best estimator lgbm's best error=0.1540
# [flaml.automl.logger: 01-12 03:40:14] {2218} INFO - iteration 4, current learner xgboost
# [flaml.automl.logger: 01-12 03:40:15] {2391} INFO -  at 8.3s,	estimator xgboost's best error=0.1516,	best estimator xgboost's best error=0.1516
# [flaml.automl.logger: 01-12 03:40:15] {2218} INFO - iteration 5, current learner xgboost
# [flaml.automl.logger: 01-12 03:40:16] {2391} INFO -  at 9.1s,	estimator xgboost's best error=0.1516,	best estimator xgboost's best error=0.1516
# [flaml.automl.logger: 01-12 03:40:16] {2218} INFO - iteration 6, current learner xgboost
# [flaml.automl.logger: 01-12 03:40:18] {2391} INFO -  at 11.3s,	estimator xgboost's best error=0.1309,	best estimator xgboost's best error=0.1309
# [flaml.automl.logger: 01-12 03:40:18] {2218} INFO - iteration 7, current learner xgboost
# [flaml.automl.logger: 01-12 03:40:19] {2391} INFO -  at 12.4s,	estimator xgboost's best error=0.1309,	best estimator xgboost's best error=0.1309
# [flaml.automl.logger: 01-12 03:40:19] {2218} INFO - iteration 8, current learner xgboost
# [flaml.automl.logger: 01-12 03:40:21] {2391} INFO -  at 14.4s,	estimator xgboost's best error=0.1237,	best estimator xgboost's best error=0.1237
# [flaml.automl.logger: 01-12 03:40:21] {2218} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 01-12 03:40:25] {2391} INFO -  at 18.7s,	estimator lgbm's best error=0.1110,	best estimator lgbm's best error=0.1110
# [flaml.automl.logger: 01-12 03:40:25] {2218} INFO - iteration 10, current learner xgboost
# [flaml.automl.logger: 01-12 03:40:28] {2391} INFO -  at 21.7s,	estimator xgboost's best error=0.0870,	best estimator xgboost's best error=0.0870
# [flaml.automl.logger: 01-12 03:40:28] {2218} INFO - iteration 11, current learner xgboost
# [flaml.automl.logger: 01-12 03:40:35] {2391} INFO -  at 28.5s,	estimator xgboost's best error=0.0870,	best estimator xgboost's best error=0.0870
# [flaml.automl.logger: 01-12 03:40:35] {2218} INFO - iteration 12, current learner extra_tree
# [flaml.automl.logger: 01-12 03:40:36] {2391} INFO -  at 29.3s,	estimator extra_tree's best error=0.1619,	best estimator xgboost's best error=0.0870
# [flaml.automl.logger: 01-12 03:40:36] {2218} INFO - iteration 13, current learner extra_tree
# [flaml.automl.logger: 01-12 03:40:38] {2391} INFO -  at 31.3s,	estimator extra_tree's best error=0.1475,	best estimator xgboost's best error=0.0870
# [flaml.automl.logger: 01-12 03:40:38] {2218} INFO - iteration 14, current learner extra_tree
# [flaml.automl.logger: 01-12 03:40:38] {2391} INFO -  at 32.0s,	estimator extra_tree's best error=0.1475,	best estimator xgboost's best error=0.0870
# [flaml.automl.logger: 01-12 03:40:38] {2218} INFO - iteration 15, current learner lgbm
# [flaml.automl.logger: 01-12 03:40:40] {2391} INFO -  at 33.9s,	estimator lgbm's best error=0.1110,	best estimator xgboost's best error=0.0870
# [flaml.automl.logger: 01-12 03:40:40] {2218} INFO - iteration 16, current learner extra_tree
# [flaml.automl.logger: 01-12 03:40:41] {2391} INFO -  at 34.5s,	estimator extra_tree's best error=0.1475,	best estimator xgboost's best error=0.0870
# [flaml.automl.logger: 01-12 03:40:41] {2218} INFO - iteration 17, current learner xgboost
# [flaml.automl.logger: 01-12 03:40:43] {2391} INFO -  at 36.1s,	estimator xgboost's best error=0.0856,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:40:43] {2218} INFO - iteration 18, current learner extra_tree
# [flaml.automl.logger: 01-12 03:40:46] {2391} INFO -  at 39.5s,	estimator extra_tree's best error=0.1118,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:40:46] {2218} INFO - iteration 19, current learner rf
# [flaml.automl.logger: 01-12 03:40:47] {2391} INFO -  at 40.3s,	estimator rf's best error=0.1818,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:40:47] {2218} INFO - iteration 20, current learner rf
# [flaml.automl.logger: 01-12 03:40:48] {2391} INFO -  at 41.9s,	estimator rf's best error=0.1477,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:40:48] {2218} INFO - iteration 21, current learner rf
# [flaml.automl.logger: 01-12 03:40:49] {2391} INFO -  at 42.6s,	estimator rf's best error=0.1477,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:40:49] {2218} INFO - iteration 22, current learner rf
# [flaml.automl.logger: 01-12 03:40:50] {2391} INFO -  at 43.6s,	estimator rf's best error=0.1477,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:40:50] {2218} INFO - iteration 23, current learner rf
# [flaml.automl.logger: 01-12 03:40:57] {2391} INFO -  at 50.3s,	estimator rf's best error=0.1205,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:40:57] {2218} INFO - iteration 24, current learner extra_tree
# [flaml.automl.logger: 01-12 03:40:59] {2391} INFO -  at 53.0s,	estimator extra_tree's best error=0.1118,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:40:59] {2218} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 01-12 03:41:05] {2391} INFO -  at 58.4s,	estimator extra_tree's best error=0.1118,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:41:05] {2218} INFO - iteration 26, current learner rf
# [flaml.automl.logger: 01-12 03:41:11] {2391} INFO -  at 64.3s,	estimator rf's best error=0.1176,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:41:11] {2218} INFO - iteration 27, current learner lgbm
# [flaml.automl.logger: 01-12 03:41:12] {2391} INFO -  at 65.7s,	estimator lgbm's best error=0.1039,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:41:12] {2218} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 01-12 03:41:14] {2391} INFO -  at 67.4s,	estimator extra_tree's best error=0.1118,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:41:14] {2218} INFO - iteration 29, current learner extra_tree
# [flaml.automl.logger: 01-12 03:41:22] {2391} INFO -  at 76.0s,	estimator extra_tree's best error=0.1105,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:41:22] {2218} INFO - iteration 30, current learner xgboost
# [flaml.automl.logger: 01-12 03:41:25] {2391} INFO -  at 78.3s,	estimator xgboost's best error=0.0856,	best estimator xgboost's best error=0.0856
# [flaml.automl.logger: 01-12 03:41:25] {2218} INFO - iteration 31, current learner xgboost
# [flaml.automl.logger: 01-12 03:41:28] {2391} INFO -  at 81.1s,	estimator xgboost's best error=0.0501,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:41:28] {2218} INFO - iteration 32, current learner xgboost
# [flaml.automl.logger: 01-12 03:41:30] {2391} INFO -  at 84.0s,	estimator xgboost's best error=0.0501,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:41:30] {2218} INFO - iteration 33, current learner lgbm
# [flaml.automl.logger: 01-12 03:41:31] {2391} INFO -  at 85.1s,	estimator lgbm's best error=0.1039,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:41:31] {2218} INFO - iteration 34, current learner xgboost
# [flaml.automl.logger: 01-12 03:41:34] {2391} INFO -  at 87.4s,	estimator xgboost's best error=0.0501,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:41:34] {2218} INFO - iteration 35, current learner rf
# [flaml.automl.logger: 01-12 03:41:41] {2391} INFO -  at 94.9s,	estimator rf's best error=0.1176,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:41:41] {2218} INFO - iteration 36, current learner extra_tree
# [flaml.automl.logger: 01-12 03:41:56] {2391} INFO -  at 109.8s,	estimator extra_tree's best error=0.1105,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:41:56] {2218} INFO - iteration 37, current learner lgbm
# [flaml.automl.logger: 01-12 03:41:57] {2391} INFO -  at 110.9s,	estimator lgbm's best error=0.1039,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:41:57] {2218} INFO - iteration 38, current learner lgbm
# [flaml.automl.logger: 01-12 03:41:59] {2391} INFO -  at 113.0s,	estimator lgbm's best error=0.0977,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:41:59] {2218} INFO - iteration 39, current learner rf
# [flaml.automl.logger: 01-12 03:42:01] {2391} INFO -  at 114.7s,	estimator rf's best error=0.1176,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:42:01] {2218} INFO - iteration 40, current learner lgbm
# [flaml.automl.logger: 01-12 03:42:10] {2391} INFO -  at 123.3s,	estimator lgbm's best error=0.0825,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:42:10] {2218} INFO - iteration 41, current learner lgbm
# [flaml.automl.logger: 01-12 03:42:13] {2391} INFO -  at 127.0s,	estimator lgbm's best error=0.0825,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:42:13] {2218} INFO - iteration 42, current learner xgboost
# [flaml.automl.logger: 01-12 03:42:15] {2391} INFO -  at 128.8s,	estimator xgboost's best error=0.0501,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:42:15] {2218} INFO - iteration 43, current learner lgbm
# [flaml.automl.logger: 01-12 03:42:26] {2391} INFO -  at 139.4s,	estimator lgbm's best error=0.0617,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:42:26] {2218} INFO - iteration 44, current learner extra_tree
# [flaml.automl.logger: 01-12 03:42:31] {2391} INFO -  at 144.3s,	estimator extra_tree's best error=0.1092,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:42:31] {2218} INFO - iteration 45, current learner lgbm
# [flaml.automl.logger: 01-12 03:42:41] {2391} INFO -  at 154.1s,	estimator lgbm's best error=0.0617,	best estimator xgboost's best error=0.0501
# [flaml.automl.logger: 01-12 03:42:41] {2218} INFO - iteration 46, current learner xgboost
# [flaml.automl.logger: 01-12 03:42:45] {2391} INFO -  at 158.5s,	estimator xgboost's best error=0.0478,	best estimator xgboost's best error=0.0478
# [flaml.automl.logger: 01-12 03:42:45] {2218} INFO - iteration 47, current learner lgbm
# [flaml.automl.logger: 01-12 03:42:57] {2391} INFO -  at 170.4s,	estimator lgbm's best error=0.0482,	best estimator xgboost's best error=0.0478
# [flaml.automl.logger: 01-12 03:42:57] {2218} INFO - iteration 48, current learner xgboost
# [flaml.automl.logger: 01-12 03:43:00] {2391} INFO -  at 173.9s,	estimator xgboost's best error=0.0478,	best estimator xgboost's best error=0.0478
# [flaml.automl.logger: 01-12 03:43:00] {2218} INFO - iteration 49, current learner rf
# [flaml.automl.logger: 01-12 03:43:10] {2391} INFO -  at 184.0s,	estimator rf's best error=0.1176,	best estimator xgboost's best error=0.0478
# [flaml.automl.logger: 01-12 03:43:10] {2218} INFO - iteration 50, current learner extra_tree
# [flaml.automl.logger: 01-12 03:43:13] {2391} INFO -  at 187.0s,	estimator extra_tree's best error=0.1015,	best estimator xgboost's best error=0.0478
# [flaml.automl.logger: 01-12 03:43:13] {2218} INFO - iteration 51, current learner lgbm
# [flaml.automl.logger: 01-12 03:44:09] {2391} INFO -  at 242.3s,	estimator lgbm's best error=0.0468,	best estimator lgbm's best error=0.0468
# [flaml.automl.logger: 01-12 03:44:09] {2218} INFO - iteration 52, current learner lgbm
# [flaml.automl.logger: 01-12 03:44:20] {2391} INFO -  at 253.8s,	estimator lgbm's best error=0.0468,	best estimator lgbm's best error=0.0468
# [flaml.automl.logger: 01-12 03:44:20] {2218} INFO - iteration 53, current learner xgboost
# [flaml.automl.logger: 01-12 03:44:31] {2391} INFO -  at 264.9s,	estimator xgboost's best error=0.0463,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:44:31] {2218} INFO - iteration 54, current learner xgboost
# [flaml.automl.logger: 01-12 03:45:02] {2391} INFO -  at 295.3s,	estimator xgboost's best error=0.0463,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:45:02] {2218} INFO - iteration 55, current learner extra_tree
# [flaml.automl.logger: 01-12 03:45:07] {2391} INFO -  at 300.8s,	estimator extra_tree's best error=0.1015,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:45:07] {2218} INFO - iteration 56, current learner rf
# [flaml.automl.logger: 01-12 03:45:16] {2391} INFO -  at 309.3s,	estimator rf's best error=0.1176,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:45:16] {2218} INFO - iteration 57, current learner lgbm
# [flaml.automl.logger: 01-12 03:46:37] {2391} INFO -  at 390.4s,	estimator lgbm's best error=0.0468,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:46:37] {2218} INFO - iteration 58, current learner extra_tree
# [flaml.automl.logger: 01-12 03:46:39] {2391} INFO -  at 392.7s,	estimator extra_tree's best error=0.1007,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:46:39] {2218} INFO - iteration 59, current learner xgboost
# [flaml.automl.logger: 01-12 03:46:41] {2391} INFO -  at 394.8s,	estimator xgboost's best error=0.0463,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:46:41] {2218} INFO - iteration 60, current learner extra_tree
# [flaml.automl.logger: 01-12 03:46:44] {2391} INFO -  at 397.9s,	estimator extra_tree's best error=0.1007,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:46:44] {2218} INFO - iteration 61, current learner xgboost
# [flaml.automl.logger: 01-12 03:46:52] {2391} INFO -  at 405.6s,	estimator xgboost's best error=0.0463,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:46:52] {2218} INFO - iteration 62, current learner extra_tree
# [flaml.automl.logger: 01-12 03:46:54] {2391} INFO -  at 407.2s,	estimator extra_tree's best error=0.1007,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:46:54] {2218} INFO - iteration 63, current learner extra_tree
# [flaml.automl.logger: 01-12 03:46:56] {2391} INFO -  at 409.6s,	estimator extra_tree's best error=0.0853,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:46:56] {2218} INFO - iteration 64, current learner xgboost
# [flaml.automl.logger: 01-12 03:47:10] {2391} INFO -  at 423.7s,	estimator xgboost's best error=0.0463,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:47:10] {2218} INFO - iteration 65, current learner extra_tree
# [flaml.automl.logger: 01-12 03:47:17] {2391} INFO -  at 430.1s,	estimator extra_tree's best error=0.0853,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:47:17] {2218} INFO - iteration 66, current learner extra_tree
# [flaml.automl.logger: 01-12 03:47:19] {2391} INFO -  at 432.8s,	estimator extra_tree's best error=0.0770,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:47:19] {2218} INFO - iteration 67, current learner extra_tree
# [flaml.automl.logger: 01-12 03:47:20] {2391} INFO -  at 434.0s,	estimator extra_tree's best error=0.0770,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:47:20] {2218} INFO - iteration 68, current learner xgboost
# [flaml.automl.logger: 01-12 03:47:35] {2391} INFO -  at 448.6s,	estimator xgboost's best error=0.0463,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:47:35] {2218} INFO - iteration 69, current learner extra_tree
# [flaml.automl.logger: 01-12 03:47:38] {2391} INFO -  at 451.2s,	estimator extra_tree's best error=0.0607,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:47:38] {2218} INFO - iteration 70, current learner extra_tree
# [flaml.automl.logger: 01-12 03:47:40] {2391} INFO -  at 453.2s,	estimator extra_tree's best error=0.0607,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:47:40] {2218} INFO - iteration 71, current learner extra_tree
# [flaml.automl.logger: 01-12 03:47:44] {2391} INFO -  at 457.7s,	estimator extra_tree's best error=0.0553,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:47:44] {2218} INFO - iteration 72, current learner extra_tree
# [flaml.automl.logger: 01-12 03:47:56] {2391} INFO -  at 469.5s,	estimator extra_tree's best error=0.0505,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:47:56] {2218} INFO - iteration 73, current learner extra_tree
# [flaml.automl.logger: 01-12 03:48:01] {2391} INFO -  at 474.4s,	estimator extra_tree's best error=0.0505,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:48:01] {2218} INFO - iteration 74, current learner extra_tree
# [flaml.automl.logger: 01-12 03:48:09] {2391} INFO -  at 482.2s,	estimator extra_tree's best error=0.0505,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:48:09] {2218} INFO - iteration 75, current learner rf
# [flaml.automl.logger: 01-12 03:48:11] {2391} INFO -  at 484.6s,	estimator rf's best error=0.1176,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:48:11] {2218} INFO - iteration 76, current learner rf
# [flaml.automl.logger: 01-12 03:48:14] {2391} INFO -  at 487.7s,	estimator rf's best error=0.1062,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:48:14] {2218} INFO - iteration 77, current learner extra_tree
# [flaml.automl.logger: 01-12 03:48:27] {2391} INFO -  at 500.4s,	estimator extra_tree's best error=0.0504,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:48:27] {2218} INFO - iteration 78, current learner rf
# [flaml.automl.logger: 01-12 03:48:32] {2391} INFO -  at 505.4s,	estimator rf's best error=0.1062,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:48:32] {2218} INFO - iteration 79, current learner rf
# [flaml.automl.logger: 01-12 03:48:35] {2391} INFO -  at 508.5s,	estimator rf's best error=0.0908,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:48:35] {2218} INFO - iteration 80, current learner extra_tree
# [flaml.automl.logger: 01-12 03:48:42] {2391} INFO -  at 515.9s,	estimator extra_tree's best error=0.0504,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:48:42] {2218} INFO - iteration 81, current learner rf
# [flaml.automl.logger: 01-12 03:48:46] {2391} INFO -  at 519.3s,	estimator rf's best error=0.0908,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:48:46] {2218} INFO - iteration 82, current learner lgbm
# [flaml.automl.logger: 01-12 03:49:24] {2391} INFO -  at 557.9s,	estimator lgbm's best error=0.0465,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:49:24] {2218} INFO - iteration 83, current learner rf
# [flaml.automl.logger: 01-12 03:49:26] {2391} INFO -  at 559.4s,	estimator rf's best error=0.0908,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:49:26] {2218} INFO - iteration 84, current learner extra_tree
# [flaml.automl.logger: 01-12 03:49:42] {2391} INFO -  at 576.0s,	estimator extra_tree's best error=0.0497,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:49:42] {2218} INFO - iteration 85, current learner rf
# [flaml.automl.logger: 01-12 03:49:45] {2391} INFO -  at 578.8s,	estimator rf's best error=0.0660,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:49:45] {2218} INFO - iteration 86, current learner rf
# [flaml.automl.logger: 01-12 03:49:52] {2391} INFO -  at 585.7s,	estimator rf's best error=0.0660,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:49:52] {2218} INFO - iteration 87, current learner rf
# [flaml.automl.logger: 01-12 03:49:54] {2391} INFO -  at 587.6s,	estimator rf's best error=0.0640,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:49:54] {2218} INFO - iteration 88, current learner rf
# [flaml.automl.logger: 01-12 03:49:56] {2391} INFO -  at 589.1s,	estimator rf's best error=0.0640,	best estimator xgboost's best error=0.0463
# [flaml.automl.logger: 01-12 03:49:56] {2525} INFO - [('xgboost', {'n_jobs': -1, 'n_estimators': 91, 'max_leaves': 147, 'min_child_weight': 0.04742539395483736, 'learning_rate': 0.14016333421486576, 'subsample': 1.0, 'colsample_bylevel': 0.5909530535241774, 'colsample_bytree': 1.0, 'reg_alpha': 2.766143654293635, 'reg_lambda': 0.04798910206552531, 'max_depth': 0, 'grow_policy': 'lossguide', 'tree_method': 'hist', 'verbosity': 0}), ('lgbm', {'n_jobs': -1, 'n_estimators': 620, 'num_leaves': 56, 'min_child_samples': 13, 'learning_rate': 0.13005562530099612, 'colsample_bytree': 0.8147536212730734, 'reg_alpha': 0.028312467126347798, 'reg_lambda': 0.47580189025240327, 'max_bin': 7, 'verbose': -1}), ('extra_tree', {'n_jobs': -1, 'n_estimators': 42, 'max_features': 0.32687800391245114, 'criterion': 'entropy', 'max_leaf_nodes': 32767, 'random_state': 12032022, 'verbose': 0}), ('rf', {'n_jobs': -1, 'n_estimators': 4, 'max_features': 0.3742008344078938, 'criterion': 'gini', 'max_leaf_nodes': 648, 'random_state': 12032022, 'verbose': 0})]
# [flaml.automl.logger: 01-12 03:49:56] {2568} INFO - Building ensemble with tuned estimators
# [flaml.automl.logger: 01-12 03:51:12] {2574} INFO - ensemble: StackingClassifier(estimators=[('xgboost',
#                                 <flaml.automl.model.XGBoostSklearnEstimator object at 0x78fcfcb18700>),
#                                ('lgbm',
#                                 <flaml.automl.model.LGBMEstimator object at 0x78fce8e266b0>),
#                                ('extra_tree',
#                                 <flaml.automl.model.ExtraTreesEstimator object at 0x78fce8e86800>),
#                                ('rf',
#                                 <flaml.automl.model.RandomForestEstimator object at 0x78fce8e858d0>)],
#                    n_jobs=1, passthrough=True)
# [flaml.automl.logger: 01-12 03:51:12] {1930} INFO - fit succeeded
# [flaml.automl.logger: 01-12 03:51:12] {1931} INFO - Time taken to find the best model: 264.8883128166199

# %%
# retrieve best config and best learner
print('Best ML leaner:', automl4.best_estimator)
print('Best hyperparmeter config:', automl4.best_config)
print('Best accuracy on validation data: {0:.4g}'.format(1-automl4.best_loss))
print('Training duration of best run: {0:.4g} s'.format(automl4.best_config_train_time))
# Out:
# Best ML leaner: xgboost
# Best hyperparmeter config: {'n_estimators': 91, 'max_leaves': 147, 'min_child_weight': 0.04742539395483736, 'learning_rate': 0.14016333421486576, 'subsample': 1.0, 'colsample_bylevel': 0.5909530535241774, 'colsample_bytree': 1.0, 'reg_alpha': 2.766143654293635, 'reg_lambda': 0.04798910206552531}
# Best accuracy on validation data: 0.9537
# Training duration of best run: 11.05 s

# %% [markdown]
# ##### Predict for train data using CV

# %%
# compute predictions of testing dataset'''
y_pred4 = automl4.predict(test_x)
y_pred_proba4 = automl4.predict_proba(test_x)[:,1]

# %%
# compute different metric values on testing dataset'''
from flaml.ml import sklearn_metric_loss_score
print('accuracy', '=', 1 - sklearn_metric_loss_score('accuracy', y_pred4, y_test))
print('roc_auc', '=', 1 - sklearn_metric_loss_score('roc_auc', y_pred_proba4, y_test))
print('log_loss', '=', sklearn_metric_loss_score('log_loss', y_pred_proba4, y_test))
# Out:
# accuracy = 0.8783993783993784
# roc_auc = 0.9472366056108122
# log_loss = 0.2946694316508978

# %%
predict(automl4, 'automl4', pred_x)

# %% [markdown]
# #### **Model 5: Unscaled imputed data, KNNImputer, Seat_Class, ArrivalDelay Binned**

# %%
train_x = X_train_imputed.copy()
train_x.drop('Seat_Class', axis = 1, inplace = True)
train_x['Arrival_Delay_Bins'] = pd.cut(train_x['Arrival_Delay_in_Mins'], bins = [-float('inf'), 0, 10, 120, float('inf')], labels = ['0', '1-10', '11-120', '121+'])
train_x['Arrival_Delay_Bins'].replace(['0', '1-10', '11-120', '121+'], [0, 1, 2, 3], inplace = True)
train_x.drop('Arrival_Delay_in_Mins', axis = 1, inplace = True)

test_x = X_test_imputed.copy()
test_x.drop('Seat_Class', axis = 1, inplace = True)
test_x['Arrival_Delay_Bins'] = pd.cut(test_x['Arrival_Delay_in_Mins'], bins = [-float('inf'), 0, 10, 120, float('inf')], labels = ['0', '1-10', '11-120', '121+'])
test_x['Arrival_Delay_Bins'].replace(['0', '1-10', '11-120', '121+'], [0, 1, 2, 3], inplace = True)
test_x.drop('Arrival_Delay_in_Mins', axis = 1, inplace = True)

pred_x = pd.concat([df_pred_orig['ID'], df_pred_imputed.copy()], axis = 1)
pred_x.drop('Seat_Class', axis = 1, inplace = True)
pred_x['Arrival_Delay_Bins'] = pd.cut(pred_x['Arrival_Delay_in_Mins'], bins = [-float('inf'), 0, 10, 120, float('inf')], labels = ['0', '1-10', '11-120', '121+'])
pred_x['Arrival_Delay_Bins'].replace(['0', '1-10', '11-120', '121+'], [0, 1, 2, 3], inplace = True)
pred_x.drop('Arrival_Delay_in_Mins', axis = 1, inplace = True)

# %%
train_x.shape
# Out:
# (66065, 22)

# %%
# declare model for logistic regression
automl5 = AutoML()

# setting for AutoML
settings = {
    "time_budget": 600,  # total running time in seconds
    "metric": 'accuracy',
    # check the documentation for options of metrics (https://microsoft.github.io/FLAML/docs/Use-Cases/Task-Oriented-AutoML#optimization-metric)
    "task": 'classification',  # task type
    "estimator_list": ['xgboost', 'xgb_limitdepth', 'rf', 'lgbm', 'lrl1', 'lrl2', 'catboost', 'extra_tree', 'kneighbor'],
    "log_file_name": '/content/drive/MyDrive/DScourse/Hackathon/AutoML/hackathon1.log',  # flaml log file
    #"ensemble": True,
    "seed": 13,    # random seed
}

# %%
# The main flaml automl API
automl5.fit(X_train=train_x, y_train=y_train, **settings)
# Out:
# [flaml.automl.logger: 01-12 04:04:27] {1679} INFO - task = classification
# [flaml.automl.logger: 01-12 04:04:27] {1690} INFO - Evaluation method: cv
# [flaml.automl.logger: 01-12 04:04:27] {1788} INFO - Minimizing error metric: 1-accuracy
# [flaml.automl.logger: 01-12 04:04:27] {1900} INFO - List of ML learners in AutoML Run: ['xgboost', 'xgb_limitdepth', 'rf', 'lgbm', 'lrl1', 'lrl2', 'catboost', 'extra_tree', 'kneighbor']
# [flaml.automl.logger: 01-12 04:04:27] {2218} INFO - iteration 0, current learner xgboost
# [flaml.automl.logger: 01-12 04:04:28] {2344} INFO - Estimated sufficient time budget=9131s. Estimated necessary time budget=171s.
# [flaml.automl.logger: 01-12 04:04:28] {2391} INFO -  at 1.3s,	estimator xgboost's best error=0.1547,	best estimator xgboost's best error=0.1547
# [flaml.automl.logger: 01-12 04:04:28] {2218} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 01-12 04:04:29] {2391} INFO -  at 2.2s,	estimator lgbm's best error=0.1547,	best estimator xgboost's best error=0.1547
# [flaml.automl.logger: 01-12 04:04:29] {2218} INFO - iteration 2, current learner xgboost
# [flaml.automl.logger: 01-12 04:04:30] {2391} INFO -  at 3.4s,	estimator xgboost's best error=0.1503,	best estimator xgboost's best error=0.1503
# [flaml.automl.logger: 01-12 04:04:30] {2218} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 01-12 04:04:31] {2391} INFO -  at 4.9s,	estimator lgbm's best error=0.1540,	best estimator xgboost's best error=0.1503
# [flaml.automl.logger: 01-12 04:04:31] {2218} INFO - iteration 4, current learner extra_tree
# [flaml.automl.logger: 01-12 04:04:32] {2391} INFO -  at 5.8s,	estimator extra_tree's best error=0.1892,	best estimator xgboost's best error=0.1503
# [flaml.automl.logger: 01-12 04:04:32] {2218} INFO - iteration 5, current learner xgboost
# [flaml.automl.logger: 01-12 04:04:35] {2391} INFO -  at 8.8s,	estimator xgboost's best error=0.1503,	best estimator xgboost's best error=0.1503
# [flaml.automl.logger: 01-12 04:04:35] {2218} INFO - iteration 6, current learner extra_tree
# [flaml.automl.logger: 01-12 04:04:37] {2391} INFO -  at 10.1s,	estimator extra_tree's best error=0.1467,	best estimator extra_tree's best error=0.1467
# [flaml.automl.logger: 01-12 04:04:37] {2218} INFO - iteration 7, current learner rf
# [flaml.automl.logger: 01-12 04:04:37] {2391} INFO -  at 10.8s,	estimator rf's best error=0.1704,	best estimator extra_tree's best error=0.1467
# [flaml.automl.logger: 01-12 04:04:37] {2218} INFO - iteration 8, current learner rf
# [flaml.automl.logger: 01-12 04:04:39] {2391} INFO -  at 12.5s,	estimator rf's best error=0.1481,	best estimator extra_tree's best error=0.1467
# [flaml.automl.logger: 01-12 04:04:39] {2218} INFO - iteration 9, current learner xgboost
# [flaml.automl.logger: 01-12 04:04:41] {2391} INFO -  at 14.7s,	estimator xgboost's best error=0.1305,	best estimator xgboost's best error=0.1305
# [flaml.automl.logger: 01-12 04:04:41] {2218} INFO - iteration 10, current learner rf
# [flaml.automl.logger: 01-12 04:04:42] {2391} INFO -  at 15.4s,	estimator rf's best error=0.1481,	best estimator xgboost's best error=0.1305
# [flaml.automl.logger: 01-12 04:04:42] {2218} INFO - iteration 11, current learner rf
# [flaml.automl.logger: 01-12 04:04:43] {2391} INFO -  at 16.3s,	estimator rf's best error=0.1481,	best estimator xgboost's best error=0.1305
# [flaml.automl.logger: 01-12 04:04:43] {2218} INFO - iteration 12, current learner extra_tree
# [flaml.automl.logger: 01-12 04:04:43] {2391} INFO -  at 16.9s,	estimator extra_tree's best error=0.1467,	best estimator xgboost's best error=0.1305
# [flaml.automl.logger: 01-12 04:04:43] {2218} INFO - iteration 13, current learner extra_tree
# [flaml.automl.logger: 01-12 04:04:44] {2391} INFO -  at 17.6s,	estimator extra_tree's best error=0.1467,	best estimator xgboost's best error=0.1305
# [flaml.automl.logger: 01-12 04:04:44] {2218} INFO - iteration 14, current learner lgbm
# [flaml.automl.logger: 01-12 04:04:45] {2391} INFO -  at 18.5s,	estimator lgbm's best error=0.1540,	best estimator xgboost's best error=0.1305
# [flaml.automl.logger: 01-12 04:04:45] {2218} INFO - iteration 15, current learner extra_tree
# [flaml.automl.logger: 01-12 04:04:51] {2391} INFO -  at 24.1s,	estimator extra_tree's best error=0.1111,	best estimator extra_tree's best error=0.1111
# [flaml.automl.logger: 01-12 04:04:51] {2218} INFO - iteration 16, current learner xgboost
# [flaml.automl.logger: 01-12 04:04:52] {2391} INFO -  at 25.2s,	estimator xgboost's best error=0.1305,	best estimator extra_tree's best error=0.1111
# [flaml.automl.logger: 01-12 04:04:52] {2218} INFO - iteration 17, current learner extra_tree
# [flaml.automl.logger: 01-12 04:04:55] {2391} INFO -  at 28.0s,	estimator extra_tree's best error=0.1111,	best estimator extra_tree's best error=0.1111
# [flaml.automl.logger: 01-12 04:04:55] {2218} INFO - iteration 18, current learner xgboost
# [flaml.automl.logger: 01-12 04:04:56] {2391} INFO -  at 29.9s,	estimator xgboost's best error=0.1225,	best estimator extra_tree's best error=0.1111
# [flaml.automl.logger: 01-12 04:04:56] {2218} INFO - iteration 19, current learner extra_tree
# [flaml.automl.logger: 01-12 04:05:03] {2391} INFO -  at 36.3s,	estimator extra_tree's best error=0.1111,	best estimator extra_tree's best error=0.1111
# [flaml.automl.logger: 01-12 04:05:03] {2218} INFO - iteration 20, current learner rf
# [flaml.automl.logger: 01-12 04:05:09] {2391} INFO -  at 42.1s,	estimator rf's best error=0.1160,	best estimator extra_tree's best error=0.1111
# [flaml.automl.logger: 01-12 04:05:09] {2218} INFO - iteration 21, current learner rf
# [flaml.automl.logger: 01-12 04:05:13] {2391} INFO -  at 46.2s,	estimator rf's best error=0.1160,	best estimator extra_tree's best error=0.1111
# [flaml.automl.logger: 01-12 04:05:13] {2218} INFO - iteration 22, current learner xgboost
# [flaml.automl.logger: 01-12 04:05:19] {2391} INFO -  at 52.5s,	estimator xgboost's best error=0.0864,	best estimator xgboost's best error=0.0864
# [flaml.automl.logger: 01-12 04:05:19] {2218} INFO - iteration 23, current learner xgboost
# [flaml.automl.logger: 01-12 04:05:26] {2391} INFO -  at 59.1s,	estimator xgboost's best error=0.0864,	best estimator xgboost's best error=0.0864
# [flaml.automl.logger: 01-12 04:05:26] {2218} INFO - iteration 24, current learner rf
# [flaml.automl.logger: 01-12 04:05:35] {2391} INFO -  at 68.9s,	estimator rf's best error=0.1138,	best estimator xgboost's best error=0.0864
# [flaml.automl.logger: 01-12 04:05:35] {2218} INFO - iteration 25, current learner extra_tree
# [flaml.automl.logger: 01-12 04:05:37] {2391} INFO -  at 70.7s,	estimator extra_tree's best error=0.1111,	best estimator xgboost's best error=0.0864
# [flaml.automl.logger: 01-12 04:05:37] {2218} INFO - iteration 26, current learner xgboost
# [flaml.automl.logger: 01-12 04:05:39] {2391} INFO -  at 72.3s,	estimator xgboost's best error=0.0837,	best estimator xgboost's best error=0.0837
# [flaml.automl.logger: 01-12 04:05:39] {2218} INFO - iteration 27, current learner xgboost
# [flaml.automl.logger: 01-12 04:05:40] {2391} INFO -  at 73.4s,	estimator xgboost's best error=0.0837,	best estimator xgboost's best error=0.0837
# [flaml.automl.logger: 01-12 04:05:40] {2218} INFO - iteration 28, current learner extra_tree
# [flaml.automl.logger: 01-12 04:05:49] {2391} INFO -  at 82.9s,	estimator extra_tree's best error=0.1111,	best estimator xgboost's best error=0.0837
# [flaml.automl.logger: 01-12 04:05:49] {2218} INFO - iteration 29, current learner extra_tree
# [flaml.automl.logger: 01-12 04:05:55] {2391} INFO -  at 88.6s,	estimator extra_tree's best error=0.1111,	best estimator xgboost's best error=0.0837
# [flaml.automl.logger: 01-12 04:05:55] {2218} INFO - iteration 30, current learner xgboost
# [flaml.automl.logger: 01-12 04:05:58] {2391} INFO -  at 91.2s,	estimator xgboost's best error=0.0499,	best estimator xgboost's best error=0.0499
# [flaml.automl.logger: 01-12 04:05:58] {2218} INFO - iteration 31, current learner xgboost
# [flaml.automl.logger: 01-12 04:06:04] {2391} INFO -  at 97.5s,	estimator xgboost's best error=0.0499,	best estimator xgboost's best error=0.0499
# [flaml.automl.logger: 01-12 04:06:04] {2218} INFO - iteration 32, current learner xgboost
# [flaml.automl.logger: 01-12 04:06:06] {2391} INFO -  at 99.9s,	estimator xgboost's best error=0.0499,	best estimator xgboost's best error=0.0499
# [flaml.automl.logger: 01-12 04:06:06] {2218} INFO - iteration 33, current learner catboost
# [flaml.automl.logger: 01-12 04:07:30] {2391} INFO -  at 184.0s,	estimator catboost's best error=0.0489,	best estimator catboost's best error=0.0489
# [flaml.automl.logger: 01-12 04:07:30] {2218} INFO - iteration 34, current learner catboost
# [flaml.automl.logger: 01-12 04:09:01] {2391} INFO -  at 274.9s,	estimator catboost's best error=0.0481,	best estimator catboost's best error=0.0481
# [flaml.automl.logger: 01-12 04:09:01] {2218} INFO - iteration 35, current learner xgboost
# [flaml.automl.logger: 01-12 04:09:03] {2391} INFO -  at 276.7s,	estimator xgboost's best error=0.0499,	best estimator catboost's best error=0.0481
# [flaml.automl.logger: 01-12 04:09:03] {2218} INFO - iteration 36, current learner xgboost
# [flaml.automl.logger: 01-12 04:09:08] {2391} INFO -  at 281.1s,	estimator xgboost's best error=0.0474,	best estimator xgboost's best error=0.0474
# [flaml.automl.logger: 01-12 04:09:08] {2218} INFO - iteration 37, current learner lrl2
# INFO:flaml.tune.searcher.blendsearch:No low-cost partial config given to the search algorithm. For cost-frugal search, consider providing low-cost values for cost-related hps via 'low_cost_partial_config'. More info can be found at https://microsoft.github.io/FLAML/docs/FAQ#about-low_cost_partial_config-in-tune
# [flaml.automl.logger: 01-12 04:09:18] {2391} INFO -  at 291.1s,	estimator lrl2's best error=0.2262,	best estimator xgboost's best error=0.0474
# [flaml.automl.logger: 01-12 04:09:18] {2218} INFO - iteration 38, current learner extra_tree
# [flaml.automl.logger: 01-12 04:09:20] {2391} INFO -  at 293.4s,	estimator extra_tree's best error=0.1111,	best estimator xgboost's best error=0.0474
# [flaml.automl.logger: 01-12 04:09:20] {2218} INFO - iteration 39, current learner lrl2
# [flaml.automl.logger: 01-12 04:09:29] {2391} INFO -  at 303.0s,	estimator lrl2's best error=0.2252,	best estimator xgboost's best error=0.0474
# [flaml.automl.logger: 01-12 04:09:30] {2218} INFO - iteration 40, current learner xgboost
# [flaml.automl.logger: 01-12 04:09:33] {2391} INFO -  at 306.1s,	estimator xgboost's best error=0.0474,	best estimator xgboost's best error=0.0474
# [flaml.automl.logger: 01-12 04:09:33] {2218} INFO - iteration 41, current learner xgboost
# [flaml.automl.logger: 01-12 04:09:43] {2391} INFO -  at 316.9s,	estimator xgboost's best error=0.0472,	best estimator xgboost's best error=0.0472
# [flaml.automl.logger: 01-12 04:09:43] {2218} INFO - iteration 42, current learner xgboost
# [flaml.automl.logger: 01-12 04:10:14] {2391} INFO -  at 347.9s,	estimator xgboost's best error=0.0469,	best estimator xgboost's best error=0.0469
# [flaml.automl.logger: 01-12 04:10:14] {2218} INFO - iteration 43, current learner kneighbor
# [flaml.automl.logger: 01-12 04:10:33] {2391} INFO -  at 366.3s,	estimator kneighbor's best error=0.3039,	best estimator xgboost's best error=0.0469
# [flaml.automl.logger: 01-12 04:10:33] {2218} INFO - iteration 44, current learner kneighbor
# [flaml.automl.logger: 01-12 04:10:51] {2391} INFO -  at 384.9s,	estimator kneighbor's best error=0.3035,	best estimator xgboost's best error=0.0469
# [flaml.automl.logger: 01-12 04:10:51] {2218} INFO - iteration 45, current learner xgboost
# [flaml.automl.logger: 01-12 04:11:02] {2391} INFO -  at 395.6s,	estimator xgboost's best error=0.0468,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 04:11:02] {2218} INFO - iteration 46, current learner xgboost
# [flaml.automl.logger: 01-12 04:11:10] {2391} INFO -  at 403.4s,	estimator xgboost's best error=0.0468,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 04:11:10] {2218} INFO - iteration 47, current learner extra_tree
# [flaml.automl.logger: 01-12 04:11:12] {2391} INFO -  at 406.0s,	estimator extra_tree's best error=0.1064,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 04:11:12] {2218} INFO - iteration 48, current learner xgboost
# [flaml.automl.logger: 01-12 04:11:26] {2391} INFO -  at 419.9s,	estimator xgboost's best error=0.0468,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 04:11:26] {2218} INFO - iteration 49, current learner xgboost
# [flaml.automl.logger: 01-12 04:11:41] {2391} INFO -  at 434.2s,	estimator xgboost's best error=0.0468,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 04:11:41] {2218} INFO - iteration 50, current learner xgboost
# [flaml.automl.logger: 01-12 04:11:45] {2391} INFO -  at 438.7s,	estimator xgboost's best error=0.0468,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 04:11:45] {2218} INFO - iteration 51, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 04:11:46] {2391} INFO -  at 439.8s,	estimator xgb_limitdepth's best error=0.0736,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 04:11:46] {2218} INFO - iteration 52, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 04:11:52] {2391} INFO -  at 445.4s,	estimator xgb_limitdepth's best error=0.0537,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 04:11:52] {2218} INFO - iteration 53, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 04:11:53] {2391} INFO -  at 446.6s,	estimator xgb_limitdepth's best error=0.0537,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 04:11:53] {2218} INFO - iteration 54, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 04:12:01] {2391} INFO -  at 454.2s,	estimator xgb_limitdepth's best error=0.0501,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 04:12:01] {2218} INFO - iteration 55, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 04:12:08] {2391} INFO -  at 461.7s,	estimator xgb_limitdepth's best error=0.0501,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 04:12:08] {2218} INFO - iteration 56, current learner xgboost
# [flaml.automl.logger: 01-12 04:12:10] {2391} INFO -  at 463.1s,	estimator xgboost's best error=0.0468,	best estimator xgboost's best error=0.0468
# [flaml.automl.logger: 01-12 04:12:10] {2218} INFO - iteration 57, current learner xgboost
# [flaml.automl.logger: 01-12 04:13:11] {2391} INFO -  at 524.8s,	estimator xgboost's best error=0.0464,	best estimator xgboost's best error=0.0464
# [flaml.automl.logger: 01-12 04:13:11] {2218} INFO - iteration 58, current learner xgboost
# [flaml.automl.logger: 01-12 04:14:30] {2391} INFO -  at 603.4s,	estimator xgboost's best error=0.0464,	best estimator xgboost's best error=0.0464
# [flaml.automl.logger: 01-12 04:14:44] {2627} INFO - retrain xgboost for 14.4s
# [flaml.automl.logger: 01-12 04:14:44] {2630} INFO - retrained model: XGBClassifier(base_score=None, booster=None, callbacks=[],
#               colsample_bylevel=0.5735740572022017, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy='lossguide', importance_type=None,
#               interaction_constraints=None, learning_rate=0.1439509194030956,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=0, max_leaves=208,
#               min_child_weight=0.10024508277504081, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=737,
#               n_jobs=-1, num_parallel_tree=None, random_state=None, ...)
# [flaml.automl.logger: 01-12 04:14:44] {1930} INFO - fit succeeded
# [flaml.automl.logger: 01-12 04:14:44] {1931} INFO - Time taken to find the best model: 524.7742195129395

# %%
# retrieve best config and best learner
print('Best ML leaner:', automl5.best_estimator)
print('Best hyperparmeter config:', automl5.best_config)
print('Best accuracy on validation data: {0:.4g}'.format(1-automl5.best_loss))
print('Training duration of best run: {0:.4g} s'.format(automl5.best_config_train_time))
# Out:
# Best ML leaner: xgboost
# Best hyperparmeter config: {'n_estimators': 737, 'max_leaves': 208, 'min_child_weight': 0.10024508277504081, 'learning_rate': 0.1439509194030956, 'subsample': 0.913964501756151, 'colsample_bylevel': 0.5735740572022017, 'colsample_bytree': 1.0, 'reg_alpha': 0.6572032565494386, 'reg_lambda': 0.029197533116278977}
# Best accuracy on validation data: 0.9536
# Training duration of best run: 14.37 s

# %%
# obtain best model
automl5.model.estimator
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=[],
#               colsample_bylevel=0.5735740572022017, colsample_bynode=None,
#               colsample_bytree=1.0, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy='lossguide', importance_type=None,
#               interaction_constraints=None, learning_rate=0.1439509194030956,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=0, max_leaves=208,
#               min_child_weight=0.10024508277504081, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=737,
#               n_jobs=-1, num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ##### Predict for train data using CV

# %%
# compute predictions of testing dataset'''
y_pred5 = automl5.predict(test_x)
y_pred_proba5 = automl5.predict_proba(test_x)[:,1]

# %%
# compute different metric values on testing dataset'''
from flaml.ml import sklearn_metric_loss_score
print('accuracy', '=', 1 - sklearn_metric_loss_score('accuracy', y_pred5, y_test))
print('roc_auc', '=', 1 - sklearn_metric_loss_score('roc_auc', y_pred_proba5, y_test))
print('log_loss', '=', sklearn_metric_loss_score('log_loss', y_pred_proba5, y_test))
# Out:
# accuracy = 0.9569824115278661
# roc_auc = 0.9933979959585009
# log_loss = 0.12026265805894386

# %%
predict(automl5, 'automl5', pred_x)

# %% [markdown]
# #### **Model 6: Unscaled imputed data, KNNImputer, Seat_Class deleted, TotalDelay**

# %%
train_x = X_train_imputed.copy()
train_x.drop('Seat_Class', axis = 1, inplace = True)
train_x['Total_Delay'] = train_x['Arrival_Delay_in_Mins'] + train_x['Departure_Delay_in_Mins']
#train_x['Arrival_Delay_Bins'] = pd.cut(train_x['Arrival_Delay_in_Mins'], bins = [-float('inf'), 0, 10, 120, float('inf')], labels = ['0', '1-10', '11-120', '121+'])
#train_x['Arrival_Delay_Bins'].replace(['0', '1-10', '11-120', '121+'], [0, 1, 2, 3], inplace = True)
train_x.drop(['Arrival_Delay_in_Mins', 'Departure_Delay_in_Mins'], axis = 1, inplace = True)

test_x = X_test_imputed.copy()
test_x.drop('Seat_Class', axis = 1, inplace = True)
test_x['Total_Delay'] = test_x['Arrival_Delay_in_Mins'] + test_x['Departure_Delay_in_Mins']
#test_x['Arrival_Delay_Bins'] = pd.cut(test_x['Arrival_Delay_in_Mins'], bins = [-float('inf'), 0, 10, 120, float('inf')], labels = ['0', '1-10', '11-120', '121+'])
#test_x['Arrival_Delay_Bins'].replace(['0', '1-10', '11-120', '121+'], [0, 1, 2, 3], inplace = True)
test_x.drop(['Arrival_Delay_in_Mins', 'Departure_Delay_in_Mins'], axis = 1, inplace = True)

pred_x = pd.concat([df_pred_orig['ID'], df_pred_imputed.copy()], axis = 1)
pred_x.drop('Seat_Class', axis = 1, inplace = True)
pred_x['Total_Delay'] = pred_x['Arrival_Delay_in_Mins'] + pred_x['Departure_Delay_in_Mins']
#pred_x['Arrival_Delay_Bins'] = pd.cut(pred_x['Arrival_Delay_in_Mins'], bins = [-float('inf'), 0, 10, 120, float('inf')], labels = ['0', '1-10', '11-120', '121+'])
#pred_x['Arrival_Delay_Bins'].replace(['0', '1-10', '11-120', '121+'], [0, 1, 2, 3], inplace = True)
pred_x.drop(['Arrival_Delay_in_Mins', 'Departure_Delay_in_Mins'], axis = 1, inplace = True)

# %%
train_x.columns
# Out:
# Index(['Gender', 'Customer_Type', 'Age', 'Type_Travel', 'Travel_Class',
#        'Travel_Distance', 'Seat_Comfort', 'Arrival_Time_Convenient',
#        'Catering', 'Platform_Location', 'Onboard_Wifi_Service',
#        'Onboard_Entertainment', 'Online_Support', 'Ease_of_Online_Booking',
#        'Onboard_Service', 'Legroom', 'Baggage_Handling', 'CheckIn_Service',
#        'Cleanliness', 'Online_Boarding', 'Total_Delay'],
#       dtype='object')

# %%
# declare model for logistic regression
automl6 = AutoML()

# setting for AutoML
settings = {
    "time_budget": 600,  # total running time in seconds
    "metric": 'accuracy',
    # check the documentation for options of metrics (https://microsoft.github.io/FLAML/docs/Use-Cases/Task-Oriented-AutoML#optimization-metric)
    "task": 'classification',  # task type
    "estimator_list": ['xgboost', 'xgb_limitdepth', 'rf', 'lgbm', 'lrl1', 'lrl2', 'catboost', 'extra_tree', 'kneighbor'],
    "log_file_name": '/content/drive/MyDrive/DScourse/Hackathon/AutoML/hackathon1.log',  # flaml log file
    #"ensemble": True,
    "seed": 13,    # random seed
}

# %%
# The main flaml automl API
automl6.fit(X_train=train_x, y_train=y_train, **settings)
# Out:
# [flaml.automl.logger: 01-12 04:21:11] {1679} INFO - task = classification
# [flaml.automl.logger: 01-12 04:21:11] {1690} INFO - Evaluation method: cv
# [flaml.automl.logger: 01-12 04:21:11] {1788} INFO - Minimizing error metric: 1-accuracy
# [flaml.automl.logger: 01-12 04:21:11] {1900} INFO - List of ML learners in AutoML Run: ['xgboost', 'xgb_limitdepth', 'rf', 'lgbm', 'lrl1', 'lrl2', 'catboost', 'extra_tree', 'kneighbor']
# [flaml.automl.logger: 01-12 04:21:11] {2218} INFO - iteration 0, current learner xgboost
# [flaml.automl.logger: 01-12 04:21:12] {2344} INFO - Estimated sufficient time budget=9873s. Estimated necessary time budget=185s.
# [flaml.automl.logger: 01-12 04:21:12] {2391} INFO -  at 1.3s,	estimator xgboost's best error=0.1547,	best estimator xgboost's best error=0.1547
# [flaml.automl.logger: 01-12 04:21:12] {2218} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 01-12 04:21:13] {2391} INFO -  at 2.2s,	estimator lgbm's best error=0.1547,	best estimator xgboost's best error=0.1547
# [flaml.automl.logger: 01-12 04:21:13] {2218} INFO - iteration 2, current learner xgboost
# [flaml.automl.logger: 01-12 04:21:14] {2391} INFO -  at 3.3s,	estimator xgboost's best error=0.1511,	best estimator xgboost's best error=0.1511
# [flaml.automl.logger: 01-12 04:21:14] {2218} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 01-12 04:21:18] {2391} INFO -  at 7.7s,	estimator lgbm's best error=0.1540,	best estimator xgboost's best error=0.1511
# [flaml.automl.logger: 01-12 04:21:18] {2218} INFO - iteration 4, current learner xgboost
# [flaml.automl.logger: 01-12 04:21:19] {2391} INFO -  at 8.5s,	estimator xgboost's best error=0.1511,	best estimator xgboost's best error=0.1511
# [flaml.automl.logger: 01-12 04:21:19] {2218} INFO - iteration 5, current learner xgboost
# [flaml.automl.logger: 01-12 04:21:21] {2391} INFO -  at 10.6s,	estimator xgboost's best error=0.1290,	best estimator xgboost's best error=0.1290
# [flaml.automl.logger: 01-12 04:21:21] {2218} INFO - iteration 6, current learner extra_tree
# [flaml.automl.logger: 01-12 04:21:22] {2391} INFO -  at 11.1s,	estimator extra_tree's best error=0.2098,	best estimator xgboost's best error=0.1290
# [flaml.automl.logger: 01-12 04:21:22] {2218} INFO - iteration 7, current learner xgboost
# [flaml.automl.logger: 01-12 04:21:23] {2391} INFO -  at 12.2s,	estimator xgboost's best error=0.1290,	best estimator xgboost's best error=0.1290
# [flaml.automl.logger: 01-12 04:21:23] {2218} INFO - iteration 8, current learner xgboost
# [flaml.automl.logger: 01-12 04:21:25] {2391} INFO -  at 14.0s,	estimator xgboost's best error=0.1240,	best estimator xgboost's best error=0.1240
# [flaml.automl.logger: 01-12 04:21:25] {2218} INFO - iteration 9, current learner extra_tree
# [flaml.automl.logger: 01-12 04:21:26] {2391} INFO -  at 15.2s,	estimator extra_tree's best error=0.1605,	best estimator xgboost's best error=0.1240
# [flaml.automl.logger: 01-12 04:21:26] {2218} INFO - iteration 10, current learner rf
# [flaml.automl.logger: 01-12 04:21:27] {2391} INFO -  at 15.9s,	estimator rf's best error=0.1876,	best estimator xgboost's best error=0.1240
# [flaml.automl.logger: 01-12 04:21:27] {2218} INFO - iteration 11, current learner rf
# [flaml.automl.logger: 01-12 04:21:28] {2391} INFO -  at 17.5s,	estimator rf's best error=0.1430,	best estimator xgboost's best error=0.1240
# [flaml.automl.logger: 01-12 04:21:28] {2218} INFO - iteration 12, current learner rf
# [flaml.automl.logger: 01-12 04:21:29] {2391} INFO -  at 18.4s,	estimator rf's best error=0.1430,	best estimator xgboost's best error=0.1240
# [flaml.automl.logger: 01-12 04:21:29] {2218} INFO - iteration 13, current learner rf
# [flaml.automl.logger: 01-12 04:21:30] {2391} INFO -  at 19.6s,	estimator rf's best error=0.1430,	best estimator xgboost's best error=0.1240
# [flaml.automl.logger: 01-12 04:21:30] {2218} INFO - iteration 14, current learner rf
# [flaml.automl.logger: 01-12 04:21:37] {2391} INFO -  at 25.7s,	estimator rf's best error=0.1122,	best estimator rf's best error=0.1122
# [flaml.automl.logger: 01-12 04:21:37] {2218} INFO - iteration 15, current learner extra_tree
# [flaml.automl.logger: 01-12 04:21:37] {2391} INFO -  at 26.3s,	estimator extra_tree's best error=0.1605,	best estimator rf's best error=0.1122
# [flaml.automl.logger: 01-12 04:21:37] {2218} INFO - iteration 16, current learner rf
# [flaml.automl.logger: 01-12 04:21:41] {2391} INFO -  at 29.9s,	estimator rf's best error=0.1122,	best estimator rf's best error=0.1122
# [flaml.automl.logger: 01-12 04:21:41] {2218} INFO - iteration 17, current learner extra_tree
# [flaml.automl.logger: 01-12 04:21:41] {2391} INFO -  at 30.6s,	estimator extra_tree's best error=0.1605,	best estimator rf's best error=0.1122
# [flaml.automl.logger: 01-12 04:21:41] {2218} INFO - iteration 18, current learner xgboost
# [flaml.automl.logger: 01-12 04:21:48] {2391} INFO -  at 36.8s,	estimator xgboost's best error=0.0867,	best estimator xgboost's best error=0.0867
# [flaml.automl.logger: 01-12 04:21:48] {2218} INFO - iteration 19, current learner extra_tree
# [flaml.automl.logger: 01-12 04:21:51] {2391} INFO -  at 40.3s,	estimator extra_tree's best error=0.1170,	best estimator xgboost's best error=0.0867
# [flaml.automl.logger: 01-12 04:21:51] {2218} INFO - iteration 20, current learner xgboost
# [flaml.automl.logger: 01-12 04:22:01] {2391} INFO -  at 50.2s,	estimator xgboost's best error=0.0867,	best estimator xgboost's best error=0.0867
# [flaml.automl.logger: 01-12 04:22:01] {2218} INFO - iteration 21, current learner extra_tree
# [flaml.automl.logger: 01-12 04:22:04] {2391} INFO -  at 52.8s,	estimator extra_tree's best error=0.1127,	best estimator xgboost's best error=0.0867
# [flaml.automl.logger: 01-12 04:22:04] {2218} INFO - iteration 22, current learner catboost
# [flaml.automl.logger: 01-12 04:22:21] {2391} INFO -  at 69.9s,	estimator catboost's best error=0.0509,	best estimator catboost's best error=0.0509
# [flaml.automl.logger: 01-12 04:22:21] {2218} INFO - iteration 23, current learner lrl2
# INFO:flaml.tune.searcher.blendsearch:No low-cost partial config given to the search algorithm. For cost-frugal search, consider providing low-cost values for cost-related hps via 'low_cost_partial_config'. More info can be found at https://microsoft.github.io/FLAML/docs/FAQ#about-low_cost_partial_config-in-tune
# [flaml.automl.logger: 01-12 04:22:30] {2391} INFO -  at 79.3s,	estimator lrl2's best error=0.2310,	best estimator catboost's best error=0.0509
# [flaml.automl.logger: 01-12 04:22:30] {2218} INFO - iteration 24, current learner xgboost
# [flaml.automl.logger: 01-12 04:22:32] {2391} INFO -  at 80.9s,	estimator xgboost's best error=0.0847,	best estimator catboost's best error=0.0509
# [flaml.automl.logger: 01-12 04:22:32] {2218} INFO - iteration 25, current learner lrl2
# [flaml.automl.logger: 01-12 04:22:41] {2391} INFO -  at 89.9s,	estimator lrl2's best error=0.2310,	best estimator catboost's best error=0.0509
# [flaml.automl.logger: 01-12 04:22:41] {2218} INFO - iteration 26, current learner catboost
# [flaml.automl.logger: 01-12 04:23:07] {2391} INFO -  at 116.4s,	estimator catboost's best error=0.0482,	best estimator catboost's best error=0.0482
# [flaml.automl.logger: 01-12 04:23:07] {2218} INFO - iteration 27, current learner kneighbor
# [flaml.automl.logger: 01-12 04:23:26] {2391} INFO -  at 135.7s,	estimator kneighbor's best error=0.3191,	best estimator catboost's best error=0.0482
# [flaml.automl.logger: 01-12 04:23:26] {2218} INFO - iteration 28, current learner kneighbor
# [flaml.automl.logger: 01-12 04:23:47] {2391} INFO -  at 155.9s,	estimator kneighbor's best error=0.3181,	best estimator catboost's best error=0.0482
# [flaml.automl.logger: 01-12 04:23:47] {2218} INFO - iteration 29, current learner lrl2
# [flaml.automl.logger: 01-12 04:23:56] {2391} INFO -  at 164.7s,	estimator lrl2's best error=0.2286,	best estimator catboost's best error=0.0482
# [flaml.automl.logger: 01-12 04:23:56] {2218} INFO - iteration 30, current learner catboost
# [flaml.automl.logger: 01-12 04:24:53] {2391} INFO -  at 222.0s,	estimator catboost's best error=0.0482,	best estimator catboost's best error=0.0482
# [flaml.automl.logger: 01-12 04:24:53] {2218} INFO - iteration 31, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 04:24:54] {2391} INFO -  at 223.1s,	estimator xgb_limitdepth's best error=0.0735,	best estimator catboost's best error=0.0482
# [flaml.automl.logger: 01-12 04:24:54] {2218} INFO - iteration 32, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 04:24:56] {2391} INFO -  at 225.2s,	estimator xgb_limitdepth's best error=0.0533,	best estimator catboost's best error=0.0482
# [flaml.automl.logger: 01-12 04:24:56] {2218} INFO - iteration 33, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 04:24:57] {2391} INFO -  at 226.3s,	estimator xgb_limitdepth's best error=0.0533,	best estimator catboost's best error=0.0482
# [flaml.automl.logger: 01-12 04:24:57] {2218} INFO - iteration 34, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 04:25:07] {2391} INFO -  at 236.0s,	estimator xgb_limitdepth's best error=0.0508,	best estimator catboost's best error=0.0482
# [flaml.automl.logger: 01-12 04:25:07] {2218} INFO - iteration 35, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 04:25:09] {2391} INFO -  at 238.1s,	estimator xgb_limitdepth's best error=0.0508,	best estimator catboost's best error=0.0482
# [flaml.automl.logger: 01-12 04:25:09] {2218} INFO - iteration 36, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 04:25:16] {2391} INFO -  at 245.5s,	estimator xgb_limitdepth's best error=0.0508,	best estimator catboost's best error=0.0482
# [flaml.automl.logger: 01-12 04:25:16] {2218} INFO - iteration 37, current learner extra_tree
# [flaml.automl.logger: 01-12 04:25:20] {2391} INFO -  at 248.9s,	estimator extra_tree's best error=0.1127,	best estimator catboost's best error=0.0482
# [flaml.automl.logger: 01-12 04:25:20] {2218} INFO - iteration 38, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 04:25:32] {2391} INFO -  at 261.3s,	estimator xgb_limitdepth's best error=0.0485,	best estimator catboost's best error=0.0482
# [flaml.automl.logger: 01-12 04:25:32] {2218} INFO - iteration 39, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 04:26:02] {2391} INFO -  at 291.6s,	estimator xgb_limitdepth's best error=0.0485,	best estimator catboost's best error=0.0482
# [flaml.automl.logger: 01-12 04:26:02] {2218} INFO - iteration 40, current learner extra_tree
# [flaml.automl.logger: 01-12 04:26:04] {2391} INFO -  at 292.9s,	estimator extra_tree's best error=0.1127,	best estimator catboost's best error=0.0482
# [flaml.automl.logger: 01-12 04:26:04] {2218} INFO - iteration 41, current learner rf
# [flaml.automl.logger: 01-12 04:26:14] {2391} INFO -  at 303.1s,	estimator rf's best error=0.1113,	best estimator catboost's best error=0.0482
# [flaml.automl.logger: 01-12 04:26:14] {2218} INFO - iteration 42, current learner catboost
# [flaml.automl.logger: 01-12 04:26:31] {2391} INFO -  at 320.3s,	estimator catboost's best error=0.0482,	best estimator catboost's best error=0.0482
# [flaml.automl.logger: 01-12 04:26:31] {2218} INFO - iteration 43, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 04:26:35] {2391} INFO -  at 323.9s,	estimator xgb_limitdepth's best error=0.0485,	best estimator catboost's best error=0.0482
# [flaml.automl.logger: 01-12 04:26:35] {2218} INFO - iteration 44, current learner catboost
# [flaml.automl.logger: 01-12 04:26:58] {2391} INFO -  at 346.7s,	estimator catboost's best error=0.0482,	best estimator catboost's best error=0.0482
# [flaml.automl.logger: 01-12 04:26:58] {2218} INFO - iteration 45, current learner catboost
# [flaml.automl.logger: 01-12 04:27:33] {2391} INFO -  at 382.3s,	estimator catboost's best error=0.0476,	best estimator catboost's best error=0.0476
# [flaml.automl.logger: 01-12 04:27:33] {2218} INFO - iteration 46, current learner xgboost
# [flaml.automl.logger: 01-12 04:27:34] {2391} INFO -  at 383.3s,	estimator xgboost's best error=0.0847,	best estimator catboost's best error=0.0476
# [flaml.automl.logger: 01-12 04:27:34] {2218} INFO - iteration 47, current learner catboost
# [flaml.automl.logger: 01-12 04:28:01] {2391} INFO -  at 410.6s,	estimator catboost's best error=0.0476,	best estimator catboost's best error=0.0476
# [flaml.automl.logger: 01-12 04:28:01] {2218} INFO - iteration 48, current learner extra_tree
# [flaml.automl.logger: 01-12 04:28:07] {2391} INFO -  at 416.2s,	estimator extra_tree's best error=0.1127,	best estimator catboost's best error=0.0476
# [flaml.automl.logger: 01-12 04:28:07] {2218} INFO - iteration 49, current learner catboost
# [flaml.automl.logger: 01-12 04:28:51] {2391} INFO -  at 460.0s,	estimator catboost's best error=0.0476,	best estimator catboost's best error=0.0476
# [flaml.automl.logger: 01-12 04:28:51] {2218} INFO - iteration 50, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 04:28:59] {2391} INFO -  at 468.5s,	estimator xgb_limitdepth's best error=0.0485,	best estimator catboost's best error=0.0476
# [flaml.automl.logger: 01-12 04:28:59] {2218} INFO - iteration 51, current learner catboost
# [flaml.automl.logger: 01-12 04:29:15] {2391} INFO -  at 484.4s,	estimator catboost's best error=0.0476,	best estimator catboost's best error=0.0476
# [flaml.automl.logger: 01-12 04:29:15] {2218} INFO - iteration 52, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 04:29:32] {2391} INFO -  at 501.3s,	estimator xgb_limitdepth's best error=0.0475,	best estimator xgb_limitdepth's best error=0.0475
# [flaml.automl.logger: 01-12 04:29:32] {2218} INFO - iteration 53, current learner xgb_limitdepth
# [flaml.automl.logger: 01-12 04:29:45] {2391} INFO -  at 514.3s,	estimator xgb_limitdepth's best error=0.0475,	best estimator xgb_limitdepth's best error=0.0475
# [flaml.automl.logger: 01-12 04:29:45] {2218} INFO - iteration 54, current learner catboost
# [flaml.automl.logger: 01-12 04:31:07] {2391} INFO -  at 596.6s,	estimator catboost's best error=0.0476,	best estimator xgb_limitdepth's best error=0.0475
# [flaml.automl.logger: 01-12 04:31:07] {2218} INFO - iteration 55, current learner lrl1
# INFO:flaml.tune.searcher.blendsearch:No low-cost partial config given to the search algorithm. For cost-frugal search, consider providing low-cost values for cost-related hps via 'low_cost_partial_config'. More info can be found at https://microsoft.github.io/FLAML/docs/FAQ#about-low_cost_partial_config-in-tune
# [flaml.automl.logger: 01-12 04:31:11] {2391} INFO -  at 600.4s,	estimator lrl1's best error=0.3484,	best estimator xgb_limitdepth's best error=0.0475
# [flaml.automl.logger: 01-12 04:31:14] {2627} INFO - retrain xgb_limitdepth for 3.2s
# [flaml.automl.logger: 01-12 04:31:14] {2630} INFO - retrained model: XGBClassifier(base_score=None, booster=None, callbacks=[],
#               colsample_bylevel=0.8976632531695978, colsample_bynode=None,
#               colsample_bytree=0.9891267920793386, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.08756537759052367,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=11, max_leaves=None,
#               min_child_weight=8.384287675156479, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=266,
#               n_jobs=-1, num_parallel_tree=None, random_state=None, ...)
# [flaml.automl.logger: 01-12 04:31:14] {1930} INFO - fit succeeded
# [flaml.automl.logger: 01-12 04:31:14] {1931} INFO - Time taken to find the best model: 501.2943277359009

# %%
# retrieve best config and best learner
print('Best ML leaner:', automl6.best_estimator)
print('Best hyperparmeter config:', automl6.best_config)
print('Best accuracy on validation data: {0:.4g}'.format(1-automl6.best_loss))
print('Training duration of best run: {0:.4g} s'.format(automl6.best_config_train_time))
# Out:
# Best ML leaner: xgb_limitdepth
# Best hyperparmeter config: {'n_estimators': 266, 'max_depth': 11, 'min_child_weight': 8.384287675156479, 'learning_rate': 0.08756537759052367, 'subsample': 0.8485132172169152, 'colsample_bylevel': 0.8976632531695978, 'colsample_bytree': 0.9891267920793386, 'reg_alpha': 0.098118480584988, 'reg_lambda': 0.05551336945491275}
# Best accuracy on validation data: 0.9525
# Training duration of best run: 3.161 s

# %%
# obtain best model
automl6.model.estimator
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=[],
#               colsample_bylevel=0.8976632531695978, colsample_bynode=None,
#               colsample_bytree=0.9891267920793386, device=None,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, feature_types=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.08756537759052367,
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=11, max_leaves=None,
#               min_child_weight=8.384287675156479, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=266,
#               n_jobs=-1, num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ##### Predict for train data using CV

# %%
# compute predictions of testing dataset'''
y_pred6 = automl6.predict(test_x)
y_pred_proba6 = automl6.predict_proba(test_x)[:,1]

# %%
# compute different metric values on testing dataset'''
from flaml.ml import sklearn_metric_loss_score
print('accuracy', '=', 1 - sklearn_metric_loss_score('accuracy', y_pred6, y_test))
print('roc_auc', '=', 1 - sklearn_metric_loss_score('roc_auc', y_pred_proba6, y_test))
print('log_loss', '=', sklearn_metric_loss_score('log_loss', y_pred_proba6, y_test))
# Out:
# accuracy = 0.9541569541569541
# roc_auc = 0.9933064204282956
# log_loss = 0.10364181346102141

# %%
predict(automl6, 'automl6', pred_x)

# %% [markdown]
# #### **Binning**

# %% [markdown]
# Creating Age Bins

# %%
# bin df_train['Age'] into 4 bins
#X_train_imputed['Age_Bins'] = pd.cut(X_train_imputed['Age'], bins = [0, 20, 40, 60, float('inf')], labels = ['0-20', '21-40', '41-60', '61+'])
#X_train_imputed['Age_Bins'].replace(['0-20', '21-40', '41-60', '61+'], [0, 1, 2, 3], inplace = True)

#X_test_imputed['Age_Bins'] = pd.cut(X_test_imputed['Age'], bins = [0, 20, 40, 60, float('inf')], labels = ['0-20', '21-40', '41-60', '61+'])
#X_test_imputed['Age_Bins'].replace(['0-20', '21-40', '41-60', '61+'], [0, 1, 2, 3], inplace = True)

#df_pred_imputed['Age_Bins'] = pd.cut(df_pred_imputed['Age'], bins = [0, 20, 40, 60, float('inf')], labels = ['0-20', '21-40', '41-60', '61+'])
#df_pred_imputed['Age_Bins'].replace(['0-20', '21-40', '41-60', '61+'], [0, 1, 2, 3], inplace = True)

# %%
#X_train_imputed['Age_Bins'].value_counts(), X_test_imputed['Age_Bins'].value_counts(), df_pred_imputed['Age_Bins'].value_counts()

# %% [markdown]
# Creating Arrival_Delay_Bins

# %%
# bin 'Arrival_Delay_in_Mins' into 4 bins
X_train_imputed['Arrival_Delay_Bins'] = pd.cut(X_train_imputed['Arrival_Delay_in_Mins'], bins = [-float('inf'), 0, 10, 120, float('inf')], labels = ['0', '1-10', '11-120', '121+'])
X_train_imputed['Arrival_Delay_Bins'].replace(['0', '1-10', '11-120', '121+'], [0, 1, 2, 3], inplace = True)

X_test_imputed['Arrival_Delay_Bins'] = pd.cut(X_test_imputed['Arrival_Delay_in_Mins'], bins = [-float('inf'), 0, 10, 120, float('inf')], labels = ['0', '1-10', '11-120', '121+'])
X_test_imputed['Arrival_Delay_Bins'].replace(['0', '1-10', '11-120', '121+'], [0, 1, 2, 3], inplace = True)

df_pred_imputed['Arrival_Delay_Bins'] = pd.cut(df_pred_imputed['Arrival_Delay_in_Mins'], bins = [-float('inf'), 0, 10, 120, float('inf')], labels = ['0', '1-10', '11-120', '121+'])
df_pred_imputed['Arrival_Delay_Bins'].replace(['0', '1-10', '11-120', '121+'], [0, 1, 2, 3], inplace = True)

# %% [markdown]
# Creating Total_Delay Bins

# %%
#X_train_imputed['Total_Delay'] = X_train_imputed['Arrival_Delay_in_Mins'] + X_train_imputed['Departure_Delay_in_Mins']

#X_test_imputed['Total_Delay'] = X_test_imputed['Arrival_Delay_in_Mins'] + X_test_imputed['Departure_Delay_in_Mins']

#df_pred_imputed['Total_Delay'] = df_pred_imputed['Arrival_Delay_in_Mins'] + df_pred_imputed['Departure_Delay_in_Mins']

# %%
X_train_imputed['Arrival_Delay_Bins'].describe()
# Out:
# count     66065
# unique        4
# top           0
# freq      37106
# Name: Arrival_Delay_Bins, dtype: int64

# %%
# bin 'Arrival_Delay_in_Mins' into 4 bins
#X_train_imputed['Total_Delay_Bins'] = pd.cut(X_train_imputed['Total_Delay'], bins = [-float('inf'), 0, 10, 120, float('inf')], labels = ['0', '1-10', '11-120', '121+'])
#X_train_imputed['Total_Delay_Bins'].replace(['0', '1-10', '11-120', '121+'], [0, 1, 2, 3], inplace = True)

#X_test_imputed['Total_Delay_Bins'] = pd.cut(X_test_imputed['Total_Delay'], bins = [-float('inf'), 0, 10, 120, float('inf')], labels = ['0', '1-10', '11-120', '121+'])
#X_test_imputed['Total_Delay_Bins'].replace(['0', '1-10', '11-120', '121+'], [0, 1, 2, 3], inplace = True)

#df_pred_imputed['Total_Delay_Bins'] = pd.cut(df_pred_imputed['Total_Delay'], bins = [-float('inf'), 0, 10, 120, float('inf')], labels = ['0', '1-10', '11-120', '121+'])
#df_pred_imputed['Total_Delay_Bins'].replace(['0', '1-10', '11-120', '121+'], [0, 1, 2, 3], inplace = True)

# %%
X_train_imputed['Arrival_Delay_Bins'].value_counts(), X_test_imputed['Arrival_Delay_Bins'].value_counts(), df_pred_imputed['Arrival_Delay_Bins'].value_counts()
# Out:
# (0    37106
#  2    16570
#  1    10733
#  3     1656
#  Name: Arrival_Delay_Bins, dtype: int64,
#  0    15815
#  2     7221
#  1     4611
#  3      667
#  Name: Arrival_Delay_Bins, dtype: int64,
#  0    19850
#  2     9097
#  1     5750
#  3      905
#  Name: Arrival_Delay_Bins, dtype: int64)

# %% [markdown]
# Creating Distance_Traveled Bins

# %%
# create 3 bins for Travel_Distance
X_train_imputed['Travel_Distance_Bins'] = pd.cut(X_train_imputed['Travel_Distance'], bins = [0, 1000, 3000, float('inf')], labels = ['0-1000', '1001-3000', '3001+'])
X_train_imputed['Travel_Distance_Bins'].replace(['0-1000', '1001-3000', '3001+'], [0, 1, 2], inplace = True)

X_test_imputed['Travel_Distance_Bins'] = pd.cut(X_test_imputed['Travel_Distance'], bins = [0, 1000, 3000, float('inf')], labels = ['0-1000', '1001-3000', '3001+'])
X_test_imputed['Travel_Distance_Bins'].replace(['0-1000', '1001-3000', '3001+'], [0, 1, 2], inplace = True)

df_pred_imputed['Travel_Distance_Bins'] = pd.cut(df_pred_imputed['Travel_Distance'], bins = [0, 1000, 3000, float('inf')], labels = ['0-1000', '1001-3000', '3001+'])
df_pred_imputed['Travel_Distance_Bins'].replace(['0-1000', '1001-3000', '3001+'], [0, 1, 2], inplace = True)

# %%
X_train_imputed['Travel_Distance_Bins'].value_counts(), X_test_imputed['Travel_Distance_Bins'].value_counts(), df_pred_imputed['Travel_Distance_Bins'].value_counts()
# Out:
# (1    44603
#  0    11436
#  2    10026
#  Name: Travel_Distance_Bins, dtype: int64,
#  1    18989
#  0     5032
#  2     4293
#  Name: Travel_Distance_Bins, dtype: int64,
#  1    23994
#  0     6120
#  2     5488
#  Name: Travel_Distance_Bins, dtype: int64)

# %%
df_pred_imputed.head()
# Out:
#    Gender  Customer_Type   Age  Type_Travel  Travel_Class  Travel_Distance  \
# 0     1.0            1.0  36.0          1.0           1.0            532.0
# 1     1.0            0.0  21.0          1.0           1.0           1425.0
# 2     0.0            1.0  60.0          1.0           1.0           2832.0
# 3     1.0            1.0  29.0          0.0           0.0           1352.0
# 4     0.0            0.0  18.0          1.0           1.0           1610.0
#
#    Departure_Delay_in_Mins  Arrival_Delay_in_Mins  Seat_Comfort  Seat_Class  \
# 0                      0.0                    0.0           3.0         1.0
# 1                      9.0                   28.0           0.0         0.0
# 2                      0.0                    0.0           5.0         0.0
# 3                      0.0                    0.0           3.0         1.0
# 4                     17.0                    0.0           5.0         0.0
#
#    ...  Online_Support  Ease_of_Online_Booking  Onboard_Service  Legroom  \
# 0  ...             4.0                     5.0         5.000000      5.0
# 1  ...             3.0                     3.0         5.000000      3.0
# 2  ...             5.0                     2.0         2.000000      2.0
# 3  ...             5.0                     1.0         3.000000      2.0
# 4  ...             5.0                     5.0         3.714286      3.0
#
#    Baggage_Handling  CheckIn_Service  Cleanliness  Online_Boarding  \
# 0               5.0              4.0          5.0              1.0
# 1               4.0              3.0          5.0              3.0
# 2               2.0              4.0          2.0              5.0
# 3               5.0              5.0          5.0              1.0
# 4               5.0              5.0          5.0              5.0
#
#    Arrival_Delay_Bins  Travel_Distance_Bins
# 0                   0                     0
# 1                   2                     1
# 2                   0                     1
# 3                   0                     1
# 4                   0                     1
#
# [5 rows x 25 columns]
